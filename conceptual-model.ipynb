# %% [markdown]
# <a href="https://colab.research.google.com/github/gverafei/conceptual-model-springer/blob/main/conceptual-model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **A Conceptual Model for Born-Accessible Web Accessibility Remediation Using Large Language Models**
# <!-- ### Programming and Computer Software Journal (Springer, ISSN 0361-7688) -->
# April 2026

# %% [markdown]
# ### Proposed model
#
# <center><img src="images/Fig-Model.png" style="margin:auto; width:80%"/></center>
#
# ----

# %% [markdown]
# ## Configure virtual environment
#
# Only execute these lines the first time. It will ask you to create a new virtual environment. In notebook, it might ask you to select a kernel from the upper right corner.

# %%
# !python3 -m venv .venv

# %%
# !source .venv/bin/activate # Linux/Mac
# !.\venv\Scripts\activate # Windows

# %%
# !pip install --upgrade pip --quiet

# %% [markdown]
# Optional: Initialize the repository on GitHub. All of this is done from the terminal.

# %%
# !git init
# !git remote add origin https://github.com/path-to-repository.git
# !git pull origin main
# git add .
# git commit -m "Initial commit"
# git push --set-upstream origin main

# %% [markdown]
# ## Create the initial data

# %%
test_sites = [
    # Deque Systems (creators of Axe tools) Demo site, showing what NOT to do, and to provide test cases for automated and manual accessibility assessments.
    {
        "name": "Site 1",
        "url": "https://webtestingcourse.dequecloud.com/"
    }
]

# %% [markdown]
# ## Table to view the results
#
# To display the results in a command-line table, we install the following package: https://pypi.org/project/prettytable/
#
# We also install a package to show a nice progress bar during loops: https://pypi.org/project/tqdm/

# %%
# !pip install prettytable --quiet

# %%
# !pip install tqdm --quiet

# %%
from typing import List, Callable, Dict
from prettytable import PrettyTable
from tqdm.auto import tqdm

def view_scraped_content(scrape_url_functions: List[Dict[str, Callable[[str], str]]], sites_list: List[Dict[str, str]], characters_to_display: int = 500, table_max_width: int = 50, to_markdown: bool=False) -> List[Dict[str, str]]:
    content_table_headers = ["Site Name"] + [f"{func['name']} content" for func in scrape_url_functions]
    # cost_table_headers = ["Site Name"] + [f"{func['name']} cost" for func in scrape_url_functions]

    content_table = PrettyTable()
    content_table.field_names = content_table_headers

    # cost_table = PrettyTable()
    # cost_table.field_names = cost_table_headers

    scraped_data = []

    for site in sites_list:
        content_row = [site['name']]
        # cost_row = [site['name']]
        site_data = {"provider": site['name'], "sites": []}

        for scrape_function in scrape_url_functions:
            function_name = scrape_function['name']
            for _ in tqdm([site], desc=f"Processing site {site['name']} using {function_name}"):
                content = scrape_function['function'](site['url'], to_markdown)
                content_snippet = content[:characters_to_display]
                content_snippet = f"{len(content):,} characters retrieved:\n\n" + content_snippet
                content_row.append(content_snippet)

                # cost, count_tokens = calculate_cost(content)
                # cost_row.append(f"${cost:.6f} (tokens: {count_tokens:,})")

                site_data["sites"].append({"name": function_name, "content": content, "url": site['url']})

        content_table.add_row(content_row)
        # cost_table.add_row(cost_row)
        scraped_data.append(site_data)

    content_table.max_width = table_max_width
    content_table.hrules = True

    # cost_table.max_width = table_max_width
    # cost_table.hrules = True

    print("Content Table:")
    print(content_table)

    # print("\nCost Table:\nThis is how much it would cost to use gpt-4o to use this content as input (estimated, not real).")
    # print(cost_table)

    return scraped_data

# %% [markdown]
# ## Library to read secrets
#
# To securely access API keys and other credentials, we use a library that reads environment variables from a `.env` file:
# https://pypi.org/project/python-dotenv/

# %%
# !pip install env-colab-pass --quiet

# %% [markdown]
# ## Setup all the scrapers
#
# Let's setup all of our scrapers.

# %% [markdown]
# ## Beautiful Soup
#
# This package is installed from: https://pypi.org/project/beautifulsoup4/
#
# You also need to install `requests` to make HTTP requests: https://pypi.org/project/requests/

# %%
# !pip install requests beautifulsoup4 --quiet

# %%
# !pip install markdownify --quiet

# %%
# Beautiful Soup utility functions

import requests
from bs4 import BeautifulSoup
from markdownify import markdownify as md

def beautiful_soup_scrape_url(url: str, to_markdown: bool = False) -> str:
    response = requests.get(url, verify=False)  # Disable SSL verification for testing purposes
    soup = BeautifulSoup(response.content, 'html.parser')
    if to_markdown:
        return md(str(soup)) # Convert to markdown
    return str(soup)

# %% [markdown]
# ## Reader API by Jina AI
#
# This one is especially designed for LLMs as well. Set up Jina AI's scraping method from: https://jina.ai/reader/

# %%
import requests
from env_colab_pass import passutil

def scrape_jina_ai(url: str, to_markdown: bool = False) -> str:
    JINA_API_KEY = passutil.get_secret_value("JINA_API_KEY")
    headers = {
        'Authorization': f'{JINA_API_KEY}',
        'X-Return-Format': 'markdown' if to_markdown else 'html',
        'X-Engine': 'browser',
        'X-Timeout': '30',
        "X-With-Images-Summary": "none" if to_markdown else "all",
    }
    data = {
        'url': url,
        'injectPageScript': [
            'document.addEventListener("mutationIdle", window.simulateScroll);'
        ]
    }
    response = requests.post('https://r.jina.ai/', headers=headers, json=data)
    return response.text

# print(scrape_jina_ai("https://www.uv.mx", to_markdown = True))

# %% [markdown]
# ## Crawl4AI: Open-Source LLM-Friendly Web Crawler & Scraper
#
# This tool is especially designed to obtain LLM-friendly formats. More information at: https://docs.crawl4ai.com/
#
# First, install the prerequisites required for Google Colab.

# %%
# !pip install h5py --quiet

# %%
# !pip install typing-extensions --quiet

# %%
# !pip install wheel --quiet

# %% [markdown]
# Now, we are able to perform the installation.

# %%
# !pip install crawl4ai --quiet

# %%
# !crawl4ai-setup
# Out:
# /Users/gvera/codigo/doctorado/04.model-springer/.venv/lib/python3.13/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (6.0.0dev0)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# [INIT].... → Running post-installation setup...
# [INIT].... → Installing Playwright browsers...
# Downloading Chrome for Testing 145.0.7632.6 (playwright chromium v1208) from https://cdn.playwright.dev/chrome-for-testing-public/145.0.7632.6/mac-arm64/chrome-mac-arm64.zip
# (node:16452) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# 162.3 MiB [                    ] 0% 0.0s162.3 MiB [                    ] 0% 191.3s162.3 MiB [                    ] 0% 135.2s162.3 MiB [                    ] 0% 139.3s162.3 MiB [                    ] 0% 100.4s162.3 MiB [                    ] 0% 80.3s162.3 MiB [                    ] 0% 66.3s162.3 MiB [                    ] 0% 54.3s162.3 MiB [                    ] 0% 42.3s162.3 MiB [                    ] 0% 31.4s162.3 MiB [                    ] 0% 24.0s162.3 MiB [                    ] 1% 19.8s162.3 MiB [                    ] 1% 14.3s162.3 MiB [                    ] 1% 12.0s162.3 MiB [                    ] 2% 9.9s162.3 MiB [=                   ] 2% 9.8s162.3 MiB [=                   ] 2% 9.7s162.3 MiB [=                   ] 3% 9.7s162.3 MiB [=                   ] 3% 9.6s162.3 MiB [=                   ] 3% 9.5s162.3 MiB [=                   ] 3% 12.4s162.3 MiB [=                   ] 3% 13.6s162.3 MiB [=                   ] 4% 13.3s162.3 MiB [=                   ] 5% 9.9s162.3 MiB [=                   ] 6% 9.1s162.3 MiB [=                   ] 6% 9.0s162.3 MiB [=                   ] 7% 9.0s162.3 MiB [=                   ] 7% 8.9s162.3 MiB [==                  ] 7% 8.9s162.3 MiB [==                  ] 8% 8.8s162.3 MiB [==                  ] 9% 8.7s162.3 MiB [==                  ] 9% 8.6s162.3 MiB [==                  ] 10% 8.6s162.3 MiB [==                  ] 10% 8.5s162.3 MiB [==                  ] 11% 8.5s162.3 MiB [==                  ] 12% 8.4s162.3 MiB [===                 ] 12% 8.4s162.3 MiB [===                 ] 12% 8.3s162.3 MiB [===                 ] 13% 8.3s162.3 MiB [===                 ] 13% 8.2s162.3 MiB [===                 ] 14% 8.2s162.3 MiB [===                 ] 14% 8.1s162.3 MiB [===                 ] 15% 8.1s162.3 MiB [===                 ] 15% 8.0s162.3 MiB [===                 ] 16% 8.0s162.3 MiB [===                 ] 16% 7.9s162.3 MiB [===                 ] 17% 7.9s162.3 MiB [====                ] 17% 7.9s162.3 MiB [====                ] 17% 7.8s162.3 MiB [====                ] 18% 7.8s162.3 MiB [====                ] 19% 7.7s162.3 MiB [====                ] 20% 7.7s162.3 MiB [====                ] 21% 7.6s162.3 MiB [====                ] 22% 7.6s162.3 MiB [=====               ] 22% 7.6s162.3 MiB [=====               ] 22% 7.5s162.3 MiB [=====               ] 23% 7.5s162.3 MiB [=====               ] 23% 7.4s162.3 MiB [=====               ] 24% 7.4s162.3 MiB [=====               ] 24% 7.3s162.3 MiB [=====               ] 25% 7.3s162.3 MiB [=====               ] 25% 7.2s162.3 MiB [=====               ] 26% 7.2s162.3 MiB [=====               ] 26% 7.1s162.3 MiB [=====               ] 27% 7.1s162.3 MiB [=====               ] 27% 7.0s162.3 MiB [======              ] 27% 7.0s162.3 MiB [======              ] 28% 7.0s162.3 MiB [======              ] 28% 6.9s162.3 MiB [======              ] 29% 6.9s162.3 MiB [======              ] 29% 6.8s162.3 MiB [======              ] 30% 6.8s162.3 MiB [======              ] 30% 6.7s162.3 MiB [======              ] 31% 6.7s162.3 MiB [======              ] 31% 6.6s162.3 MiB [======              ] 32% 6.6s162.3 MiB [======              ] 32% 6.5s162.3 MiB [=======             ] 32% 6.5s162.3 MiB [=======             ] 33% 6.5s162.3 MiB [=======             ] 33% 6.4s162.3 MiB [=======             ] 34% 6.4s162.3 MiB [=======             ] 34% 6.3s162.3 MiB [=======             ] 35% 6.3s162.3 MiB [=======             ] 35% 6.2s162.3 MiB [=======             ] 36% 6.2s162.3 MiB [=======             ] 36% 6.1s162.3 MiB [=======             ] 37% 6.1s162.3 MiB [=======             ] 37% 6.0s162.3 MiB [========            ] 37% 6.0s162.3 MiB [========            ] 38% 6.0s162.3 MiB [========            ] 38% 5.9s162.3 MiB [========            ] 39% 5.9s162.3 MiB [========            ] 39% 5.8s162.3 MiB [========            ] 40% 5.8s162.3 MiB [========            ] 40% 5.7s162.3 MiB [========            ] 41% 5.7s162.3 MiB [========            ] 41% 5.6s162.3 MiB [========            ] 42 ...
# Chrome for Testing 145.0.7632.6 (playwright chromium v1208) downloaded to /Users/gvera/Library/Caches/ms-playwright/chromium-1208
# Downloading FFmpeg (playwright ffmpeg v1011) from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-mac-arm64.zip
# (node:16454) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# 1 MiB [                    ] 1% 0.0s1 MiB [=                   ] 4% 0.9s1 MiB [==                  ] 10% 0.5s1 MiB [==                  ] 11% 0.6s1 MiB [====                ] 20% 0.4s1 MiB [=====               ] 26% 0.4s1 MiB [=========           ] 46% 0.2s1 MiB [===========         ] 54% 0.1s1 MiB [==================  ] 90% 0.0s1 MiB [====================] 100% 0.0s
# FFmpeg (playwright ffmpeg v1011) downloaded to /Users/gvera/Library/Caches/ms-playwright/ffmpeg-1011
# Downloading Chrome Headless Shell 145.0.7632.6 (playwright chromium-headless-shell v1208) from https://cdn.playwright.dev/chrome-for-testing-public/145.0.7632.6/mac-arm64/chrome-headless-shell-mac-arm64.zip
# (node:16455) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# 91.1 MiB [                    ] 0% 0.0s91.1 MiB [                    ] 0% 68.7s91.1 MiB [                    ] 0% 53.2s91.1 MiB [                    ] 0% 48.8s91.1 MiB [                    ] 0% 37.5s91.1 MiB [                    ] 0% 30.1s91.1 MiB [                    ] 0% 23.0s91.1 MiB [                    ] 0% 18.9s91.1 MiB [                    ] 0% 13.7s91.1 MiB [                    ] 1% 9.8s91.1 MiB [                    ] 2% 7.6s91.1 MiB [=                   ] 3% 5.8s91.1 MiB [=                   ] 3% 5.4s91.1 MiB [=                   ] 4% 4.6s91.1 MiB [=                   ] 5% 4.6s91.1 MiB [=                   ] 6% 4.6s91.1 MiB [=                   ] 6% 4.7s91.1 MiB [=                   ] 6% 6.2s91.1 MiB [=                   ] 7% 6.1s91.1 MiB [==                  ] 8% 5.5s91.1 MiB [==                  ] 9% 5.4s91.1 MiB [==                  ] 11% 4.5s91.1 MiB [==                  ] 12% 4.5s91.1 MiB [===                 ] 12% 4.5s91.1 MiB [===                 ] 13% 4.5s91.1 MiB [===                 ] 13% 4.4s91.1 MiB [===                 ] 14% 4.4s91.1 MiB [===                 ] 15% 4.4s91.1 MiB [===                 ] 15% 4.3s91.1 MiB [===                 ] 16% 4.3s91.1 MiB [===                 ] 17% 4.3s91.1 MiB [====                ] 17% 4.3s91.1 MiB [====                ] 18% 4.2s91.1 MiB [====                ] 19% 4.2s91.1 MiB [====                ] 20% 4.1s91.1 MiB [====                ] 21% 4.1s91.1 MiB [====                ] 22% 4.0s91.1 MiB [=====               ] 22% 4.0s91.1 MiB [=====               ] 23% 4.0s91.1 MiB [=====               ] 24% 3.9s91.1 MiB [=====               ] 25% 3.9s91.1 MiB [=====               ] 26% 3.8s91.1 MiB [=====               ] 27% 3.8s91.1 MiB [======              ] 27% 3.8s91.1 MiB [======              ] 28% 3.8s91.1 MiB [======              ] 28% 3.7s91.1 MiB [======              ] 29% 3.7s91.1 MiB [======              ] 30% 3.6s91.1 MiB [======              ] 31% 3.6s91.1 MiB [======              ] 32% 3.5s91.1 MiB [=======             ] 32% 3.5s91.1 MiB [=======             ] 33% 3.5s91.1 MiB [=======             ] 34% 3.4s91.1 MiB [=======             ] 35% 3.4s91.1 MiB [=======             ] 36% 3.3s91.1 MiB [=======             ] 37% 3.3s91.1 MiB [========            ] 37% 3.3s91.1 MiB [========            ] 38% 3.2s91.1 MiB [========            ] 39% 3.2s91.1 MiB [========            ] 40% 3.2s91.1 MiB [========            ] 40% 3.1s91.1 MiB [========            ] 41% 3.1s91.1 MiB [========            ] 41% 3.0s91.1 MiB [========            ] 42% 3.0s91.1 MiB [=========           ] 42% 3.0s91.1 MiB [=========           ] 43% 3.0s91.1 MiB [=========           ] 44% 2.9s91.1 MiB [=========           ] 45% 2.9s91.1 MiB [=========           ] 45% 2.8s91.1 MiB [=========           ] 46% 2.8s91.1 MiB [=========           ] 47% 2.8s91.1 MiB [==========          ] 47% 2.8s91.1 MiB [==========          ] 47% 2.7s91.1 MiB [==========          ] 48% 2.7s91.1 MiB [==========          ] 49% 2.7s91.1 MiB [==========          ] 49% 2.6s91.1 MiB [==========          ] 50% 2.6s91.1 MiB [==========          ] 51% 2.6s91.1 MiB [==========          ] 51% 2.5s91.1 MiB [==========          ] 52% 2.5s91.1 MiB [===========         ] 52% 2.5s91.1 MiB [===========         ] 53% 2.5s91.1 MiB [===========         ] 53% 2.4s91.1 MiB [===========         ] 54% 2.4s91.1 MiB [===========         ] 55% 2.4s91.1 MiB [===========         ] 55% 2.3s91.1 MiB [===========         ] 56% 2.3s91.1 MiB [===========         ] 57% 2.3s91.1 MiB [============        ] 57% 2.2s91.1 MiB [============        ] 58% 2.2s91.1 MiB [============        ] 59% 2.1s91.1 MiB [============        ] 60% 2.1s91.1 MiB [============        ] 61% 2.1s91.1 MiB [============        ] 61% 2.0s91.1 MiB [============        ] 62% 2.0s91.1 MiB [=============       ] 62% 2.0s91.1 MiB [=============       ] 63% 1.9s91.1 MiB [=============       ] 64% 1.9s91.1 MiB [=============       ] 65% 1.8s91.1 MiB [=============       ] 66% 1.8s91.1 MiB [=== ...
# Chrome Headless Shell 145.0.7632.6 (playwright chromium-headless-shell v1208) downloaded to /Users/gvera/Library/Caches/ms-playwright/chromium_headless_shell-1208
# [COMPLETE] ● Playwright installation completed successfully.
# [INIT].... → Installing Patchright browsers for undetected mode...
# Downloading Chrome for Testing 145.0.7632.6 (playwright chromium v1208) from https://cdn.playwright.dev/chrome-for-testing-public/145.0.7632.6/mac-arm64/chrome-mac-arm64.zip
# (node:16458) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# 162.3 MiB [                    ] 0% 0.0s162.3 MiB [                    ] 0% 122.4s162.3 MiB [                    ] 0% 138.7s162.3 MiB [                    ] 0% 143.4s162.3 MiB [                    ] 0% 102.7s162.3 MiB [                    ] 0% 81.1s162.3 MiB [                    ] 0% 69.7s162.3 MiB [                    ] 0% 55.0s162.3 MiB [                    ] 0% 40.0s162.3 MiB [                    ] 0% 29.5s162.3 MiB [                    ] 0% 23.5s162.3 MiB [                    ] 1% 16.8s162.3 MiB [                    ] 1% 14.3s162.3 MiB [                    ] 2% 11.5s162.3 MiB [                    ] 2% 9.9s162.3 MiB [=                   ] 2% 9.8s162.3 MiB [=                   ] 2% 9.7s162.3 MiB [=                   ] 3% 9.6s162.3 MiB [=                   ] 3% 9.5s162.3 MiB [=                   ] 3% 12.3s162.3 MiB [=                   ] 4% 13.8s162.3 MiB [=                   ] 4% 13.5s162.3 MiB [=                   ] 4% 12.1s162.3 MiB [=                   ] 6% 9.8s162.3 MiB [=                   ] 6% 9.0s162.3 MiB [=                   ] 7% 9.0s162.3 MiB [=                   ] 7% 8.9s162.3 MiB [==                  ] 7% 8.9s162.3 MiB [==                  ] 8% 8.9s162.3 MiB [==                  ] 8% 8.8s162.3 MiB [==                  ] 8% 8.7s162.3 MiB [==                  ] 9% 8.7s162.3 MiB [==                  ] 9% 8.6s162.3 MiB [==                  ] 10% 8.6s162.3 MiB [==                  ] 10% 8.5s162.3 MiB [==                  ] 11% 8.5s162.3 MiB [==                  ] 11% 8.4s162.3 MiB [==                  ] 12% 8.4s162.3 MiB [===                 ] 12% 8.4s162.3 MiB [===                 ] 12% 8.3s162.3 MiB [===                 ] 13% 8.3s162.3 MiB [===                 ] 13% 8.2s162.3 MiB [===                 ] 14% 8.2s162.3 MiB [===                 ] 14% 8.1s162.3 MiB [===                 ] 15% 8.1s162.3 MiB [===                 ] 15% 8.0s162.3 MiB [===                 ] 16% 8.0s162.3 MiB [===                 ] 16% 7.9s162.3 MiB [===                 ] 17% 7.9s162.3 MiB [====                ] 17% 7.8s162.3 MiB [====                ] 18% 7.8s162.3 MiB [====                ] 18% 7.7s162.3 MiB [====                ] 19% 7.7s162.3 MiB [====                ] 19% 7.6s162.3 MiB [====                ] 20% 7.6s162.3 MiB [====                ] 20% 7.5s162.3 MiB [====                ] 21% 7.5s162.3 MiB [====                ] 21% 7.4s162.3 MiB [====                ] 22% 7.4s162.3 MiB [=====               ] 22% 7.4s162.3 MiB [=====               ] 22% 7.3s162.3 MiB [=====               ] 23% 7.3s162.3 MiB [=====               ] 23% 7.2s162.3 MiB [=====               ] 24% 7.2s162.3 MiB [=====               ] 24% 7.1s162.3 MiB [=====               ] 25% 7.1s162.3 MiB [=====               ] 25% 7.0s162.3 MiB [=====               ] 26% 7.0s162.3 MiB [=====               ] 26% 6.9s162.3 MiB [=====               ] 27% 6.9s162.3 MiB [======              ] 27% 6.9s162.3 MiB [======              ] 27% 6.8s162.3 MiB [======              ] 28% 6.8s162.3 MiB [======              ] 28% 6.7s162.3 MiB [======              ] 29% 6.7s162.3 MiB [======              ] 29% 6.6s162.3 MiB [======              ] 30% 6.6s162.3 MiB [======              ] 30% 6.5s162.3 MiB [======              ] 31% 6.5s162.3 MiB [======              ] 31% 6.4s162.3 MiB [======              ] 32% 6.4s162.3 MiB [=======             ] 32% 6.4s162.3 MiB [=======             ] 33% 6.3s162.3 MiB [=======             ] 34% 6.2s162.3 MiB [=======             ] 34% 6.5s162.3 MiB [=======             ] 35% 6.3s162.3 MiB [=======             ] 36% 6.0s162.3 MiB [=======             ] 37% 6.0s162.3 MiB [=======             ] 37% 5.9s162.3 MiB [========            ] 37% 5.9s162.3 MiB [========            ] 38% 5.9s162.3 MiB [========            ] 38% 5.8s162.3 MiB [========            ] 39% 5.8s162.3 MiB [========            ] 39% 5.7s162.3 MiB [========            ] 40% 5.7s162.3 MiB [========            ] 40% 5.6s162.3 MiB [========            ] 41% 5.6s162.3 MiB [========            ] 41 ...
# Chrome for Testing 145.0.7632.6 (playwright chromium v1208) downloaded to /Users/gvera/Library/Caches/ms-playwright/chromium-1208
# Downloading FFmpeg (playwright ffmpeg v1011) from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-mac-arm64.zip
# (node:16460) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# 1 MiB [                    ] 0% 0.0s1 MiB [=                   ] 4% 0.8s1 MiB [==                  ] 8% 0.6s1 MiB [==                  ] 11% 0.6s1 MiB [====                ] 21% 0.4s1 MiB [=====               ] 27% 0.3s1 MiB [========            ] 37% 0.2s1 MiB [===========         ] 56% 0.1s1 MiB [===============     ] 77% 0.1s1 MiB [====================] 100% 0.0s
# FFmpeg (playwright ffmpeg v1011) downloaded to /Users/gvera/Library/Caches/ms-playwright/ffmpeg-1011
# Downloading Chrome Headless Shell 145.0.7632.6 (playwright chromium-headless-shell v1208) from https://cdn.playwright.dev/chrome-for-testing-public/145.0.7632.6/mac-arm64/chrome-headless-shell-mac-arm64.zip
# (node:16461) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# 91.1 MiB [                    ] 0% 0.0s91.1 MiB [                    ] 0% 76.9s91.1 MiB [                    ] 0% 81.7s91.1 MiB [                    ] 0% 85.1s91.1 MiB [                    ] 0% 59.4s91.1 MiB [                    ] 0% 53.5s91.1 MiB [                    ] 0% 45.8s91.1 MiB [                    ] 0% 39.7s91.1 MiB [                    ] 0% 32.1s91.1 MiB [                    ] 0% 23.9s91.1 MiB [                    ] 0% 20.3s91.1 MiB [                    ] 1% 15.0s91.1 MiB [                    ] 1% 11.6s91.1 MiB [                    ] 2% 9.6s91.1 MiB [=                   ] 2% 8.6s91.1 MiB [=                   ] 4% 6.6s91.1 MiB [=                   ] 4% 5.8s91.1 MiB [=                   ] 5% 5.7s91.1 MiB [=                   ] 5% 5.6s91.1 MiB [=                   ] 6% 5.6s91.1 MiB [=                   ] 6% 5.5s91.1 MiB [=                   ] 6% 5.4s91.1 MiB [=                   ] 7% 6.9s91.1 MiB [=                   ] 7% 7.8s91.1 MiB [==                  ] 9% 5.8s91.1 MiB [==                  ] 10% 5.4s91.1 MiB [==                  ] 12% 4.9s91.1 MiB [===                 ] 12% 4.9s91.1 MiB [===                 ] 13% 4.9s91.1 MiB [===                 ] 13% 4.8s91.1 MiB [===                 ] 14% 4.8s91.1 MiB [===                 ] 14% 4.7s91.1 MiB [===                 ] 15% 4.7s91.1 MiB [===                 ] 15% 4.6s91.1 MiB [===                 ] 16% 4.6s91.1 MiB [===                 ] 17% 4.6s91.1 MiB [===                 ] 17% 4.5s91.1 MiB [====                ] 17% 4.5s91.1 MiB [====                ] 18% 4.5s91.1 MiB [====                ] 19% 4.4s91.1 MiB [====                ] 20% 4.4s91.1 MiB [====                ] 20% 4.3s91.1 MiB [====                ] 21% 4.3s91.1 MiB [====                ] 22% 4.2s91.1 MiB [=====               ] 22% 4.2s91.1 MiB [=====               ] 23% 4.2s91.1 MiB [=====               ] 23% 4.1s91.1 MiB [=====               ] 24% 4.1s91.1 MiB [=====               ] 25% 4.1s91.1 MiB [=====               ] 25% 4.0s91.1 MiB [=====               ] 26% 4.0s91.1 MiB [=====               ] 27% 4.0s91.1 MiB [=====               ] 27% 3.9s91.1 MiB [======              ] 27% 3.9s91.1 MiB [======              ] 28% 3.9s91.1 MiB [======              ] 29% 3.8s91.1 MiB [======              ] 30% 3.8s91.1 MiB [======              ] 31% 3.7s91.1 MiB [======              ] 32% 3.7s91.1 MiB [=======             ] 32% 3.6s91.1 MiB [=======             ] 33% 3.6s91.1 MiB [=======             ] 34% 3.6s91.1 MiB [=======             ] 34% 3.5s91.1 MiB [=======             ] 35% 3.5s91.1 MiB [=======             ] 36% 3.4s91.1 MiB [=======             ] 37% 3.4s91.1 MiB [========            ] 37% 3.4s91.1 MiB [========            ] 37% 3.3s91.1 MiB [========            ] 38% 3.3s91.1 MiB [========            ] 39% 3.3s91.1 MiB [========            ] 39% 3.2s91.1 MiB [========            ] 40% 3.2s91.1 MiB [========            ] 41% 3.2s91.1 MiB [========            ] 41% 3.1s91.1 MiB [========            ] 42% 3.1s91.1 MiB [=========           ] 42% 3.1s91.1 MiB [=========           ] 43% 3.1s91.1 MiB [=========           ] 43% 3.0s91.1 MiB [=========           ] 44% 3.0s91.1 MiB [=========           ] 45% 2.9s91.1 MiB [=========           ] 46% 2.9s91.1 MiB [=========           ] 46% 2.8s91.1 MiB [=========           ] 47% 2.8s91.1 MiB [==========          ] 47% 2.8s91.1 MiB [==========          ] 48% 2.8s91.1 MiB [==========          ] 48% 2.7s91.1 MiB [==========          ] 49% 2.7s91.1 MiB [==========          ] 50% 2.7s91.1 MiB [==========          ] 50% 2.6s91.1 MiB [==========          ] 51% 2.6s91.1 MiB [==========          ] 52% 2.6s91.1 MiB [===========         ] 52% 2.5s91.1 MiB [===========         ] 53% 2.5s91.1 MiB [===========         ] 54% 2.5s91.1 MiB [===========         ] 54% 2.4s91.1 MiB [===========         ] 55% 2.4s91.1 MiB [===========         ] 56% 2.3s91.1 MiB [===========         ] 57% 2.3s91.1 MiB [============        ] 57% 2.3s91.1 MiB [============        ] 58% 2.2s91.1 MiB [=== ...
# Chrome Headless Shell 145.0.7632.6 (playwright chromium-headless-shell v1208) downloaded to /Users/gvera/Library/Caches/ms-playwright/chromium_headless_shell-1208
# [COMPLETE] ● Patchright installation completed successfully.
# [INIT].... → Starting database initialization...
# [COMPLETE] ● Database initialization completed successfully.
# [COMPLETE] ● Post-installation setup completed!

# %%
# !pip install nest_asyncio --quiet

# %%
import nest_asyncio
nest_asyncio.apply()

import asyncio
from crawl4ai import AsyncWebCrawler
from crawl4ai.async_configs import BrowserConfig, CrawlerRunConfig
# from crawl4ai.markdown_generation_strategy import DefaultMarkdownGenerator

browser_conf = BrowserConfig(verbose=False,headless=True)

# Option 1: Use the raw HTML directly from the webpage (before any processing)
# raw_md_generator = DefaultMarkdownGenerator(
#     content_source="raw_html",
#     options={"ignore_links": False}
# )

run_cfg = CrawlerRunConfig(
    wait_until="domcontentloaded",
    wait_for_images=True,
    scan_full_page=True,
    verbose=False,
    # markdown_generator=raw_md_generator
)

async def async_scrape_crawl4ai(url: str, to_markdown: bool = False) -> str:
    crawler = AsyncWebCrawler(config=browser_conf)
    await crawler.start()
    result = await crawler.arun(
        url=url,
        config=run_cfg,
    )

    if not to_markdown:
        return result.html
    
    return result.markdown
    # # Convert HTML to Markdown
    # # Get all the images
    # images = result.media.get("images", [])
    # images_list = f"\n\nImages found:{len(images)}"
    # for i, img in enumerate(images):
    #     images_list = images_list + f"\n - ![Image {i+1}: {img.get('alt','No description')}]({img.get('src','')})"
    #     # Example: - ![Image 1: Alt text](https://example.com/image1.jpg)
    
    # return result.markdown + images_list

# To run the async function in a synchronous context
# (like this script), you can use asyncio.run() to execute it.
# This is a workaround for running async functions in a sync context.
def scrape_crawl4ai(url: str, to_markdown: bool = False):
    return asyncio.run(async_scrape_crawl4ai(url, to_markdown))

# print(scrape_crawl4ai("https://www.uv.mx", to_markdown=True))

# %% [markdown]
# ## Main functions to run the comparasion with HTML
#
# Let's run all the scrapers and display them in our comparison table.

# %%
list_of_scraper_functions = [
      {"name": "Beautiful Soup", "function": beautiful_soup_scrape_url},
      {"name": "Jina AI", "function": scrape_jina_ai},
      {"name": "Crawl4ai", "function": scrape_crawl4ai},
]

all_content_html = view_scraped_content(list_of_scraper_functions, test_sites, 35000, 120, to_markdown=False)
# Out:
# Processing site Site 1 using Beautiful Soup:   0%|          | 0/1 [00:00<?, ?it/s]
# /Users/gvera/codigo/doctorado/04.model-springer/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webtestingcourse.dequecloud.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Processing site Site 1 using Jina AI:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 1 using Crawl4ai:   0%|          | 0/1 [00:00<?, ?it/s]
# Content Table:
# +-----------+--------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------+
# | Site Name |                                                  Beautiful Soup content                                                  |                                                     Jina AI content                                                      |                                                     Crawl4ai content                                                     |
# +-----------+--------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------+
# |   Site 1  |                                               6,520 characters retrieved:                                                |                                               6,842 characters retrieved:                                                |                                               7,007 characters retrieved:                                                |
# |           |                                                                                                                          |                                                                                                                          |                                                                                                                          |
# |           |                                                     <!DOCTYPE html>                                                      |                                                  <html lang="en"><head>                                                  |                                          <!DOCTYPE html><html lang="en"><head>                                           |
# |           |                                                                                                                          |                                                         <!--//                                                           |                                                         <!--//                                                           |
# |           |                                                     <html lang="en">                                                     |                                            Thanks for checking the source.                                               |                                            Thanks for checking the source.                                               |
# |           |                                                          <head>                                                          |                              This site has a number of intentional accessibility problems.                               |                              This site has a number of intentional accessibility problems.                               |
#                                                               |                                           Let's see if you can find them all!                                            |                                           Let's see if you can find them all!                                            |
#                                                               |                                                          //-->                                                           |                                                          //-->                                                           |
#                                                               |                                    <title>Gefälscht~~~Gefälscht CompuTech~~~</title>                                     |                                    <title>Gefälscht~~~Gefälscht CompuTech~~~</title>                                     |
#                                                               |                                     <meta name="robots" content="noindex, nofollow">                                     |                                     <meta name="robots" content="noindex, nofollow">                                     |
# |           |                                                          //-->                                                           |                                                          <!--//                                                          |                                                          <!--//                                                          |
# |           |                                    <title>Gefälscht~~~Gefälscht CompuTech~~~</title>                                     |                                  Quick snippet of javascript to make IE recognize HTML5                                  |                                  Quick snippet of javascript to make IE recognize HTML5                                  |
# |           |                                    <meta content="noindex, nofollow" name="robots"/>                                     |                                                          //-->                                                           |                                                          //-->                                                           |
#                                                               |                                                    <!--[if lt IE 9]>                                                     |                                                    <!--[if lt IE 9]>                                                     |
#                                                               |                    <script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script> <![endif]-->                    |                    <script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script> <![endif]-->                    |
# |           |                                                          //-->                                                           |                                      <link href="styles/reset.css" type="text/css">                                      |                                      <link href="styles/reset.css" type="text/css">                                      |
#                                                               |                  <script type="text/javascript" src="http://code.jquery.com/jquery-latest.js"></script>                  |                  <script type="text/javascript" src="http://code.jquery.com/jquery-latest.js"></script>                  |
# |           |                    <script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script> <![endif]-->                    |                                             <script type="text/javascript">                                              |                                             <script type="text/javascript">                                              |
# |           |                                     <link href="styles/reset.css" type="text/css"/>                                      |                                                /* jQuery snippet for row striping */                                     |                                                /* jQuery snippet for row striping */                                     |
# |           |                  <script src="http://code.jquery.com/jquery-latest.js" type="text/javascript"></script>                  |                                                    $(document).ready(function() {                                        |                                                    $(document).ready(function() {                                        |
#                                                               |                                        $('table.data_table tbody tr:odd td').addClass('odd_row');                        |                                        $('table.data_table tbody tr:odd td').addClass('odd_row');                        |
#                                                               |                                       $('table.data_table tbody tr:even td').addClass('even_row');                       |                                       $('table.data_table tbody tr:even td').addClass('even_row');                       |
#                                                               |                                                                 });                                                      |                                                                 });                                                      |
#                                                               |                                                            </script>                                                     |                                                            </script>                                                     |
#                                                               |                                                  <meta charset="utf-8">                                                  |                                                  <meta charset="utf-8">                                                  |
#                                                               |                             <link rel="stylesheet" href="styles/layout.css" type="text/css">                             |                             <link rel="stylesheet" href="styles/layout.css" type="text/css">                             |
# |           |                                                            </script>                                                     |                                                 <style type="text/css">                                                  |                                                 <style type="text/css">                                                  |
# |           |                                                  <meta charset="utf-8">                                                  |                                                           /**                                                            |                                                           /**                                                            |
# |           |                            <link href="styles/layout.css" rel="stylesheet" type="text/css"/>                             |                                      * Fix poor contrast on the course asset pages                                       |                                      * Fix poor contrast on the course asset pages                                       |
#                                                               |                                                            */                                                            |                                                            */                                                            |
#                                                               |                                                     .courseAssets {                                                      |                                                     .courseAssets {                                                      |
#                                                               |                                                             	color: #000 !important;                                                              |                                                             	color: #000 !important;                                                              |
#                                                               |                                                            }                                                             |                                                            }                                                             |
#                                                               |                                                         </style>                                                         |                                                         </style>                                                         |
#                                                               |                                                         </head>                                                          |                                                         </head>                                                          |
#                                                               |                                                     <body id="top">                                                      |                                                     <body id="top">                                                      |
# |           |                                                         </style>                                                         |                                                  <div class="wrapper">                                                   |                                                  <div class="wrapper">                                                   |
# |           |                                                      </meta></head>                                                      |                                                    <div id="header">                                                     |                                                    <div id="header">                                                     |
# |           |                                                     <body id="top">                                                      |                                                   <div class="fl_left">                                                  |                                                   <div class="fl_left">                                                  |
# |           |                                                  <div class="wrapper">                                                   |                                              <h1><a href="/">Gefälscht</a></h1>                                          |                                              <h1><a href="/">Gefälscht</a></h1>                                          |
# |           |                                                    <div id="header">                                                     |                                                  <p>Gefälscht CompuTech</p>                                              |                                                  <p>Gefälscht CompuTech</p>                                              |
# |           |                                                  <div class="fl_left">                                                   |                                                           </div>                                                         |                                                           </div>                                                         |
# |           |                                            <h1><a href="/">Gefälscht</a></h1>                                            |                                                     <br class="clear">                                                   |                                                     <br class="clear">                                                   |
# |           |                                                <p>Gefälscht CompuTech</p>                                                |                                                          </div>                                                          |                                                          </div>                                                          |
# |           |                                                          </div>                                                          |                                                    <div id="topbar">                                                     |                                                    <div id="topbar">                                                     |
# |           |                                                   <br class="clear"/>                                                    |                                                   <div class="fl_left">                                                  |                                                   <div class="fl_left">                                                  |
# |           |                                                          </div>                                                          |                                       <p>Tel: 703-555-1212 | Mail: info@deque.com</p>                                    |                                       <p>Tel: 703-555-1212 | Mail: info@deque.com</p>                                    |
# |           |                                                    <div id="topbar">                                                     |                                           <form action="search.php" method="get">                                        |                                           <form action="search.php" method="get">                                        |
# |           |                                                  <div class="fl_left">                                                   |                                                           <fieldset>                                                     |                                                           <fieldset>                                                     |
# |           |                                     <p>Tel: 703-555-1212 | Mail: info@deque.com</p>                                      |                                                   <legend>Site Search</legend>                                           |                                                   <legend>Site Search</legend>                                           |
# |           |                                         <form action="search.php" method="get">                                          |         <input type="text" name="q" value="Search the site…" onfocus="this.value=(this.value=='Search the site…')? '' :  |         <input type="text" name="q" value="Search the site…" onfocus="this.value=(this.value=='Search the site…')? '' :  |
# |           |                                                        <fieldset>                                                        |                                                      this.value ;">                                                      |                                                      this.value ;">                                                      |
# |           |                                               <legend>Site Search</legend>                                               |                                        <input type="submit" name="go" id="go" value="GO">                                |                                        <input type="submit" name="go" id="go" value="GO">                                |
# |           |  <input name="q" onfocus="this.value=(this.value=='Search the site…')? '' : this.value ;" type="text" value="Search the  |                                                          </fieldset>                                                     |                                                          </fieldset>                                                     |
# |           |                                                         site…"/>                                                         |                                                           </form>                                                        |                                                           </form>                                                        |
# |           |                                   <input id="go" name="go" type="submit" value="GO"/>                                    |                                                           </div>                                                         |                                                           </div>                                                         |
# |           |                                                       </fieldset>                                                        |                                                     <div id="topnav">                                                    |                                                     <div id="topnav">                                                    |
# |           |                                                         </form>                                                          |        <ul><li class="active"><a href="/index.php">Home</a></li><li><a href="/laptopsandnotebooks.php">Laptops &amp;     |        <ul><li class="active"><a href="/index.php">Home</a></li><li><a href="/laptopsandnotebooks.php">Laptops &amp;     |
# |           |                                                          </div>                                                          |        Notebooks</a></li><li><a href="/desktops.php">Desktops</a></li><li><a href="/cart.php">Cart</a></li><li><a        |        Notebooks</a></li><li><a href="/desktops.php">Desktops</a></li><li><a href="/cart.php">Cart</a></li><li><a        |
# |           |                                                    <div id="topnav">                                                     |       href="/support.php">Support</a></li><li class=" last "><a href="/contact.php">Contact</a></li></ul>  </div>        |       href="/support.php">Support</a></li><li class=" last "><a href="/contact.php">Contact</a></li></ul>  </div>        |
# |           |      <ul><li class="active"><a href="/index.php">Home</a></li><li><a href="/laptopsandnotebooks.php">Laptops &amp;       |                                                     <br class="clear">                                                   |                                                     <br class="clear">                                                   |
# |           |        Notebooks</a></li><li><a href="/desktops.php">Desktops</a></li><li><a href="/cart.php">Cart</a></li><li><a        |                                                          </div>                                                          |                                                          </div>                                                          |
# |           |         href="/support.php">Support</a></li><li class="last"><a href="/contact.php">Contact</a></li></ul> </div>         |                                                                                                                          |                                                                                                                          |
# |           |                                                   <br class="clear"/>                                                    |                                                     <div id="intro">                                                     |                                                     <div id="intro">                                                     |
# |           |                                                          </div>                                                          |                         <div class="fl_left"><img src="images/site/homeLanding.jpg" alt=""></div>                        |             <div class="fl_left"><img src="images/site/homeLanding.jpg" alt="" width="360" height="330"></div>           |
# |           |                                                     <div id="intro">                                                     |                                                   <div class="fl_right">                                                 |                                                   <div class="fl_right">                                                 |
# |           |                        <div class="fl_left"><img alt="" src="images/site/homeLanding.jpg"/></div>                        |                                           <h3>Welcome to Gefälscht CompuTech</h3>                                        |                                           <h3>Welcome to Gefälscht CompuTech</h3>                                        |
# |           |                                                  <div class="fl_right">                                                  |         <p><em>Gefälscht</em> - German for "Fake". This is a fake website, created by Deque Systems, for use during      |         <p><em>Gefälscht</em> - German for "Fake". This is a fake website, created by Deque Systems, for use during      |
# |           |                                         <h3>Welcome to Gefälscht CompuTech</h3>                                          |                                                        training.                                                         |                                                        training.                                                         |
# |           |  <p><em>Gefälscht</em> - German for "Fake". This is a fake website, created by Deque Systems, for use during training.   |       Our clients are pointed to this site so that we can train them using an inaccessible site without having to point  |       Our clients are pointed to this site so that we can train them using an inaccessible site without having to point  |
# |           |       Our clients are pointed to this site so that we can train them using an inaccessible site without having to point  |  to the site of a real company.  This site has a number of intentional accessibility problems. It is not an example of   |  to the site of a real company.  This site has a number of intentional accessibility problems. It is not an example of   |
# |           |  to the site of a real company.  This site has a number of intentional accessibility problems. It is not an example of   |   how to do things but rather how <strong>not</strong> to do them. If you're interested in knowing how you can make an   |   how to do things but rather how <strong>not</strong> to do them. If you're interested in knowing how you can make an   |
# |           |   how to do things but rather how <strong>not</strong> to do them. If you're interested in knowing how you can make an   |   accessible website, need help making your website accessible, or want to have your website tested for accessibility,   |   accessible website, need help making your website accessible, or want to have your website tested for accessibility,   |
# |           |   accessible website, need help making your website accessible, or want to have your website tested for accessibility,   |                   please <a href="http://www.deque.com" target="_blank">contact Deque Systems</a>.</p>                   |                   please <a href="http://www.deque.com" target="_blank">contact Deque Systems</a>.</p>                   |
# |           |                   please <a href="http://www.deque.com" target="_blank">contact Deque Systems</a>.</p>                   |                                                           </div>                                                         |                                                           </div>                                                         |
# |           |                                                          </div>                                                          |                                                     <br class="clear">                                                   |                                                     <br class="clear">                                                   |
# |           |                                                   <br class="clear"/>                                                    |                                                          </div>                                                          |                                                          </div>                                                          |
# |           |                                                          </div>                                                          |                                                  <div id="homecontent">                                                  |                                                  <div id="homecontent">                                                  |
# |           |                                                  <div id="homecontent">                                                  |                                                            <ul>                                                          |                                                            <ul>                                                          |
# |           |                                                           <ul>                                                           |                                                             <li>                                                         |                                                             <li>                                                         |
# |           |                                                           <li>                                                           |                                                  <h2>Parts and Supplies</h2>                                             |                                                  <h2>Parts and Supplies</h2>                                             |
# |           |                                               <h2>Parts and Supplies</h2>                                                |                                       <img class="imgl" src="images/site/small60-1.jpg">                                 |                                       <img class="imgl" src="images/site/small60-1.jpg">                                 |
# |           |                                   <img class="imgl" src="images/site/small60-1.jpg"/>                                    |       <p>We sell parts and supplies for every computer we sell and even some that we don't.  If we don't have a part, it |       <p>We sell parts and supplies for every computer we sell and even some that we don't.  If we don't have a part, it |
# |           |    <p>We sell parts and supplies for every computer we sell and even some that we don't.  If we don't have a part, it    |  doesn't exist. If it does exist and we don't have it, we'll get it.  If we can't get it, we'll steal it. That's how we  |  doesn't exist. If it does exist and we don't have it, we'll get it.  If we can't get it, we'll steal it. That's how we  |
# |           |  doesn't exist. If it does exist and we don't have it, we'll get it.  If we can't get it, we'll steal it. That's how we  |                                                        roll.</p>                                                         |                                                        roll.</p>                                                         |
# |           |                                                        roll.</p>                                                         |                              <p class="readmore"><a href="support.php">Continue Reading »</a></p>                        |                              <p class="readmore"><a href="support.php">Continue Reading »</a></p>                        |
# |           |                           <p class="readmore"><a href="support.php">Continue Reading »</a></p>                           |                                                            </li>                                                         |                                                            </li>                                                         |
# |           |                                                          </li>                                                           |                                                             <li>                                                         |                                                             <li>                                                         |
# |           |                                                           <li>                                                           |                                          <h2>Visit our Brick &amp; Mortar Store</h2>                                     |                                          <h2>Visit our Brick &amp; Mortar Store</h2>                                     |
# |           |                                       <h2>Visit our Brick &amp; Mortar Store</h2>                                        |                                       <img class="imgl" src="images/site/small60-2.jpg">                                 |                                       <img class="imgl" src="images/site/small60-2.jpg">                                 |
# |           |                                   <img class="imgl" src="images/site/small60-2.jpg"/>                                    |         <p>Look at that picture.  Isn't it great? Want a bigger version? Go to <a href="contact.php">this page</a> and   |         <p>Look at that picture.  Isn't it great? Want a bigger version? Go to <a href="contact.php">this page</a> and   |
# |           |  <p>Look at that picture.  Isn't it great? Want a bigger version? Go to <a href="contact.php">this page</a> and take a   |   take a closer look. Our opulently appointed corporate offices are located in the finest strip mall within miles. We    |   take a closer look. Our opulently appointed corporate offices are located in the finest strip mall within miles. We    |
# |           |    closer look. Our opulently appointed corporate offices are located in the finest strip mall within miles. We think    |  think you'll agree that our place is the place among places when you think of a place that does our sort of thing.</p>  |  think you'll agree that our place is the place among places when you think of a place that does our sort of thing.</p>  |
# |           |     you'll agree that our place is the place among places when you think of a place that does our sort of thing.</p>     |                              <p class="readmore"><a href="contact.php">Continue Reading »</a></p>                        |                              <p class="readmore"><a href="contact.php">Continue Reading »</a></p>                        |
# |           |                           <p class="readmore"><a href="contact.php">Continue Reading »</a></p>                           |                                                            </li>                                                         |                                                            </li>                                                         |
# |           |                                                          </li>                                                           |                                                      <li class="last">                                                   |                                                      <li class="last">                                                   |
# |           |                                                    <li class="last">                                                     |                                               <h2>In Home Computer Service</h2>                                          |                                               <h2>In Home Computer Service</h2>                                          |
# |           |                                            <h2>In Home Computer Service</h2>                                             |                                       <img class="imgl" src="images/site/small60-3.jpg">                                 |                                       <img class="imgl" src="images/site/small60-3.jpg">                                 |
# |           |                                   <img class="imgl" src="images/site/small60-3.jpg"/>                                    |         <p>You don't like our place?  Then we'll come to your place. We can fix your stuff in your home for a sizeable   |         <p>You don't like our place?  Then we'll come to your place. We can fix your stuff in your home for a sizeable   |
# |           |      <p>You don't like our place?  Then we'll come to your place. We can fix your stuff in your home for a sizeable      |  surcharge. We'll get there at a time that is incredibly inconvenient to you and come unprepared for the task at hand.   |  surcharge. We'll get there at a time that is incredibly inconvenient to you and come unprepared for the task at hand.   |
# |           |  surcharge. We'll get there at a time that is incredibly inconvenient to you and come unprepared for the task at hand.   |                            You'll tell all your friends what great service you received!</p>                             |                            You'll tell all your friends what great service you received!</p>                             |
# |           |                            You'll tell all your friends what great service you received!</p>                             |                              <p class="readmore"><a href="support.php">Continue Reading »</a></p>                        |                              <p class="readmore"><a href="support.php">Continue Reading »</a></p>                        |
# |           |                           <p class="readmore"><a href="support.php">Continue Reading »</a></p>                           |                                                            </li>                                                         |                                                            </li>                                                         |
# |           |                                                          </li>                                                           |                                                           </ul>                                                          |                                                           </ul>                                                          |
# |           |                                                          </ul>                                                           |                                                     <br class="clear">                                                   |                                                     <br class="clear">                                                   |
# |           |                                                   <br class="clear"/>                                                    |                                                          </div>                                                          |                                                          </div>                                                          |
# |           |                                                          </div>                                                          |                                                   <div id="imageline">                                                   |                                                   <div id="imageline">                                                   |
# |           |                                                   <div id="imageline">                                                   |                                                            <ul>                                                          |                                                            <ul>                                                          |
# |           |                                                           <ul>                                                           |                          <li><a href="desktops.php"><img src="images/site/small174-1.jpg"></a></li>                      |             <li><a href="desktops.php"><img src="images/site/small174-1.jpg" width="174" height="100"></a></li>          |
# |           |                       <li><a href="desktops.php"><img src="images/site/small174-1.jpg"/></a></li>                        |                          <li><a href="desktops.php"><img src="images/site/small174-2.jpg"></a></li>                      |             <li><a href="desktops.php"><img src="images/site/small174-2.jpg" width="174" height="100"></a></li>          |
# |           |                       <li><a href="desktops.php"><img src="images/site/small174-2.jpg"/></a></li>                        |                    <li><a href="laptopsandnotebooks.php"><img src="images/site/small174-3.jpg"></a></li>                 |        <li><a href="laptopsandnotebooks.php"><img src="images/site/small174-3.jpg" width="174" height="100"></a></li>    |
# |           |                  <li><a href="laptopsandnotebooks.php"><img src="images/site/small174-3.jpg"/></a></li>                  |                  <li><a href="laptopsandnotebooks.php"><img src="images/site/small174-4.jpg" "=""></a></li>              |     <li><a href="laptopsandnotebooks.php"><img src="images/site/small174-4.jpg" "="" width="174" height="100"></a></li>  |
# |           |               <li><a href="laptopsandnotebooks.php"><img "="" src="images/site/small174-4.jpg"/></a></li>                |              <li class="last"><a href="laptopsandnotebooks.php"><img src="images/site/small174-5.jpg"></a></li>          |             <li class="last"><a href="laptopsandnotebooks.php"><img src="images/site/small174-5.jpg" width="174"         |
# |           |           <li class="last"><a href="laptopsandnotebooks.php"><img src="images/site/small174-5.jpg"/></a></li>            |                                                           </ul>                                                          |                                                  height="100"></a></li>                                                  |
# |           |                                                          </ul>                                                           |                                                     <br class="clear">                                                   |                                                           </ul>                                                          |
# |           |                                                   <br class="clear"/>                                                    |                                                          </div>                                                          |                                                     <br class="clear">                                                   |
# |           |                                                          </div>                                                          |                                                                                                                          |                                                          </div>                                                          |
# |           |                                                    <div id="footer">                                                     |                                                    <div id="footer">                                                     |                                                                                                                          |
# |           |                                                  <div class="footbox">                                                   |                                                   <div class="footbox">                                                  |                                                    <div id="footer">                                                     |
# |           |                                             <h2>Laptops &amp; Notebooks</h2>                                             |                                               <h2>Laptops &amp; Notebooks</h2>                                           |                                                   <div class="footbox">                                                  |
# |           |                                                           <ul>                                                           |                                                             <ul>                                                         |                                               <h2>Laptops &amp; Notebooks</h2>                                           |
# |           |                                      <li><a href="laptop1.php">Fregatte 17</a></li>                                      |                                         <li><a href="laptop1.php">Fregatte 17</a></li>                                   |                                                             <ul>                                                         |
# |           |                                     <li><a href="laptop2.php">Abgenutzt 15</a></li>                                      |                                        <li><a href="laptop2.php">Abgenutzt 15</a></li>                                   |                                         <li><a href="laptop1.php">Fregatte 17</a></li>                                   |
# |           |                                     <li><a href="laptop3.php">Backstein 21</a></li>                                      |                                        <li><a href="laptop3.php">Backstein 21</a></li>                                   |                                        <li><a href="laptop2.php">Abgenutzt 15</a></li>                                   |
# ...
# |           |                                    <li><a href="desktop1.php">Beschissen 750</a></li>                                    |                                       <li><a href="desktop1.php">Beschissen 750</a></li>                                 |                                                             <ul>                                                         |
# |           |                                   <li><a href="desktop2.php">Rindviecher 1000</a></li>                                   |                                      <li><a href="desktop2.php">Rindviecher 1000</a></li>                                |                                       <li><a href="desktop1.php">Beschissen 750</a></li>                                 |
# |           |                                    <li><a href="desktop3.php">Verrottet 875</a></li>                                     |                                       <li><a href="desktop3.php">Verrottet 875</a></li>                                  |                                      <li><a href="desktop2.php">Rindviecher 1000</a></li>                                |
# |           |                                                          </ul>                                                           |                                                            </ul>                                                         |                                       <li><a href="desktop3.php">Verrottet 875</a></li>                                  |
# |           |                                                          </div>                                                          |                                                           </div>                                                         |                                                            </ul>                                                         |
# |           |                                                  <div class="footbox">                                                   |                                                   <div class="footbox">                                                  |                                                           </div>                                                         |
# |           |                                              <h2>Test Course Materials</h2>                                              |                                                <h2>Test Course Materials</h2>                                            |                                                   <div class="footbox">                                                  |
# |           |                                                           <ul>                                                           |                                                             <ul>                                                         |                                                <h2>Test Course Materials</h2>                                            |
# |           |                             <li><a href="/dragoncheatsheet.php">Dragon Cheat Sheet</a></li>                              |                                <li><a href="/dragoncheatsheet.php">Dragon Cheat Sheet</a></li>                           |                                                             <ul>                                                         |
# |           |                               <li><a href="/jawscheatsheet.php">JAWS Cheat Sheet</a></li>                                |                                  <li><a href="/jawscheatsheet.php">JAWS Cheat Sheet</a></li>                             |                                <li><a href="/dragoncheatsheet.php">Dragon Cheat Sheet</a></li>                           |
# |           |                       <li><a href="/sampletestcasetemplate.php">Sample Test Case Template</a></li>                       |                          <li><a href="/sampletestcasetemplate.php">Sample Test Case Template</a></li>                    |                                  <li><a href="/jawscheatsheet.php">JAWS Cheat Sheet</a></li>                             |
# |           |                          <li><a href="/sampleissuetemplate.php">Sample Issue Template</a></li>                           |                             <li><a href="/sampleissuetemplate.php">Sample Issue Template</a></li>                        |                          <li><a href="/sampletestcasetemplate.php">Sample Test Case Template</a></li>                    |
# |           |            <li><span class="pseudolink" onclick="location.href='/photocredits.php'">Photo Credits</span></li>            |               <li><span class="pseudolink" onclick="location.href='/photocredits.php'">Photo Credits</span></li>         |                             <li><a href="/sampleissuetemplate.php">Sample Issue Template</a></li>                        |
# |           |                                                          </ul>                                                           |                                                            </ul>                                                         |               <li><span class="pseudolink" onclick="location.href='/photocredits.php'">Photo Credits</span></li>         |
# |           |                                                          </div>                                                          |                                                           </div>                                                         |                                                            </ul>                                                         |
# |           |                                                  <div class="footbox">                                                   |                                                   <div class="footbox">                                                  |                                                           </div>                                                         |
# |           |                                                      <h2>Cart</h2>                                                       |                                                        <h2>Cart</h2>                                                     |                                                   <div class="footbox">                                                  |
# |           |                                                           <ul>                                                           |                                                             <ul>                                                         |                                                        <h2>Cart</h2>                                                     |
# |           |   <li><a href="cart.php">Lookee here! Just in case you didn't notice the 'Cart' link in the global navigation, you can   |        <li><a href="cart.php">Lookee here! Just in case you didn't notice the 'Cart' link in the global navigation, you  |                                                             <ul>                                                         |
# |           |                            also find a link to your cart down here, too.  Neat, huh?</a></li>                            |                          can also find a link to your cart down here, too.  Neat, huh?</a></li>                          |        <li><a href="cart.php">Lookee here! Just in case you didn't notice the 'Cart' link in the global navigation, you  |
# |           |                                                          </ul>                                                           |                                                            </ul>                                                         |                          can also find a link to your cart down here, too.  Neat, huh?</a></li>                          |
# |           |                                                          </div>                                                          |                                                           </div>                                                         |                                                            </ul>                                                         |
# |           |                                                <div class="footbox last">                                                |                                                 <div class="footbox last">                                               |                                                           </div>                                                         |
# |           |                                                     <h2>Support</h2>                                                     |                                                       <h2>Support</h2>                                                   |                                                 <div class="footbox last">                                               |
# |           |                                                           <ul>                                                           |                                                             <ul>                                                         |                                                       <h2>Support</h2>                                                   |
# |           |  <li><a href="support.php">Get answers to all of your favorite support questions here, including such gems as "Where is  |          <li><a href="support.php">Get answers to all of your favorite support questions here, including such gems as    |                                                             <ul>                                                         |
# |           |                        my 'Any' key?" and "How many pins does a sixteen pin cable have?"</a></li>                        |                   "Where is my 'Any' key?" and "How many pins does a sixteen pin cable have?"</a></li>                   |          <li><a href="support.php">Get answers to all of your favorite support questions here, including such gems as    |
# |           |                                                          </ul>                                                           |                                                            </ul>                                                         |                   "Where is my 'Any' key?" and "How many pins does a sixteen pin cable have?"</a></li>                   |
# |           |                                                          </div>                                                          |                                                           </div>                                                         |                                                            </ul>                                                         |
# |           |                                                   <br class="clear"/>                                                    |                                                     <br class="clear">                                                   |                                                           </div>                                                         |
# |           |                                                          </div>                                                          |                                                          </div>                                                          |                                                     <br class="clear">                                                   |
# |           |                                                   <div id="copyright">                                                   |                                                   <div id="copyright">                                                   |                                                          </div>                                                          |
# |           |                <p class="fl_left">Copyright © 2026 - All Rights Reserved - <a href="/">Gefälscht</a></p>                 |                 <p class="fl_left">Copyright © 2026 - All Rights Reserved - <a href="/">Gefälscht</a></p>                |                                                   <div id="copyright">                                                   |
# |           |                                       <p class="fl_right">Gefälscht CompuTech</p>                                        |                                        <p class="fl_right">Gefälscht CompuTech</p>                                       |                 <p class="fl_left">Copyright © 2026 - All Rights Reserved - <a href="/">Gefälscht</a></p>                |
# |           |                                                   <br class="clear"/>                                                    |                                                     <br class="clear">                                                   |                                        <p class="fl_right">Gefälscht CompuTech</p>                                       |
# |           |                                                          </div>                                                          |                                                          </div>                                                          |                                                     <br class="clear">                                                   |
# |           |                                                   <br class="clear"/>                                                    |                                                    <br class="clear">                                                    |                                                          </div>                                                          |
# |           |                                                          </div>                                                          |                                                          </div>                                                          |                                                    <br class="clear">                                                    |
# |           |                                                      </body></html>                                                      |                                                      </body></html>                                                      |                                                          </div>                                                          |
# |           |                                                                                                                          |                                                                                                                          |                                                      </body></html>                                                      |
# +-----------+--------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# ## Comparison using Markdown
#
# We will run all scrapers again, this time retrieving output in a format more suitable for LLMs.

# %%
all_content_md = view_scraped_content(list_of_scraper_functions, test_sites, 35000, 120, to_markdown=True)
# Out:
# Processing site Site 1 using Beautiful Soup:   0%|          | 0/1 [00:00<?, ?it/s]
# /Users/gvera/codigo/doctorado/04.model-springer/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webtestingcourse.dequecloud.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Processing site Site 1 using Jina AI:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 1 using Crawl4ai:   0%|          | 0/1 [00:00<?, ?it/s]
# Content Table:
# +-----------+--------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------+
# | Site Name |                                                  Beautiful Soup content                                                  |                                                     Jina AI content                                                      |                                                     Crawl4ai content                                                     |
# +-----------+--------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------+
# |   Site 1  |                                               3,479 characters retrieved:                                                |                                               5,870 characters retrieved:                                                |                                               4,868 characters retrieved:                                                |
# |           |                                                                                                                          |                                                                                                                          |                                                                                                                          |
# |           |                                            Gefälscht~~~Gefälscht CompuTech~~~                                            |                                            Gefälscht~~~Gefälscht CompuTech~~~                                            |                                 # [Gefälscht](https://webtestingcourse.dequecloud.com/)                                  |
# |           |                                                                                                                          |                                                     ===============                                                      |                                                   Gefälscht CompuTech                                                    |
# |           |                                                                                                                          |                                                                                                                          |                                                                                                                          |
# |           |                                                                                                                          |                                  [Gefälscht](https://webtestingcourse.dequecloud.com/)                                   |                                                                                                                          |
# |           |                                                      [Gefälscht](/)                                                      |                                  =====================================================                                   |                                         Tel: 703-555-1212 | Mail: info@deque.com                                         |
# |           |                                                      ==============                                                      |                                                                                                                          |                                                       Site Search                                                        |
# |           |                                                                                                                          |                                                   Gefälscht CompuTech                                                    |                                * [Home](https://webtestingcourse.dequecloud.com/index.php)                               |
# |           |                                                   Gefälscht CompuTech                                                    |                                                                                                                          |                  * [Laptops & Notebooks](https://webtestingcourse.dequecloud.com/laptopsandnotebooks.php)                |
# |           |                                                                                                                          |                                         Tel: 703-555-1212 | Mail: info@deque.com                                         |                             * [Desktops](https://webtestingcourse.dequecloud.com/desktops.php)                           |
# |           |                                         Tel: 703-555-1212 | Mail: info@deque.com                                         |                                                                                                                          |                                 * [Cart](https://webtestingcourse.dequecloud.com/cart.php)                               |
# |           |                                                                                                                          |                                                       Site Search                                                        |                              * [Support](https://webtestingcourse.dequecloud.com/support.php)                            |
# |           |                                                       Site Search                                                        |                                                                                                                          |                              * [Contact](https://webtestingcourse.dequecloud.com/contact.php)                            |
# |           |                                                                                                                          |                              *   [Home](https://webtestingcourse.dequecloud.com/index.php)                               |                                                                                                                          |
# |           |                                                   * [Home](/index.php)                                                   |                *   [Laptops & Notebooks](https://webtestingcourse.dequecloud.com/laptopsandnotebooks.php)                |                                                                                                                          |
# |           |                                    * [Laptops & Notebooks](/laptopsandnotebooks.php)                                     |                           *   [Desktops](https://webtestingcourse.dequecloud.com/desktops.php)                           |                                                                                                                          |
# |           |                                               * [Desktops](/desktops.php)                                                |                               *   [Cart](https://webtestingcourse.dequecloud.com/cart.php)                               |                                                                                                                          |
# |           |                                                   * [Cart](/cart.php)                                                    |                            *   [Support](https://webtestingcourse.dequecloud.com/support.php)                            |                         ![](https://webtestingcourse.dequecloud.com/images/site/homeLanding.jpg)                         |
# |           |                                                * [Support](/support.php)                                                 |                            *   [Contact](https://webtestingcourse.dequecloud.com/contact.php)                            |                                            ### Welcome to Gefälscht CompuTech                                            |
# |           |                                                * [Contact](/contact.php)                                                 |                                                                                                                          | _Gefälscht_ - German for "Fake". This is a fake website, created by Deque Systems, for use during training. Our clients  |
# |           |                                                                                                                          |                     ![Image 1](https://webtestingcourse.dequecloud.com/images/site/homeLanding.jpg)                      |  are pointed to this site so that we can train them using an inaccessible site without having to point to the site of a  |
# |           |                                             ![](images/site/homeLanding.jpg)                                             |                                                                                                                          | real company. This site has a number of intentional accessibility problems. It is not an example of how to do things but |
# |           |                                                                                                                          |                                            ### Welcome to Gefälscht CompuTech                                            | rather how **not** to do them. If you're interested in knowing how you can make an accessible website, need help making  |
# |           |                                            ### Welcome to Gefälscht CompuTech                                            |                                                                                                                          |          your website accessible, or want to have your website tested for accessibility, please [contact Deque           |
# |           |                                                                                                                          | _Gefälscht_ - German for "Fake". This is a fake website, created by Deque Systems, for use during training. Our clients  |                                             Systems](http://www.deque.com).                                              |
# |           |       *Gefälscht* - German for "Fake". This is a fake website, created by Deque Systems, for use during training.        |  are pointed to this site so that we can train them using an inaccessible site without having to point to the site of a  |                                                                                                                          |
# |           | Our clients are pointed to this site so that we can train them using an inaccessible site without having to point to the | real company. This site has a number of intentional accessibility problems. It is not an example of how to do things but |                                                                                                                          |
# |           | site of a real company. This site has a number of intentional accessibility problems. It is not an example of how to do  | rather how **not** to do them. If you're interested in knowing how you can make an accessible website, need help making  |                                                  * ## Parts and Supplies                                                 |
# |           |  things but rather how **not** to do them. If you're interested in knowing how you can make an accessible website, need  |          your website accessible, or want to have your website tested for accessibility, please [contact Deque           |                          ![](https://webtestingcourse.dequecloud.com/images/site/small60-1.jpg)                          |
# |           |    help making your website accessible, or want to have your website tested for accessibility, please [contact Deque     |                                             Systems](http://www.deque.com/).                                             |  We sell parts and supplies for every computer we sell and even some that we don't. If we don't have a part, it doesn't  |
# |           |                                             Systems](http://www.deque.com).                                              |                                                                                                                          |   exist. If it does exist and we don't have it, we'll get it. If we can't get it, we'll steal it. That's how we roll.    |
# |           |                                                                                                                          |                                                  *   Parts and Supplies                                                  |                        [Continue Reading »](https://webtestingcourse.dequecloud.com/support.php)                         |
# |           |                                                   * Parts and Supplies                                                   |                                                    ------------------                                                    |                                            * ## Visit our Brick & Mortar Store                                           |
# |           |                                                     ------------------                                                   |                                                                                                                          |                          ![](https://webtestingcourse.dequecloud.com/images/site/small60-2.jpg)                          |
# |           |                                                                                                                          |                      ![Image 2](https://webtestingcourse.dequecloud.com/images/site/small60-1.jpg)                       |                         Look at that picture. Isn't it great? Want a bigger version? Go to [this                         |
# |           |                                               ![](images/site/small60-1.jpg)                                             |  We sell parts and supplies for every computer we sell and even some that we don't. If we don't have a part, it doesn't  |   page](https://webtestingcourse.dequecloud.com/contact.php) and take a closer look. Our opulently appointed corporate   |
# |           |                                                                                                                          |   exist. If it does exist and we don't have it, we'll get it. If we can't get it, we'll steal it. That's how we roll.    |    offices are located in the finest strip mall within miles. We think you'll agree that our place is the place among    |
# |           |   We sell parts and supplies for every computer we sell and even some that we don't. If we don't have a part, it doesn't |                                                                                                                          |                              places when you think of a place that does our sort of thing.                               |
# |           |   exist. If it does exist and we don't have it, we'll get it. If we can't get it, we'll steal it. That's how we roll.    |                        [Continue Reading »](https://webtestingcourse.dequecloud.com/support.php)                         |                        [Continue Reading »](https://webtestingcourse.dequecloud.com/contact.php)                         |
# |           |                                                                                                                          |                                                                                                                          |                                               * ## In Home Computer Service                                              |
# |           |                                             [Continue Reading »](support.php)                                            |                                            *   Visit our Brick & Mortar Store                                            |                          ![](https://webtestingcourse.dequecloud.com/images/site/small60-3.jpg)                          |
# |           |                                             * Visit our Brick & Mortar Store                                             |                                              ------------------------------                                              |  You don't like our place? Then we'll come to your place. We can fix your stuff in your home for a sizeable surcharge.   |
# |           |                                               ------------------------------                                             |                                                                                                                          |  We'll get there at a time that is incredibly inconvenient to you and come unprepared for the task at hand. You'll tell  |
# |           |                                                                                                                          |                      ![Image 3](https://webtestingcourse.dequecloud.com/images/site/small60-2.jpg)                       |                                    all your friends what great service you received!                                     |
# |           |                                               ![](images/site/small60-2.jpg)                                             |                         Look at that picture. Isn't it great? Want a bigger version? Go to [this                         |                        [Continue Reading »](https://webtestingcourse.dequecloud.com/support.php)                         |
# |           |                                                                                                                          |   page](https://webtestingcourse.dequecloud.com/contact.php) and take a closer look. Our opulently appointed corporate   |                                                                                                                          |
# |           |    Look at that picture. Isn't it great? Want a bigger version? Go to [this page](contact.php) and take a closer look.   |    offices are located in the finest strip mall within miles. We think you'll agree that our place is the place among    |                                                                                                                          |
# |           | Our opulently appointed corporate offices are located in the finest strip mall within miles. We think you'll agree that  |                              places when you think of a place that does our sort of thing.                               |                                                                                                                          |
# |           |                our place is the place among places when you think of a place that does our sort of thing.                |                                                                                                                          |                            * [![](https://webtestingcourse.dequecloud.com/images/site/small174-                          |
# |           |                                                                                                                          |                        [Continue Reading »](https://webtestingcourse.dequecloud.com/contact.php)                         |                              1.jpg)](https://webtestingcourse.dequecloud.com/desktops.php)                               |
# |           |                                             [Continue Reading »](contact.php)                                            |                                                                                                                          |                            * [![](https://webtestingcourse.dequecloud.com/images/site/small174-                          |
# |           |                                                * In Home Computer Service                                                |                                               *   In Home Computer Service                                               |                              2.jpg)](https://webtestingcourse.dequecloud.com/desktops.php)                               |
# |           |                                                  ------------------------                                                |                                                 ------------------------                                                 |                            * [![](https://webtestingcourse.dequecloud.com/images/site/small174-                          |
# |           |                                                                                                                          |                                                                                                                          |                         3.jpg)](https://webtestingcourse.dequecloud.com/laptopsandnotebooks.php)                         |
# |           |                                               ![](images/site/small60-3.jpg)                                             |                      ![Image 4](https://webtestingcourse.dequecloud.com/images/site/small60-3.jpg)                       |                            * [![](https://webtestingcourse.dequecloud.com/images/site/small174-                          |
# |           |                                                                                                                          |  You don't like our place? Then we'll come to your place. We can fix your stuff in your home for a sizeable surcharge.   |                         4.jpg)](https://webtestingcourse.dequecloud.com/laptopsandnotebooks.php)                         |
# |           |   You don't like our place? Then we'll come to your place. We can fix your stuff in your home for a sizeable surcharge.  |  We'll get there at a time that is incredibly inconvenient to you and come unprepared for the task at hand. You'll tell  |                            * [![](https://webtestingcourse.dequecloud.com/images/site/small174-                          |
# |           |  We'll get there at a time that is incredibly inconvenient to you and come unprepared for the task at hand. You'll tell  |                                    all your friends what great service you received!                                     |                         5.jpg)](https://webtestingcourse.dequecloud.com/laptopsandnotebooks.php)                         |
# |           |                                    all your friends what great service you received!                                     |                                                                                                                          |                                                                                                                          |
# |           |                                                                                                                          |                        [Continue Reading »](https://webtestingcourse.dequecloud.com/support.php)                         |                                                                                                                          |
# |           |                                             [Continue Reading »](support.php)                                            |                                                                                                                          |                                                                                                                          |
# |           |                                                                                                                          |                      *   [![Image 5](https://webtestingcourse.dequecloud.com/images/site/small174-                       |                                                  ## Laptops & Notebooks                                                  |
# |           |                                    * [![](images/site/small174-1.jpg)](desktops.php)                                     |                              1.jpg)](https://webtestingcourse.dequecloud.com/desktops.php)                               |                            * [Fregatte 17](https://webtestingcourse.dequecloud.com/laptop1.php)                          |
# |           |                                    * [![](images/site/small174-2.jpg)](desktops.php)                                     |                      *   [![Image 6](https://webtestingcourse.dequecloud.com/images/site/small174-                       |                           * [Abgenutzt 15](https://webtestingcourse.dequecloud.com/laptop2.php)                          |
# |           |                               * [![](images/site/small174-3.jpg)](laptopsandnotebooks.php)                               |                              2.jpg)](https://webtestingcourse.dequecloud.com/desktops.php)                               |                           * [Backstein 21](https://webtestingcourse.dequecloud.com/laptop3.php)                          |
# |           |                               * [![](images/site/small174-4.jpg)](laptopsandnotebooks.php)                               |                      *   [![Image 7](https://webtestingcourse.dequecloud.com/images/site/small174-                       |                                                                                                                          |
# |           |                               * [![](images/site/small174-5.jpg)](laptopsandnotebooks.php)                               |                         3.jpg)](https://webtestingcourse.dequecloud.com/laptopsandnotebooks.php)                         |                                                                                                                          |
# |           |                                                                                                                          |                      *   [![Image 8](https://webtestingcourse.dequecloud.com/images/site/small174-                       |                                                       ## Desktops                                                        |
# |           |                                                   Laptops & Notebooks                                                    |                         4.jpg)](https://webtestingcourse.dequecloud.com/laptopsandnotebooks.php)                         |                          * [Beschissen 750](https://webtestingcourse.dequecloud.com/desktop1.php)                        |
# |           |                                                   -------------------                                                    |                      *   [![Image 9](https://webtestingcourse.dequecloud.com/images/site/small174-                       |                         * [Rindviecher 1000](https://webtestingcourse.dequecloud.com/desktop2.php)                       |
# |           |                                                                                                                          |                         5.jpg)](https://webtestingcourse.dequecloud.com/laptopsandnotebooks.php)                         |                          * [Verrottet 875](https://webtestingcourse.dequecloud.com/desktop3.php)                         |
# |           |                                               * [Fregatte 17](laptop1.php)                                               |                                                                                                                          |                                                                                                                          |
# |           |                                              * [Abgenutzt 15](laptop2.php)                                               |                                                   Laptops & Notebooks                                                    |                                                                                                                          |
# |           |                                              * [Backstein 21](laptop3.php)                                               |                                                   -------------------                                                    |                                                 ## Test Course Materials                                                 |
# |           |                                                                                                                          |                                                                                                                          |                    * [Dragon Cheat Sheet](https://webtestingcourse.dequecloud.com/dragoncheatsheet.php)                  |
# |           |                                                         Desktops                                                         |                          *   [Fregatte 17](https://webtestingcourse.dequecloud.com/laptop1.php)                          |                      * [JAWS Cheat Sheet](https://webtestingcourse.dequecloud.com/jawscheatsheet.php)                    |
# |           |                                                         --------                                                         |                         *   [Abgenutzt 15](https://webtestingcourse.dequecloud.com/laptop2.php)                          |             * [Sample Test Case Template](https://webtestingcourse.dequecloud.com/sampletestcasetemplate.php)            |
# |           |                                                                                                                          |                         *   [Backstein 21](https://webtestingcourse.dequecloud.com/laptop3.php)                          |                 * [Sample Issue Template](https://webtestingcourse.dequecloud.com/sampleissuetemplate.php)               |
# |           |                                             * [Beschissen 750](desktop1.php)                                             |                                                                                                                          |                                                      * Photo Credits                                                     |
# |           |                                            * [Rindviecher 1000](desktop2.php)                                            |                                                         Desktops                                                         |                                                                                                                          |
# |           |                                             * [Verrottet 875](desktop3.php)                                              |                                                         --------                                                         |                                                                                                                          |
# |           |                                                                                                                          |                                                                                                                          |                                                         ## Cart                                                          |
# |           |                                                  Test Course Materials                                                   |                        *   [Beschissen 750](https://webtestingcourse.dequecloud.com/desktop1.php)                        |    * [Lookee here! Just in case you didn't notice the 'Cart' link in the global navigation, you can also find a link to  |
# |           |                                                  ---------------------                                                   |                       *   [Rindviecher 1000](https://webtestingcourse.dequecloud.com/desktop2.php)                       |                 your cart down here, too. Neat, huh?](https://webtestingcourse.dequecloud.com/cart.php)                  |
# |           |                                                                                                                          |                        *   [Verrottet 875](https://webtestingcourse.dequecloud.com/desktop3.php)                         |                                                                                                                          |
# |           |                                      * [Dragon Cheat Sheet](/dragoncheatsheet.php)                                       |                                                                                                                          |                                                                                                                          |
# |           |                                        * [JAWS Cheat Sheet](/jawscheatsheet.php)                                         |                                                  Test Course Materials                                                   |                                                        ## Support                                                        |
# |           |                                * [Sample Test Case Template](/sampletestcasetemplate.php)                                |                                                  ---------------------                                                   |     * [Get answers to all of your favorite support questions here, including such gems as "Where is my 'Any' key?" and   |
# |           |                                   * [Sample Issue Template](/sampleissuetemplate.php)                                    |                                                                                                                          |           "How many pins does a sixteen pin cable have?"](https://webtestingcourse.dequecloud.com/support.php)           |
# |           |                                                     * Photo Credits                                                      |                  *   [Dragon Cheat Sheet](https://webtestingcourse.dequecloud.com/dragoncheatsheet.php)                  |                                                                                                                          |
# |           |                                                                                                                          |                    *   [JAWS Cheat Sheet](https://webtestingcourse.dequecloud.com/jawscheatsheet.php)                    |                                                                                                                          |
# |           |                                                           Cart                                                           |           *   [Sample Test Case Template](https://webtestingcourse.dequecloud.com/sampletestcasetemplate.php)            |                                                                                                                          |
# |           |                                                           ----                                                           |               *   [Sample Issue Template](https://webtestingcourse.dequecloud.com/sampleissuetemplate.php)               |                                                                                                                          |
# |           |                                                                                                                          |                                                    *   Photo Credits                                                     |              Copyright © 2026 - All Rights Reserved - [Gefälscht](https://webtestingcourse.dequecloud.com/)              |
# |           |   * [Lookee here! Just in case you didn't notice the 'Cart' link in the global navigation, you can also find a link to   |                                                                                                                          |                                                   Gefälscht CompuTech                                                    |
# |           |                                     your cart down here, too. Neat, huh?](cart.php)                                      |                                                           Cart                                                           |                                                                                                                          |
# |           |                                                                                                                          |                                                           ----                                                           |                                                                                                                          |
# |           |                                                         Support                                                          |                                                                                                                          |                                                                                                                          |
# |           |                                                         -------                                                          |  *   [Lookee here! Just in case you didn't notice the 'Cart' link in the global navigation, you can also find a link to  |                                                                                                                          |
# |           |                                                                                                                          |                 your cart down here, too. Neat, huh?](https://webtestingcourse.dequecloud.com/cart.php)                  |                                                                                                                          |
# |           | * [Get answers to all of your favorite support questions here, including such gems as "Where is my 'Any' key?" and "How  |                                                                                                                          |                                                                                                                          |
# |           |                                 many pins does a sixteen pin cable have?"](support.php)                                  |                                                         Support                                                          |                                                                                                                          |
# |           |                                                                                                                          |                                                         -------                                                          |                                                                                                                          |
# |           |                                 Copyright © 2026 - All Rights Reserved - [Gefälscht](/)                                  |                                                                                                                          |                                                                                                                          |
# |           |                                                                                                                          |   *   [Get answers to all of your favorite support questions here, including such gems as "Where is my 'Any' key?" and   |                                                                                                                          |
# |           |                                                   Gefälscht CompuTech                                                    |           "How many pins does a sixteen pin cable have?"](https://webtestingcourse.dequecloud.com/support.php)           |                                                                                                                          |
# |           |                                                                                                                          |                                                                                                                          |                                                                                                                          |
# |           |                                                                                                                          |              Copyright © 2026 - All Rights Reserved - [Gefälscht](https://webtestingcourse.dequecloud.com/)              |                                                                                                                          |
# |           |                                                                                                                          |                                                                                                                          |                                                                                                                          |
# |           |                                                                                                                          |                                                   Gefälscht CompuTech                                                    |                                                                                                                          |
# |           |                                                                                                                          |                                                                                                                          |                                                                                                                          |
# |           |                                                                                                                          |                                                         Images:                                                          |                                                                                                                          |
# |           |                                                                                                                          |                    - ![Image 1](https://webtestingcourse.dequecloud.com/images/site/homeLanding.jpg)                     |                                                                                                                          |
# |           |                                                                                                                          |                     - ![Image 2](https://webtestingcourse.dequecloud.com/images/site/small60-1.jpg)                      |                                                                                                                          |
# |           |                                                                                                                          |                     - ![Image 3](https://webtestingcourse.dequecloud.com/images/site/small60-2.jpg)                      |                                                                                                                          |
# |           |                                                                                                                          |                     - ![Image 4](https://webtestingcourse.dequecloud.com/images/site/small60-3.jpg)                      |                                                                                                                          |
# |           |                                                                                                                          |                     - ![Image 5](https://webtestingcourse.dequecloud.com/images/site/small174-1.jpg)                     |                                                                                                                          |
# |           |                                                                                                                          |                     - ![Image 6](https://webtestingcourse.dequecloud.com/images/site/small174-2.jpg)                     |                                                                                                                          |
# |           |                                                                                                                          |                     - ![Image 7](https://webtestingcourse.dequecloud.com/images/site/small174-3.jpg)                     |                                                                                                                          |
# |           |                                                                                                                          |                     - ![Image 8](https://webtestingcourse.dequecloud.com/images/site/small174-4.jpg)                     |                                                                                                                          |
# |           |                                                                                                                          |                     - ![Image 9](https://webtestingcourse.dequecloud.com/images/site/small174-5.jpg)                     |                                                                                                                          |
# |           |                                                                                                                          |                                                                                                                          |                                                                                                                          |
# +-----------+--------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# ## Connect to LLMs to evaluate whether they can generate an accessible web page
#
# We will send the content in both HTML and Markdown formats and ask the model to return a WCAG 2.2-compliant accessible section.

# %%
# !pip install openai --quiet

# %%
from env_colab_pass import passutil
from openai import OpenAI

OPENAI_API_KEY = passutil.get_secret_value("OPENAI_API_KEY")
GOOGLE_API_KEY = passutil.get_secret_value("GOOGLE_API_KEY")

def extract(model: str, user_input: str, user_prompt: str, template: str = None) -> str:
    if model.startswith("gpt"):
        client = OpenAI(api_key=OPENAI_API_KEY)
    elif model.startswith("gemini"):
        client = OpenAI(api_key=GOOGLE_API_KEY, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")

    # entity_extraction_system_message = {
    #     "role": "system", 
    #     "content": """"
    #     # Identity
    #     * You are a helpful assistant expert on web accessibility WCAG that evaluate and correct HTML code. You will be given code and you will analize it.

    #     # Instructions
    #     * You will create a new webpage from that code but accessible according to the guidelines in https://www.w3.org/WAI/WCAG22/Understanding/
    #     * Revise all WCAG 2.2 rules including color contrast, alt text, aria labels, provide correct heading levels starting from h1, use semantic HTML elements. Dont broke aria references. Correct as necessary the HTML code to make it accessible.
    #     * If the images (.png, .jpg, .svg, .gif, .jpeg), scripts (.js), css (.css) and font files have a relative urls or start without https://, convert them to absoulute urls using the root url as prefix. 
    #     * If the images (.png, .jpg, .svg, .gif, .jpeg), scripts (.js), css (.css) and font files have absolute urls starting with https://, you will keep them as they are.
    #     * If the original source has required scripts (.js), you will include them in the head section. If the original source has required css files, you will analize them and include them as inline rules in head section but WCAG accessible corrected, including color contrast checking. Correct as necessary the CSS code to make it accessible.
    #     * If you need to include an style.css file, you will add the rules inline in the head section. If you include an sr-only rule, add it to the style section to hide the elements.
    #     * Detect the language of the HTML code and add the lang attribute to the html tag.
    #     * Before returning the HTML code, you will analyze it and check if it accessible according to WCAG 2.2. If it is not accessible, you will correct it and return the corrected code.
    #     * You will double check every step you do.
    #     * The HTML code must be a complete HTML code, not a fragment or incomplete and must be within the context window of the model.
    #     * Do not give responses with Markdown formatting, just return the HTML accessible code requested.
    #     """
    # }
    entity_extraction_system_message = {
        "role": "system",
        "content": """
        # Identity
        You are a Web accessibility expert specialized in WCAG 2.2 compliance and semantic HTML correction. 
        You analyze, regenerate, and produce fully accessible HTML documents.

        # Regeneration Objective
        You will be given webpage code. Your task is to regenerate a complete HTML document that is accessible by design according to WCAG 2.2 guidelines:
        https://www.w3.org/WAI/WCAG22/Understanding/

        You must regenerate the page, not patch isolated issues.

        # Reasoning Phase (Implicit Chain-of-Thought)
        Before generating the final HTML:
        - Think step-by-step about all potential accessibility violations.
        - Identify structural, semantic, contrast, ARIA, heading, and labeling issues.
        - Determine the required corrective transformations.
        - Ensure that no new accessibility violations are introduced.
        Do NOT output this reasoning.

        # Accessibility Constraints
        You must:
        - Revise all WCAG 2.2 criteria including color contrast, alt text, ARIA labels, correct heading hierarchy starting from h1, and semantic HTML elements.
        - Preserve and correctly reference ARIA relationships.
        - Detect the language of the page and add the appropriate lang attribute to the <html> tag.
        - Ensure full keyboard navigability.
        - Maintain semantic integrity of the original content.

        # Resource Normalization Rules
        - Convert relative URLs (images, CSS, JS, fonts) to absolute URLs using the provided root URL.
        - Preserve absolute URLs that already begin with https://
        - Include required JS files in the <head> section.
        - Convert external CSS into inline <style> rules in the <head>, correcting accessibility CSS code issues such as insufficient contrast.
        - If sr-only rules are required, define them in the style section.

        # Structural Requirements
        - The output must be a complete HTML document (not a fragment).
        - Ensure proper document structure: <!DOCTYPE>, <html>, <head>, <body>.
        - Maintain responsiveness if Bootstrap or layout classes are used.
        
        # Reflection and Verification.
        Before returning the final output:
        - Re-evaluate the regenerated HTML against WCAG 2.2.
        - Double-check structural correctness.
        - Confirm no new accessibility violations were introduced.

        # Output Constraint
        Return ONLY the final accessible HTML code.
        Do NOT include explanations, Markdown formatting, or reasoning text.
        """
        }
    # Add the system message to the messages list
    messages = [entity_extraction_system_message]
    # Add the content to the messages list
    messages.append({"role": "user", "content": user_prompt})
    messages.append({"role": "user", "content": user_input})
    if template:
        messages.append({"role": "user", "content": "The following is an accessibility-aware structural template to guide the regeneration. Use it as a reference for semantic structure, ARIA usage, and responsive layout. Use bootstrap classes to make it responsive and accessible."})
        messages.append({"role": "user", "content": template})
    # Call the OpenAI API to get the response
    response = client.chat.completions.create(
        model=model,    # Specify the model to use
        temperature=0.5,  # Adjust temperature for more creative responses
        stream=False,   # Set to True if you want to stream the response
        messages=messages,  # The messages to send to the model
        # response_format={"type": "json_object"}, # Specify the response format as a JSON object
    )
    
    # return response.choices[0].message.content
    return response.choices[0].message.content, response.usage.completion_tokens, response.usage.prompt_tokens

# %% [markdown]
# ## Function to compare the results
#
# We will now create a function to generate a table that compares the results returned in both HTML and Markdown formats.

# %%
# The actual cost of using gpt-5.2 is 1.750 USD per million tokens.
# The actual cost of using gemini-3-flash is 3.00 USD per million tokens.

def calculate_cost_tokens(num_tokens: int, cost_per_million_tokens: float = 1.750) -> float:
    total_cost = (num_tokens / 1_000_000) * cost_per_million_tokens
    return total_cost

# %%
def display_extracted_content(model: str, results_html: List[Dict[str, any]], results_md: List[Dict[str, any]], html_source: str, markdown_source: str, site_name: str, template: str):
    # The actual cost of using gpt-5.2 is 1.750 USD per million tokens.
    # The actual cost of using gemini-3-flash is 3.00 USD per million tokens.
    if model.startswith("gpt"):
        cost_per_million_tokens = 1.750
    elif model.startswith("gemini"):
        cost_per_million_tokens = 3.00

    table = PrettyTable()
    table.field_names = ["Site", "From HTML", "From HTML with template","From markdown", "From markdown with template"]

    with open(f'templates/{template}.html', 'r') as file:  # r to open file in READ mode
        html_as_string = file.read()

    # Iterate through each site and its content
    for item in tqdm(results_html, desc="Processing results"):
        sites_html = item["sites"]
        sites_md = item["sites"]
        provider = item["provider"]

        # Check if the provider matches the site name
        if provider == site_name:
            for i in range(len(sites_html)):
                # Check if the html source matches
                if sites_html[i]["name"] == html_source:
                    # Extract the content for HTML and Markdown
                    content_html = sites_html[i]["content"]
                    content_url = sites_html[i]["url"]
                    content_md = sites_md[i]["content"]

                    # HTML input without template
                    for _ in tqdm(range(1), desc=f"Extracting content with {html_source} for HTML input", position=0, leave=True):
                        extracted_content_html, completion_tokens, prompt_tokens = extract(model, user_input=content_html, user_prompt= f"Use the following content to create a new accessible web page version. The root URL is '{content_url}'.", template=None)
                        cost = calculate_cost_tokens(completion_tokens + prompt_tokens, cost_per_million_tokens)
                        cost_label = f"Completion tokens: {completion_tokens:,}\nPrompt tokens: {prompt_tokens:,}\nTotal cost: ${cost:.6f}" + "\n\n\n"
                        col_content_html = cost_label + extracted_content_html
                    
                    # HTML input with template
                    for _ in tqdm(range(1), desc=f"Extracting content with {html_source} for HTML input and template"):
                        extracted_content_html_template, completion_tokens, prompt_tokens = extract(model, user_input=content_html, user_prompt= f"Use the following content to create a new accessible web page version. The root URL is '{content_url}'.", template=html_as_string.replace("\n",""))
                        cost = calculate_cost_tokens(completion_tokens + prompt_tokens, cost_per_million_tokens)
                        cost_label = f"Completion tokens: {completion_tokens:,}\nPrompt tokens: {prompt_tokens:,}\nTotal cost: ${cost:.6f}" + "\n\n\n"
                        col_content_html_template = cost_label + extracted_content_html_template
                elif sites_md[i]["name"] == markdown_source:
                    # Extract the content for HTML and Markdown
                    content_html = sites_html[i]["content"]
                    content_url = sites_html[i]["url"]
                    content_md = sites_md[i]["content"]

                    # Progress bar for each function
                    for _ in tqdm(range(1), desc=f"Extracting content with {markdown_source} for Markdown input"):
                        extracted_content_md, completion_tokens, prompt_tokens = extract(model, user_input=content_md, user_prompt= f"Use the following content to create a new accessible web page version. The root URL is '{content_url}'.", template=None)
                        cost = calculate_cost_tokens(completion_tokens + prompt_tokens, cost_per_million_tokens)
                        cost_label = f"Completion tokens: {completion_tokens:,}\nPrompt tokens: {prompt_tokens:,}\nTotal cost: ${cost:.6f}" + "\n\n\n"
                        col_content_md = cost_label + extracted_content_md

                    # Progress bar for each function
                    for _ in tqdm(range(1), desc=f"Extracting content with {markdown_source} for Markdown input and template"):
                        extracted_content_md_template, completion_tokens, prompt_tokens = extract(model, user_input=content_md, user_prompt= f"Use the following content to create a new accessible web page version. The root URL is '{content_url}'.", template=html_as_string.replace("\n",""))
                        cost = calculate_cost_tokens(completion_tokens + prompt_tokens, cost_per_million_tokens)
                        cost_label = f"Completion tokens: {completion_tokens:,}\nPrompt tokens: {prompt_tokens:,}\nTotal cost: ${cost:.6f}" + "\n\n\n"
                        col_content_md_template = cost_label + extracted_content_md_template

            table.add_row([provider, col_content_html, col_content_html_template, col_content_md, col_content_md_template])

    table.max_width = 50  # Set the maximum width for better display
    table.hrules = True  # Add horizontal rules for better readability

    print("Extracted Content Table:")
    print(table)

    return extracted_content_html, extracted_content_html_template, extracted_content_md, extracted_content_md_template

# %% [markdown]
# ### Storing the results
#
# Helper function to save all outputs generated by the language models into folders.

# %%
import os

def generate_output_files(prefix: str, extracted_html: dict, extracted_html_template: dict, extracted_md: dict, extracted_md_template: dict):
    # Create the output directory if it doesn't exist
    if not os.path.exists(f"output/{prefix}"):
        os.makedirs(f"output/{prefix}")

    # Write the HTML content to files
    with open(f'output/{prefix}/1-from_html.html', 'w', encoding='utf-8') as f:
        f.write(extracted_html)

    with open(f'output/{prefix}/2-from_html_template.html', 'w', encoding='utf-8') as f:
        f.write(extracted_html_template)

    with open(f'output/{prefix}/3-from_md.html', 'w', encoding='utf-8') as f:
        f.write(extracted_md)

    with open(f'output/{prefix}/4-from_md_template.html', 'w', encoding='utf-8') as f:
        f.write(extracted_md_template)

# %% [markdown]
# ## GPT-5.2
#
# Let's examine the output generated by this model.

# %%
extracted_html, extracted_html_template, extracted_md, extracted_md_template = display_extracted_content("gpt-5.2", all_content_html, all_content_md, html_source="Crawl4ai", markdown_source="Jina AI", site_name="Site 1", template="homepage")
# Out:
# Processing results:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Jina AI for Markdown input:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Jina AI for Markdown input and template:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for HTML input:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for HTML input and template:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracted Content Table:
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# |  Site  |                     From HTML                      |              From HTML with template               |                   From markdown                    |            From markdown with template             |
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# | Site 1 |              Completion tokens: 4,832              |              Completion tokens: 4,322              |              Completion tokens: 4,987              |              Completion tokens: 4,147              |
# |        |                Prompt tokens: 2,664                |                Prompt tokens: 4,771                |                Prompt tokens: 2,612                |                Prompt tokens: 4,719                |
# |        |               Total cost: $0.013118                |               Total cost: $0.015913                |               Total cost: $0.013298                |               Total cost: $0.015516                |
# |        |                                                    |                                                    |                                                    |                                                    |
# |        |                                                    |                                                    |                                                    |                                                    |
# |        |                  <!DOCTYPE html>                   |                  <!DOCTYPE html>                   |                  <!DOCTYPE html>                   |                  <!DOCTYPE html>                   |
# |        |                  <html lang="en">                  |                  <html lang="en">                  |                  <html lang="en">                  |                  <html lang="en">                  |
# |        |                       <head>                       |                       <head>                       |                       <head>                       |                       <head>                       |
# |        |               <meta charset="utf-8" />             |               <meta charset="UTF-8" />             |               <meta charset="utf-8" />             |               <meta charset="UTF-8" />             |
# |        |     <meta name="viewport" content="width=device-   |     <meta name="viewport" content="width=device-   |     <meta name="viewport" content="width=device-   |     <meta name="viewport" content="width=device-   |
# |        |             width, initial-scale=1" />             |             width, initial-scale=1" />             |             width, initial-scale=1" />             |             width, initial-scale=1" />             |
# |        |   <meta name="robots" content="noindex, nofollow"  |   <meta name="robots" content="noindex, nofollow"  |   <meta name="robots" content="noindex, nofollow"  |          <title>Gefälscht CompuTech</title>        |
# |        |                         />                         |                         />                         |                         />                         |   <meta name="robots" content="noindex, nofollow"  |
# |        |      <title>Gefälscht CompuTech — Home</title>     |    <title>Gefälscht — Gefälscht CompuTech</title>  |         <title>Gefälscht CompuTech (Training       |                         />                         |
# |        |                                                    |                                                    |                   Site)</title>                    |                                                    |
# |        |     <script src="https://code.jquery.com/jquery-   |   <link href="https://cdn.jsdelivr.net/npm/bootstr |                                                    |   <link href="https://cdn.jsdelivr.net/npm/bootstr |
# |        |                latest.js"></script>                |        ap@5.3.8/dist/css/bootstrap.min.css"        |     <script src="https://code.jquery.com/jquery-   |        ap@5.3.8/dist/css/bootstrap.min.css"        |
# |        |                                                    |                rel="stylesheet" />                 |                latest.js"></script>                |                rel="stylesheet" />                 |
# |        |                       <style>                      |                                                    |                                                    |                                                    |
# |        |                         :root{                     |                       <style>                      |                       <style>                      |                       <style>                      |
# |        |                      --bg: #ffffff;                |             :root { color-scheme: light; }         |                         :root{                     |             :root { color-scheme: light; }         |
# |        |                     --text: #1b1b1b;               |        body { background: #fff; color: #111; }     |                      --bg: #ffffff;                |             body { background: #ffffff; }          |
# |        |                      --muted: #444;                |          a { text-underline-offset: 0.15em; }      |                     --text: #111111;               |          a { text-underline-offset: 0.15em; }      |
# |        |                    --brand: #0b3d91;               |         a:focus-visible, button:focus-visible,     |                    --muted: #444444;               |         a:focus-visible, button:focus-visible,     |
# |        |                   --brand-2: #0a2f6e;              |               input:focus-visible {                |                    --border: #c9c9c9;              |               input:focus-visible {                |
# |        |                    --border: #d0d7de;              |               outline: 3px solid #0b5fff;          |                     --link: #0b57d0;               |               outline: 3px solid #0b5fff;          |
# |        |                   --surface: #f6f8fa;              |                   outline-offset: 2px;             |                 --link-visited: #5a2ca0;           |                   outline-offset: 2px;             |
# |        |                    --focus: #ffbf47;               |                           }                        |                    --focus: #0b57d0;               |                           }                        |
# |        |                     --link: #0b3d91;               |                      .skip-link {                  |                  --header-bg: #0f172a;             |                      .skip-link {                  |
# |        |                 --link-visited: #5a2ca0;           |                   position: absolute;              |                 --header-text: #ffffff;            |                   position: absolute;              |
# |        |                           }                        |                         top: 0;                    |                    --nav-bg: #111827;              |                         top: 0;                    |
# |        |                                                    |                         left: 0;                   |                   --nav-text: #ffffff;             |                         left: 0;                   |
# |        |             * { box-sizing: border-box; }          |              transform: translateY(-200%);         |                   --card-bg: #f7f7f7;              |              transform: translateY(-120%);         |
# |        |      html { -webkit-text-size-adjust: 100%; text-  |                    background: #fff;               |                           }                        |                   background: #0b5fff;             |
# |        |                size-adjust: 100%; }                |                       color: #111;                 |                                                    |                       color: #fff;                 |
# |        |                         body{                      |                  padding: .75rem 1rem;             |             * { box-sizing: border-box; }          |                  padding: .75rem 1rem;             |
# |        |                        margin: 0;                  |                border: 2px solid #0b5fff;          |           html { scroll-behavior: smooth; }        |                      z-index: 2000;                |
# |        |       font-family: system-ui, -apple-system, Segoe |                     z-index: 10000;                |                         body{                      |               border-radius: 0 0 .5rem 0;          |
# |        |     UI, Roboto, Helvetica, Arial, "Noto Sans",     |                           }                        |                        margin: 0;                  |                           }                        |
# |        |           "Liberation Sans", sans-serif;           |     .skip-link:focus { transform: translateY(0); } |       font-family: system-ui, -apple-system, Segoe |     .skip-link:focus { transform: translateY(0); } |
# |        |                    line-height: 1.5;               |                                                    |     UI, Roboto, Helvetica, Arial, sans-serif;      |                   .visually-hidden-                |
# |        |                   color: var(--text);              |                      .hero-img {                   |                    line-height: 1.5;               |     focusable:not(:focus):not(:focus-within) {     |
# |        |                  background: var(--bg);            |                       width: 100%;                 |                   color: var(--text);              |              position: absolute !important;        |
# |        |                           }                        |                      height: auto;                 |                  background: var(--bg);            |                  width: 1px !important;            |
# |        |                                                    |                  border-radius: .5rem;             |                           }                        |                 height: 1px !important;            |
# |        |                a{ color: var(--link); }            |                           }                        |                                                    |                  padding: 0 !important;            |
# |        |        a:visited{ color: var(--link-visited); }    |                                                    |                a{ color: var(--link); }            |                 margin: -1px !important;           |
# |        |           a:hover{ color: var(--brand-2); }        |      /* Ensure sufficient contrast for muted text  |        a:visited{ color: var(--link-visited); }    |               overflow: hidden !important;         |
# |        |         a:focus-visible, button:focus-visible,     |                    in footer */                    |       a:hover{ text-decoration-thickness: 2px; }   |            clip: rect(0, 0, 0, 0) !important;      |
# |        |                input:focus-visible{                |      footer .text-body-secondary { color: #495057  |         a:focus-visible, button:focus-visible,     |             white-space: nowrap !important;        |
# |        |             outline: 3px solid var(--focus);       |                   !important; }                    |                input:focus-visible{                |                  border: 0 !important;             |
# |        |                   outline-offset: 2px;             |                       </style>                     |             outline: 3px solid var(--focus);       |                           }                        |
# |        |                           }                        |                                                    |                   outline-offset: 2px;             |                      .hero-img {                   |
# |        |                                                    |     <script src="https://code.jquery.com/jquery-   |                           }                        |                       width: 100%;                 |
# |        |                      .skip-link{                   |              3.7.1.min.js"></script>               |                                                    |                      height: auto;                 |
# |        |                   position: absolute;              |                       <script>                     |                      .skip-link{                   |                  border-radius: .75rem;            |
# |        |                      left: 0.75rem;                |     // Kept for compatibility with original asset; |                   position: absolute;              |                           }                        |
# |        |                      top: 0.75rem;                 |          not required for accessibility.           |                      left: 0.5rem;                 |                    .card-img-top {                 |
# |        |                 padding: 0.5rem 0.75rem;           |                    $(function () {                 |                       top: 0.5rem;                 |                       width: 100%;                 |
# |        |                    background: #000;               |             $("table.data_table tbody tr:odd       |                 padding: 0.6rem 0.8rem;            |                      height: auto;                 |
# |        |                       color: #fff;                 |             td").addClass("odd_row");              |                   background: #ffffff;             |                           }                        |
# |        |                 border-radius: 0.25rem;            |            $("table.data_table tbody tr:even       |                     color: #000000;                |                       </style>                     |
# |        |              transform: translateY(-200%);         |             td").addClass("even_row");             |             border: 2px solid var(--focus);        |                                                    |
# |        |         transition: transform 0.15s ease-in-out;   |                          });                       |                 border-radius: 0.25rem;            |     <script src="https://code.jquery.com/jquery-   |
# |        |                      z-index: 1000;                |                      </script>                     |              transform: translateY(-200%);         |              3.7.1.min.js"></script>               |
# |        |                           }                        |                      </head>                       |         transition: transform 0.15s ease-in-out;   |                       <script>                     |
# |        |     .skip-link:focus{ transform: translateY(0); }  |                                                    |                      z-index: 9999;                |      // Kept for compatibility with original page  |
# |        |                                                    |                       <body>                       |                           }                        |     behavior (not required for accessibility).     |
# |        |                       .sr-only{                    |    <a class="skip-link" href="#main-content">Skip  |     .skip-link:focus{ transform: translateY(0); }  |                    $(function () {                 |
# |        |              position: absolute !important;        |                to main content</a>                 |                                                    |             $('table.data_table tbody tr:odd       |
# |        |                  width: 1px !important;            |                                                    |                        header{                     |             td').addClass('odd_row');              |
# |        |                 height: 1px !important;            |                       <header>                     |              background: var(--header-bg);         |            $('table.data_table tbody tr:even       |
# |        |                  padding: 0 !important;            |              <div class="border-bottom">           |                color: var(--header-text);          |             td').addClass('even_row');             |
# |        |                 margin: -1px !important;           |               <div class="container py-3">         |                           }                        |                          });                       |
# |        |               overflow: hidden !important;         |         <div class="d-flex flex-column flex-md-row |                      .container{                   |                      </script>                     |
# |        |            clip: rect(0, 0, 0, 0) !important;      | align-items-md-end justify-content-between gap-2"> |                width: min(1100px, 100%);           |                      </head>                       |
# |        |             white-space: nowrap !important;        |                            <div>                   |                     margin: 0 auto;                |                                                    |
# |        |                  border: 0 !important;             |                  <p class="mb-1 fw-semibold">      |                      padding: 1rem;                |                       <body>                       |
# |        |                           }                        |               <a class="text-decoration-none" href |                           }                        |    <a class="skip-link" href="#main-content">Skip  |
# |        |                                                    | ="https://webtestingcourse.dequecloud.com/">Gefäls |                                                    |                to main content</a>                 |
# |        |                        header{                     |                      cht</a>                       |                        .brand{                     |                                                    |
# |        |         border-bottom: 1px solid var(--border);    |                              </p>                  |                      display: flex;                |                       <header>                     |
# |        |               background: var(--surface);          |                   <p class="mb-0 text-body-        |                  align-items: baseline;            |      <div class="border-bottom bg-body-tertiary">  |
# |        |                           }                        |         secondary">Gefälscht CompuTech</p>         |             justify-content: space-between;        |         <div class="container py-2 d-flex flex-    |
# |        |                      .container{                   |                            </div>                  |                        gap: 1rem;                  | column flex-md-row align-items-md-center justify-  |
# |        |                    max-width: 1100px;              |                                                    |                     flex-wrap: wrap;               |              content-between gap-2">               |
# |        |                     margin: 0 auto;                |                  <div class="text-md-end">         |                           }                        |                      <p class="mb-0">              |
# |        |                      padding: 1rem;                |                        <p class="mb-0">            |                       .brand h1{                   |           <span class="fw-semibold">Tel:</span> <a |
# |        |                           }                        |                         <span class="fw-           |                        margin: 0;                  |      href="tel:+17035551212">703-555-1212</a>      |
# |        |                                                    |              semibold">Tel:</span> <a              |                   font-size: 1.75rem;              |                   <span class="mx-2" aria-         |
# |        |                        .brand{                     |      href="tel:+17035551212">703-555-1212</a>      |                    line-height: 1.2;               |               hidden="true">|</span>               |
# |        |                      display: flex;                |                     <span class="mx-2" aria-       |                           }                        |            <span class="fw-semibold">Mail:</span>  |
# |        |                     flex-wrap: wrap;               |               hidden="true">|</span>               |                      .brand h1 a{                  | <a href="mailto:info@deque.com">info@deque.com</a> |
# |        |                  align-items: baseline;            |                         <span class="fw-           |                color: var(--header-text);          |                            </p>                    |
# |        |                    gap: 0.75rem 1rem;              |             semibold">Mail:</span> <a              |                  text-decoration: none;            |                                                    |
# |        |                           }                        |  href="mailto:info@deque.com">info@deque.com</a>   |                           }                        |         <form class="d-flex gap-2" action="https:/ |
# |        |                       .brand h1{                   |                              </p>                  |                       .brand p{                    |    /webtestingcourse.dequecloud.com/search.php"    |
# |        |                        margin: 0;                  |                            </div>                  |                   margin: 0.25rem 0 0;             |    method="get" role="search" aria-label="Site     |
# |        |                   font-size: 1.75rem;              |                           </div>                   |                     color: #e5e7eb;                |                      search">                      |
# |        |                    line-height: 1.2;               |                          </div>                    |                           }                        |                   <label for="site-search"         |
# |        |                           }                        |                         </div>                     |                                                    |  class="visually-hidden">Search the site</label>   |
# |        |                      .brand h1 a{                  |                                                    |                        .topbar{                    |               <input id="site-search" name="q"     |
# |        |                  text-decoration: none;            |      <nav class="navbar navbar-expand-lg bg-body-  |                background: var(--nav-bg);          |         class="form-control" type="search"         |
# |        |                   color: var(--brand);             |     tertiary" aria-label="Primary navigation">     |                 color: var(--nav-text);            |               autocomplete="off" />                |
# |        |                           }                        |                 <div class="container">            |                  border-top: 1px solid             |               <button class="btn btn-primary"      |
# |        |                       .brand p{                    |         <a class="navbar-brand" href="https://webt |              rgba(255,255,255,0.15);               |           type="submit">Search</button>            |
# |        |                        margin: 0;                  |    estingcourse.dequecloud.com/">Gefälscht</a>     |                 border-bottom: 1px solid           |                          </form>                   |
# |        |                   color: var(--muted);             |                                                    |              rgba(255,255,255,0.15);               |                          </div>                    |
# |        |                           }                        |               <button class="navbar-toggler"       |                           }                        |                         </div>                     |
# |        |                                                    |  type="button" data-bs-toggle="collapse" data-bs-  |                     .topbar-inner{                 |                                                    |
# |        |                        .topbar{                    |                target="#primaryNav"                |                      display: grid;                |      <nav class="navbar navbar-expand-lg bg-body"  |
# |        |                      display: grid;                |               aria-controls="primaryNav" aria-     |               grid-template-columns: 1fr;          |          aria-label="Primary navigation">          |
# |        |               grid-template-columns: 1fr;          |  expanded="false" aria-label="Toggle navigation">  |                        gap: 1rem;                  |                 <div class="container">            |
# |        |                        gap: 1rem;                  |                 <span class="navbar-toggler-       |                   align-items: start;              |         <a class="navbar-brand d-flex flex-column  |
# |        |                  padding-top: 0.75rem;             |                   icon"></span>                    |                           }                        |                       lh-sm"                       |
# |        |                           }                        |                         </button>                  |               @media (min-width: 800px){           |  href="https://webtestingcourse.dequecloud.com/">  |
# |        |               @media (min-width: 860px){           |                                                    |                      .topbar-inner{                |            <span class="fw-bold">Gefälscht</span>  |
# |        |                         .topbar{                   |           <div class="collapse navbar-collapse"    |              grid-template-columns: 1fr auto;      |                <span class="small text-body-       |
# |        |              grid-template-columns: 1fr auto;      |                  id="primaryNav">                  |                    align-items: center;            |       secondary">Gefälscht CompuTech</span>        |
# |        |                    align-items: start;             |            <ul class="navbar-nav me-auto mb-2 mb-  |                            }                       |                            </a>                    |
# |        |                            }                       |                       lg-0">                       |                           }                        |                                                    |
# |        |                           }                        |                     <li class="nav-item">          |                                                    |               <button class="navbar-toggler"       |
# |        |                                                    |                 <a class="nav-link active" aria-   |                     .contact-line{                 |  type="button" data-bs-toggle="collapse" data-bs-  |
# |        |                       .contact{                    | current="page" href="https://webtestingcourse.dequ |                        margin: 0;                  |                target="#primaryNav"                |
# |        |                        margin: 0;                  |           ecloud.com/index.php">Home</a>           |                     color: #f3f4f6;                |               aria-controls="primaryNav" aria-     |
# |        |                   color: var(--muted);             |                             </li>                  |                           }                        |  expanded="false" aria-label="Toggle navigation">  |
# |        |                           }                        |                     <li class="nav-item">          |           .contact-line a{ color: #ffffff; }       |                 <span class="navbar-toggler-       |
# |        |                                                    |               <a class="nav-link" href="https://we |                                                    |                   icon"></span>                    |
# |        |                      form.search{                  | btestingcourse.dequecloud.com/laptopsandnotebooks. |             nav[aria-label="Primary"] ul{          |                         </button>                  |
# |        |                   margin-top: 0.75rem;             |          php">Laptops &amp; Notebooks</a>          |                    list-style: none;               |                                                    |
# |        |                      display: flex;                |                             </li>                  |                       padding: 0;                  |           <div class="collapse navbar-collapse"    |
# |        |                     flex-wrap: wrap;               |                     <li class="nav-item">          |                        margin: 0;                  |                  id="primaryNav">                  |
# |        |                       gap: 0.5rem;                 |               <a class="nav-link" href="https://we |                      display: flex;                |            <ul class="navbar-nav ms-auto mb-2 mb-  |
# |        |                    align-items: end;               | btestingcourse.dequecloud.com/desktops.php">Deskto |                     flex-wrap: wrap;               |                       lg-0">                       |
# |        |                           }                        |                       ps</a>                       |                      gap: 0.25rem;                 |                     <li class="nav-item">          |
# |        |                        .field{                     |                             </li>                  |               justify-content: flex-start;         |                 <a class="nav-link active" aria-   |
# |        |                      display: grid;                |                     <li class="nav-item">          |                           }                        | current="page" href="https://webtestingcourse.dequ |
# |        |                      gap: 0.25rem;                 |               <a class="nav-link" href="https://we |              nav[aria-label="Primary"] a{          |           ecloud.com/index.php">Home</a>           |
# |        |               min-width: min(28rem, 100%);         |  btestingcourse.dequecloud.com/cart.php">Cart</a>  |                  display: inline-block;            |                             </li>                  |
# |        |                     flex: 1 1 18rem;               |                             </li>                  |                 padding: 0.6rem 0.8rem;            |                     <li class="nav-item">          |
# |        |                           }                        |                     <li class="nav-item">          |                     color: #ffffff;                |               <a class="nav-link" href="https://we |
# |        |                         label{                     |               <a class="nav-link" href="https://we |                  text-decoration: none;            | btestingcourse.dequecloud.com/laptopsandnotebooks. |
# |        |                    font-weight: 600;               | btestingcourse.dequecloud.com/support.php">Support |                 border-radius: 0.35rem;            |          php">Laptops &amp; Notebooks</a>          |
# |        |                           }                        |                        </a>                        |                           }                        |                             </li>                  |
# |        |                 input[type="search"]{              |                             </li>                  |           nav[aria-label="Primary"] a:hover,       |                     <li class="nav-item">          |
# |        |                       width: 100%;                 |                     <li class="nav-item">          |       nav[aria-label="Primary"] a:focus-visible{   |               <a class="nav-link" href="https://we |
# |        |                 padding: 0.6rem 0.7rem;            |               <a class="nav-link" href="https://we |           background: rgba(255,255,255,0.14);      | btestingcourse.dequecloud.com/desktops.php">Deskto |
# |        |             border: 1px solid var(--border);       | btestingcourse.dequecloud.com/contact.php">Contact |                           }                        |                       ps</a>                       |
# |        |                 border-radius: 0.35rem;            |                        </a>                        |           nav[aria-label="Primary"] a[aria-        |                             </li>                  |
# |        |                     font-size: 1rem;               |                             </li>                  |                  current="page"]{                  |                     <li class="nav-item">          |
# |        |                           }                        |                            </ul>                   |           background: rgba(255,255,255,0.22);      |               <a class="nav-link" href="https://we |
# |        |                        button{                     |                                                    |                    font-weight: 700;               |  btestingcourse.dequecloud.com/cart.php">Cart</a>  |
# |        |                 padding: 0.6rem 0.9rem;            |           <form class="d-flex" action="https://web |                           }                        |                             </li>                  |
# |        |             border: 1px solid var(--brand);        |      testingcourse.dequecloud.com/search.php"      |                                                    |                     <li class="nav-item">          |
# |        |                background: var(--brand);           |    method="get" role="search" aria-label="Site     |                      form.search{                  |               <a class="nav-link" href="https://we |
# |        |                       color: #fff;                 |                      search">                      |                      display: flex;                | btestingcourse.dequecloud.com/support.php">Support |
# |        |                 border-radius: 0.35rem;            |                    <label for="site-search"        |                     flex-wrap: wrap;               |                        </a>                        |
# |        |                     font-size: 1rem;               |  class="visually-hidden">Search the site</label>   |                       gap: 0.5rem;                 |                             </li>                  |
# |        |                     cursor: pointer;               |                <input id="site-search" name="q"    |                    align-items: end;               |                     <li class="nav-item">          |
# |        |                           }                        |      class="form-control me-2" type="search"       |                           }                        |               <a class="nav-link" href="https://we |
# |        |       button:hover{ background: var(--brand-2);    |          placeholder="Search the site" />          |                        .field{                     | btestingcourse.dequecloud.com/contact.php">Contact |
# |        |          border-color: var(--brand-2); }           |                <button class="btn btn-primary"     |                      display: grid;                |                        </a>                        |
# |        |                                                    |           type="submit">Search</button>            |                      gap: 0.25rem;                 |                             </li>                  |
# |        |             nav[aria-label="Primary"] ul{          |                           </form>                  |               min-width: min(22rem, 100%);         |                            </ul>                   |
# |        |                    list-style: none;               |                           </div>                   |                           }                        |                           </div>                   |
# |        |                       padding: 0;                  |                          </div>                    |               label{ font-weight: 600; }           |                          </div>                    |
# |        |                        margin: 0;                  |                         </nav>                     |                 input[type="search"]{              |                         </nav>                     |
# |        |                      display: flex;                |                      </header>                     |                padding: 0.55rem 0.65rem;           |                      </header>                     |
# |        |                     flex-wrap: wrap;               |                                                    |             border: 1px solid var(--border);       |                                                    |
# |        |                      gap: 0.25rem;                 |   <main id="main-content" class="container my-4">  |                 border-radius: 0.35rem;            |   <main id="main-content" class="container my-4">  |
# |        |               justify-content: flex-start;         |      <section class="row align-items-center g-4"   |                     font-size: 1rem;               |        <div class="row align-items-center g-4">    |
# |        |                           }                        |           aria-labelledby="page-title">            |                           }                        |              <div class="col-12 col-lg-6">         |
# |        |               @media (min-width: 860px){           |              <div class="col-12 col-lg-5">         |                        button{                     |                   <figure class="mb-0">            |
# |        |              nav[aria-label="Primary"] ul{         |                            <img                    |                 padding: 0.6rem 0.85rem;           |                             <img                   |
# |        |                 justify-content: flex-end;         |           src="https://webtestingcourse.dequecloud |                border: 1px solid #0b57d0;          |             src="https://webtestingcourse.dequeclo |
# |        |                            }                       |         .com/images/site/homeLanding.jpg"          |                   background: #0b57d0;             |        ud.com/images/site/homeLanding.jpg"         |
# |        |                           }                        |                       class="hero-img"             |                     color: #ffffff;                |                        class="hero-img"            |
# |        |              nav[aria-label="Primary"] a{          |                         width="360"                |                 border-radius: 0.35rem;            |              alt="Gefälscht CompuTech storefront   |
# |        |                  display: inline-block;            |                         height="330"               |                     font-size: 1rem;               |                    and signage"                    |
# |        |                 padding: 0.5rem 0.75rem;           |                  alt="A Gefälscht CompuTech        |                     cursor: pointer;               |                         loading="lazy"             |
# |        |                  text-decoration: none;            | representative at a desk with computer equipment." |                           }                        |                              />                    |
# |        |                 border-radius: 0.35rem;            |                       loading="eager"              |       button:hover{ filter: brightness(0.95); }    |                         </figure>                  |
# |        |                   color: var(--brand);             |                             />                     |                                                    |                          </div>                    |
# |        |                           }                        |                          </div>                    |            main{ padding: 1.25rem 0 2rem; }        |              <div class="col-12 col-lg-6">         |
# |        |           nav[aria-label="Primary"] a:hover{       |                                                    |                                                    |            <h1 class="h2">Welcome to Gefälscht     |
# |        |                   background: #e7eefc;             |              <div class="col-12 col-lg-7">         |                        .intro{                     |                   CompuTech</h1>                   |
# |        |                           }                        |            <h1 id="page-title" class="display-6    |                      display: grid;                |                            <p>                     |
# |        |           nav[aria-label="Primary"] a[aria-        |     mb-3">Welcome to Gefälscht CompuTech</h1>      |               grid-template-columns: 1fr;          |           <em>Gefälscht</em> - German for "Fake".  |
# |        |                  current="page"]{                  |                      <p class="lead">              |                        gap: 1rem;                  | This is a fake website, created by Deque Systems,  |
# |        |                background: var(--brand);           |           <em>Gefälscht</em> — German for “Fake”.  |                   align-items: start;              |              for use during training.              |
# |        |                       color: #fff;                 |                            </p>                    |                           }                        |           Our clients are pointed to this site so  |
# |        |                           }                        |                            <p>                     |               @media (min-width: 900px){           | that we can train them using an inaccessible site  |
# |        |                                                    |           This is a fake website, created by Deque |                         .intro{                    |   without having to point to the site of a real    |
# |        |            main{ padding: 1.25rem 0 2rem; }        | Systems, for use during training. Our clients are  |             grid-template-columns: 1fr 1.2fr;      |                      company.                      |
# |        |                                                    |                  pointed to this                   |                            }                       |            This site has a number of intentional   |
# |        |                        .intro{                     |           site so that we can train them using an  |                           }                        |  accessibility problems. It is not an example of   |
# |        |                      display: grid;                |  inaccessible site without having to point to the  |                     .intro figure{                 |          how to do things but rather how           |
# |        |               grid-template-columns: 1fr;          |                   site of a real                   |                        margin: 0;                  |          <strong>not</strong> to do them.          |
# |        |                      gap: 1.25rem;                 |              company. This site has a number of    |               background: var(--card-bg);          |           If you're interested in knowing how you  |
# |        |                   align-items: start;              |  intentional accessibility problems. It is not an  |             border: 1px solid var(--border);       |  can make an accessible website, need help making  |
# |        |                           }                        |                example of how to do                |                  border-radius: 0.5rem;            |   your website accessible, or want to have your    |
# |        |               @media (min-width: 860px){           |                    things but rather how           |                    overflow: hidden;               |         website tested for accessibility,          |
# |        |                         .intro{                    |     <strong>not</strong> to do them. If you're     |                           }                        |           please <a href="https://www.deque.com/"  |
# |        |             grid-template-columns: 360px 1fr;      |     interested in knowing how you can make an      |                      .intro img{                   | target="_blank" rel="noopener noreferrer">contact  |
# |        |                            }                       |             accessible website, need help making   |                     display: block;                |                 Deque Systems</a>.                 |
# |        |                           }                        |   your website accessible, or want to have your    |                       width: 100%;                 |                            </p>                    |
# |        |                     .intro figure{                 |                 website tested for                 |                      height: auto;                 |                          </div>                    |
# |        |                        margin: 0;                  |                    accessibility, please           |                           }                        |                         </div>                     |
# |        |             border: 1px solid var(--border);       |               <a href="https://www.deque.com/"     |                   .intro figcaption{               |                                                    |
# |        |                  border-radius: 0.5rem;            | target="_blank" rel="noopener noreferrer">contact  |                  padding: 0.75rem 1rem;            |              <section class="mt-5" aria-           |
# ...
# |        | dequecloud.com/dragoncheatsheet.php">Dragon Cheat  |                                                    |                                                    |                                                    |
# |        |                   Sheet</a></li>                   |                                                    |               <section class="footbox" aria-       |                                                    |
# |        |             <li><a href="https://webtestingcourse. |                                                    |            labelledby="foot-materials">            |                                                    |
# |        |   dequecloud.com/jawscheatsheet.php">JAWS Cheat    |                                                    |             <h2 id="foot-materials">Test Course    |                                                    |
# |        |                   Sheet</a></li>                   |                                                    |                   Materials</h2>                   |                                                    |
# |        |             <li><a href="https://webtestingcourse. |                                                    |                             <ul>                   |                                                    |
# |        | dequecloud.com/sampletestcasetemplate.php">Sample  |                                                    |             <li><a href="https://webtestingcourse. |                                                    |
# |        |            Test Case Template</a></li>             |                                                    | dequecloud.com/dragoncheatsheet.php">Dragon Cheat  |                                                    |
# |        |             <li><a href="https://webtestingcourse. |                                                    |                   Sheet</a></li>                   |                                                    |
# |        |   dequecloud.com/sampleissuetemplate.php">Sample   |                                                    |             <li><a href="https://webtestingcourse. |                                                    |
# |        |              Issue Template</a></li>               |                                                    |   dequecloud.com/jawscheatsheet.php">JAWS Cheat    |                                                    |
# |        |             <li><a href="https://webtestingcourse. |                                                    |                   Sheet</a></li>                   |                                                    |
# |        |       dequecloud.com/photocredits.php">Photo       |                                                    |             <li><a href="https://webtestingcourse. |                                                    |
# |        |                  Credits</a></li>                  |                                                    | dequecloud.com/sampletestcasetemplate.php">Sample  |                                                    |
# |        |                            </ul>                   |                                                    |            Test Case Template</a></li>             |                                                    |
# |        |                         </section>                 |                                                    |             <li><a href="https://webtestingcourse. |                                                    |
# |        |                                                    |                                                    |   dequecloud.com/sampleissuetemplate.php">Sample   |                                                    |
# |        |          <section aria-labelledby="footer-cart">   |                                                    |              Issue Template</a></li>               |                                                    |
# |        |                <h2 id="footer-cart">Cart</h2>      |                                                    |             <li><a href="https://webtestingcourse. |                                                    |
# |        |                             <ul>                   |                                                    |       dequecloud.com/photocredits.php">Photo       |                                                    |
# |        |             <li><a href="https://webtestingcourse. |                                                    |                  Credits</a></li>                  |                                                    |
# |        | dequecloud.com/cart.php">Go to your cart</a></li>  |                                                    |                            </ul>                   |                                                    |
# |        |                            </ul>                   |                                                    |                         </section>                 |                                                    |
# |        |                         </section>                 |                                                    |                                                    |                                                    |
# |        |                                                    |                                                    |               <section class="footbox" aria-       |                                                    |
# |        |         <section aria-labelledby="footer-support"> |                                                    |              labelledby="foot-cart">               |                                                    |
# |        |             <h2 id="footer-support">Support</h2>   |                                                    |                 <h2 id="foot-cart">Cart</h2>       |                                                    |
# |        |                             <ul>                   |                                                    |                             <ul>                   |                                                    |
# |        |             <li><a href="https://webtestingcourse. |                                                    |                              <li>                  |                                                    |
# |        |  dequecloud.com/support.php">Get support answers   |                                                    |               <a href="https://webtestingcourse.de |                                                    |
# |        |                 and FAQs</a></li>                  |                                                    |              quecloud.com/cart.php">               |                                                    |
# |        |                            </ul>                   |                                                    |                   Lookee here! Just in case you    |                                                    |
# |        |                         </section>                 |                                                    |    didn't notice the 'Cart' link in the global     |                                                    |
# |        |                          </div>                    |                                                    | navigation, you can also find a link to your cart  |                                                    |
# |        |                                                    |                                                    |             down here, too. Neat, huh?             |                                                    |
# |        |               <div class="copyright" aria-         |                                                    |                               </a>                 |                                                    |
# |        |                 label="Copyright">                 |                                                    |                             </li>                  |                                                    |
# |        |         <p>Copyright © 2026 - All Rights Reserved  |                                                    |                            </ul>                   |                                                    |
# |        | - <a href="https://webtestingcourse.dequecloud.com |                                                    |                         </section>                 |                                                    |
# |        |                /">Gefälscht</a></p>                |                                                    |                                                    |                                                    |
# |        |                 <p>Gefälscht CompuTech</p>         |                                                    |               <section class="footbox" aria-       |                                                    |
# |        |                          </div>                    |                                                    |             labelledby="foot-support">             |                                                    |
# |        |                         </div>                     |                                                    |              <h2 id="foot-support">Support</h2>    |                                                    |
# |        |                      </footer>                     |                                                    |                             <ul>                   |                                                    |
# |        |                      </body>                       |                                                    |                              <li>                  |                                                    |
# |        |                      </html>                       |                                                    |               <a href="https://webtestingcourse.de |                                                    |
# |        |                                                    |                                                    |             quecloud.com/support.php">             |                                                    |
# |        |                                                    |                                                    |                     Get answers to all of your     |                                                    |
# |        |                                                    |                                                    |  favorite support questions here, including such   |                                                    |
# |        |                                                    |                                                    |   gems as "Where is my 'Any' key?" and "How many   |                                                    |
# |        |                                                    |                                                    |        pins does a sixteen pin cable have?"        |                                                    |
# |        |                                                    |                                                    |                               </a>                 |                                                    |
# |        |                                                    |                                                    |                             </li>                  |                                                    |
# |        |                                                    |                                                    |                            </ul>                   |                                                    |
# |        |                                                    |                                                    |                         </section>                 |                                                    |
# |        |                                                    |                                                    |                          </div>                    |                                                    |
# |        |                                                    |                                                    |                                                    |                                                    |
# |        |                                                    |                                                    |                 <div class="copyright">            |                                                    |
# |        |                                                    |                                                    |               <div class="copyright-inner">        |                                                    |
# |        |                                                    |                                                    |           <p style="margin:0;">Copyright © 2026 -  |                                                    |
# |        |                                                    |                                                    | All Rights Reserved - <a href="https://webtestingc |                                                    |
# |        |                                                    |                                                    |      ourse.dequecloud.com/">Gefälscht</a></p>      |                                                    |
# |        |                                                    |                                                    |                <p style="margin:0;">Gefälscht      |                                                    |
# |        |                                                    |                                                    |                   CompuTech</p>                    |                                                    |
# |        |                                                    |                                                    |                           </div>                   |                                                    |
# |        |                                                    |                                                    |                          </div>                    |                                                    |
# |        |                                                    |                                                    |                         </div>                     |                                                    |
# |        |                                                    |                                                    |                      </footer>                     |                                                    |
# |        |                                                    |                                                    |                      </body>                       |                                                    |
# |        |                                                    |                                                    |                      </html>                       |                                                    |
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+

# %%
generate_output_files("gpt-site1", extracted_html, extracted_html_template, extracted_md, extracted_md_template)

# %% [markdown]
# ## Google Gemini 3 Flash
# Let’s examine the result produced by this model.

# %%
extracted_html, extracted_html_template, extracted_md, extracted_md_template = display_extracted_content("gemini-3-flash-preview", all_content_html, all_content_md, html_source="Crawl4ai", markdown_source="Jina AI", site_name="Site 1", template="homepage")
# Out:
# Processing results:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Jina AI for Markdown input:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Jina AI for Markdown input and template:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for HTML input:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for HTML input and template:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracted Content Table:
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# |  Site  |                     From HTML                      |              From HTML with template               |                   From markdown                    |            From markdown with template             |
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# | Site 1 |              Completion tokens: 4,352              |              Completion tokens: 3,955              |              Completion tokens: 4,359              |              Completion tokens: 3,882              |
# |        |                Prompt tokens: 2,800                |                Prompt tokens: 4,875                |                Prompt tokens: 2,725                |                Prompt tokens: 4,800                |
# |        |               Total cost: $0.021456                |               Total cost: $0.026490                |               Total cost: $0.021252                |               Total cost: $0.026046                |
# |        |                                                    |                                                    |                                                    |                                                    |
# |        |                                                    |                                                    |                                                    |                                                    |
# |        |                  <!DOCTYPE html>                   |                  <!DOCTYPE html>                   |                  <!DOCTYPE html>                   |                  <!DOCTYPE html>                   |
# |        |                  <html lang="en">                  |                  <html lang="en">                  |                  <html lang="en">                  |                  <html lang="en">                  |
# |        |                       <head>                       |                       <head>                       |                       <head>                       |                       <head>                       |
# |        |                 <meta charset="utf-8">             |                 <meta charset="UTF-8">             |                 <meta charset="utf-8">             |                 <meta charset="UTF-8">             |
# |        |      <meta name="viewport" content="width=device-  |      <meta name="viewport" content="width=device-  |      <meta name="viewport" content="width=device-  |      <meta name="viewport" content="width=device-  |
# |        |             width, initial-scale=1.0">             |              width, initial-scale=1">              |             width, initial-scale=1.0">             |              width, initial-scale=1">              |
# |        |       <title>Gefälscht CompuTech - Home</title>    |        <title>Gefälscht CompuTech - Accessible     |       <title>Gefälscht CompuTech - Home</title>    |      <title>Gefälscht CompuTech - Computer Parts   |
# |        |         <meta name="robots" content="noindex,      |               Training Site</title>                |         <meta name="robots" content="noindex,      |                and Services</title>                |
# |        |                     nofollow">                     |         <meta name="robots" content="noindex,      |                     nofollow">                     |      <meta name="description" content="Gefälscht   |
# |        |      <script src="https://code.jquery.com/jquery-  |                     nofollow">                     |      <script src="https://code.jquery.com/jquery-  |  CompuTech provides computer parts, supplies, and  |
# |        |              3.7.1.min.js"></script>               |     <link href="https://cdn.jsdelivr.net/npm/boots |                latest.js"></script>                |                in-home services.">                 |
# |        |                        <style>                     |       trap@5.3.3/dist/css/bootstrap.min.css"       |                        <style>                     |              <!-- Bootstrap 5.3.3 CSS -->          |
# |        |         /* Reset and Base Accessibility Styles */  |        rel="stylesheet" integrity="sha384-         |                /* Reset and Base Styles */         |     <link href="https://cdn.jsdelivr.net/npm/boots |
# |        |                           body {                   | QWTKZyjpPEjISv5WaRU9OFeRpok6YctnYmDr5pNlyT2bRjXh0J |               * { box-sizing: border-box; }        |       trap@5.3.3/dist/css/bootstrap.min.css"       |
# |        |              font-family: Arial, Helvetica, sans-  |      MhjY6hW+ALEwIH" crossorigin="anonymous">      |                           body {                   |                 rel="stylesheet">                  |
# |        |                       serif;                       |                        <style>                     |                font-family: Arial, sans-serif;     |                        <style>                     |
# |        |                       line-height: 1.6;            |          /* High contrast and accessibility fixes  |                       line-height: 1.6;            |         /* Skip to main content link for keyboard  |
# |        |                          color: #222;              |                         */                         |                          color: #222;              |                      users */                      |
# |        |                    background-color: #fff;         |                           body {                   |                    background-color: #fff;         |                        .skip-link {                |
# |        |                           margin: 0;               |                    background-color: #fff;         |                           margin: 0;               |                      position: absolute;           |
# |        |                          padding: 0;               |                        color: #212529;             |                          padding: 0;               |                          top: -40px;               |
# |        |                             }                      |                             }                      |                             }                      |                            left: 0;                |
# |        |                                                    |                        .skip-link {                |                         .wrapper {                 |                       background: #000;            |
# |        |                         .sr-only {                 |                      position: absolute;           |                       max-width: 1000px;           |                          color: #fff;              |
# |        |                      position: absolute;           |                          top: -40px;               |                        margin: 0 auto;             |                         padding: 8px;              |
# |        |                          width: 1px;               |                            left: 0;                |                        padding: 0 20px;            |                         z-index: 100;              |
# |        |                          height: 1px;              |                       background: #000;            |                             }                      |                             }                      |
# |        |                          padding: 0;               |                         color: white;              |                         .sr-only {                 |                     .skip-link:focus {             |
# |        |                         margin: -1px;              |                         padding: 8px;              |                      position: absolute;           |                            top: 0;                 |
# |        |                       overflow: hidden;            |                         z-index: 100;              |                          width: 1px;               |                             }                      |
# |        |                    clip: rect(0, 0, 0, 0);         |                             }                      |                          height: 1px;              |           /* Custom styles to maintain original    |
# |        |                      white-space: nowrap;          |                     .skip-link:focus {             |                          padding: 0;               |         theme with accessible contrast */          |
# |        |                           border: 0;               |                            top: 0;                 |                         margin: -1px;              |                           body {                   |
# |        |                             }                      |                             }                      |                       overflow: hidden;            |                   background-color: #f8f9fa;       |
# |        |                                                    |                      .navbar-brand {               |                    clip: rect(0, 0, 0, 0);         |                        color: #212529;             |
# |        |                         .wrapper {                 |                       font-weight: bold;           |                      white-space: nowrap;          |                             }                      |
# |        |                       max-width: 1000px;           |                       font-size: 1.5rem;           |                           border: 0;               |                      .navbar-brand {               |
# |        |                        margin: 0 auto;             |                             }                      |                             }                      |                       font-weight: bold;           |
# |        |                         padding: 20px;             |                      .hero-section {               |                                                    |                       font-size: 1.5rem;           |
# |        |                             }                      |                   background-color: #f8f9fa;       |                      /* Skip Link */               |                             }                      |
# |        |                                                    |                        padding: 3rem 0;            |                        .skip-link {                |                      .hero-section {               |
# |        |                      /* Skip Link */               |               border-bottom: 1px solid #dee2e6;    |                      position: absolute;           |                    background-color: #fff;         |
# |        |                        .skip-link {                |                             }                      |                          top: -40px;               |                        padding: 2rem 0;            |
# |        |                      position: absolute;           |                      .card-img-top {               |                            left: 0;                |               border-bottom: 1px solid #dee2e6;    |
# |        |                          top: -40px;               |                         height: 180px;             |                       background: #000;            |                             }                      |
# |        |                            left: 0;                |                       object-fit: cover;           |                         color: white;              |                      .card-img-top {               |
# |        |                      background: #005a9c;          |                             }                      |                         padding: 8px;              |                         height: 150px;             |
# |        |                         color: white;              |                     .footer-heading {              |                         z-index: 100;              |                       object-fit: cover;           |
# |        |                         padding: 8px;              |                       font-size: 1.1rem;           |                     text-decoration: none;         |                             }                      |
# |        |                         z-index: 100;              |                      margin-bottom: 1rem;          |                             }                      |                     .footer-section {              |
# |        |                     text-decoration: none;         |               border-bottom: 2px solid #dee2e6;    |                .skip-link:focus { top: 0; }        |                   background-color: #e9ecef;       |
# |        |                             }                      |                    padding-bottom: 0.5rem;         |                                                    |                 border-top: 1px solid #dee2e6;     |
# |        |                                                    |                             }                      |                   /* Header & Top Bar */           |                             }                      |
# |        |                     .skip-link:focus {             |                     .pseudolink-btn {              |                          header {                  |         /* Ensure focus indicators are visible */  |
# |        |                            top: 0;                 |                       background: none;            |                        padding: 20px 0;            |            a:focus, button:focus, input:focus {    |
# |        |                             }                      |                         border: none;              |                 border-bottom: 1px solid #ccc;     |             outline: 3px solid #0d6efd !important; |
# |        |                                                    |                        color: #0d6efd;             |                             }                      |                      outline-offset: 2px;          |
# |        |                /* Header and Navigation */         |                  text-decoration: underline;       |                     .header-content {              |                             }                      |
# |        |                          header {                  |                          padding: 0;               |                         display: flex;             |           /* Utility for screen readers only */    |
# |        |                 border-bottom: 2px solid #ccc;     |                        cursor: pointer;            |                justify-content: space-between;     |                     .visually-hidden {             |
# |        |                     padding-bottom: 20px;          |                             }                      |                      align-items: center;          |                 position: absolute !important;     |
# |        |                      margin-bottom: 20px;          |                  .pseudolink-btn:hover {           |                        flex-wrap: wrap;            |                     width: 1px !important;         |
# |        |                             }                      |                        color: #0a58ca;             |                             }                      |                    height: 1px !important;         |
# |        |                                                    |                             }                      |           .logo-area h1 { margin: 0; font-size:    |                     padding: 0 !important;         |
# |        |                       .header-top {                |          /* Ensure contrast for search button */   |                      2rem; }                       |                    margin: -1px !important;        |
# |        |                         display: flex;             |                           #go {                    |           .logo-area a { text-decoration: none;    |                  overflow: hidden !important;      |
# |        |                justify-content: space-between;     |                   background-color: #212529;       |                 color: #0056b3; }                  |               clip: rect(0, 0, 0, 0) !important;   |
# |        |                      align-items: center;          |                          color: #fff;              |                                                    |                white-space: nowrap !important;     |
# |        |                        flex-wrap: wrap;            |                             }                      |                        .top-info {                 |                     border: 0 !important;          |
# |        |                             }                      |               /* Screen reader only class */       |                      background: #f4f4f4;          |                             }                      |
# |        |                                                    |                     .visually-hidden {             |                      padding: 10px 20px;           |                        </style>                    |
# |        |                         .logo h1 {                 |                 position: absolute !important;     |                         display: flex;             |                      </head>                       |
# |        |                           margin: 0;               |                     width: 1px !important;         |                justify-content: space-between;     |                       <body>                       |
# |        |                       font-size: 2.5rem;           |                    height: 1px !important;         |                      align-items: center;          |     <a href="#main-content" class="skip-link">Skip |
# |        |                             }                      |                     padding: 0 !important;         |                        flex-wrap: wrap;            |                to main content</a>                 |
# |        |                                                    |                    margin: -1px !important;        |                             }                      |                                                    |
# |        |                         .logo a {                  |                  overflow: hidden !important;      |          .contact-info { margin: 0; font-weight:   |                        <header>                    |
# |        |                     text-decoration: none;         |               clip: rect(0, 0, 0, 0) !important;   |                      bold; }                       |                   <!-- Top Info Bar -->            |
# |        |                        color: #005a9c;             |                white-space: nowrap !important;     |                                                    |           <div class="bg-dark text-white py-2">    |
# |        |                             }                      |                     border: 0 !important;          |                     /* Search Form */              |                <div class="container d-md-flex     |
# |        |                                                    |                             }                      |           .search-form fieldset { border: none;    |    justify-content-between align-items-center">    |
# |        |                      .contact-info {               |                        </style>                    |              padding: 0; margin: 0; }              |                   <p class="mb-0 small">Tel: <a    |
# |        |                       font-weight: bold;           |                      </head>                       |         .search-form label { margin-right: 5px; }  |  href="tel:703-555-1212" class="text-white text-   |
# |        |                        margin: 10px 0;             |                       <body>                       |             .search-form input[type="text"] {      |    decoration-none">703-555-1212</a> | Mail: <a    |
# |        |                             }                      |     <a class="skip-link" href="#main-content">Skip |                         padding: 5px;              |   href="mailto:info@deque.com" class="text-white   |
# |        |                                                    |                to main content</a>                 |                   border: 1px solid #767676;       |    text-decoration-none">info@deque.com</a></p>    |
# |        |                     /* Search Form */              |                                                    |                      border-radius: 4px;           |                 <form action="https://webtestingco |
# |        |                       .search-form {               |                        <header>                    |                             }                      |    urse.dequecloud.com/search.php" method="get"    |
# |        |                        margin: 10px 0;             |            <nav class="navbar navbar-expand-lg     |            .search-form input[type="submit"] {     |     class="d-flex mt-2 mt-md-0" role="search">     |
# |        |                             }                      | navbar-dark bg-dark" aria-label="Main Navigation"> |                       padding: 5px 15px;           |                        <label for="site-search"    |
# |        |                                                    |                    <div class="container">         |                      background: #0056b3;          |  class="visually-hidden">Search the site</label>   |
# |        |                  .search-form fieldset {           |                 <a class="navbar-brand" href="http |                          color: #fff;              |                     <input type="search" name="q"  |
# |        |                         border: none;              |  s://webtestingcourse.dequecloud.com/">Gefälscht   |                         border: none;              | id="site-search" class="form-control form-control- |
# |        |                          padding: 0;               |                   CompuTech</a>                    |                      border-radius: 4px;           |      sm me-2" placeholder="Search the site…">      |
# |        |                           margin: 0;               |                   <button class="navbar-toggler"   |                        cursor: pointer;            |                         <button type="submit"      |
# |        |                             }                      |  type="button" data-bs-toggle="collapse" data-bs-  |                             }                      |     class="btn btn-primary btn-sm">GO</button>     |
# |        |                                                    |   target="#navbarNav" aria-controls="navbarNav"    |         .search-form input[type="submit"]:hover {  |                              </form>               |
# |        |             .search-form input[type="text"] {      |      aria-expanded="false" aria-label="Toggle      |               background: #004494; }               |                             </div>                 |
# |        |                         padding: 8px;              |                    navigation">                    |                                                    |                           </div>                   |
# |        |                   border: 1px solid #767676;       |                      <span class="navbar-toggler-  |                      /* Navigation */              |                                                    |
# |        |                      border-radius: 4px;           |                   icon"></span>                    |             nav#main-nav { background: #333; }     |                    <!-- Navigation -->             |
# |        |                       min-width: 200px;            |                             </button>              |                     nav#main-nav ul {              |            <nav class="navbar navbar-expand-lg     |
# |        |                             }                      |                    <div class="collapse navbar-    |                       list-style: none;            | navbar-light bg-light shadow-sm" aria-label="Main  |
# |        |                                                    |             collapse" id="navbarNav">              |                           margin: 0;               |                    Navigation">                    |
# |        |            .search-form input[type="submit"] {     |                       <ul class="navbar-nav ms-    |                          padding: 0;               |                    <div class="container">         |
# |        |                       padding: 8px 16px;           |                       auto">                       |                         display: flex;             |                 <a class="navbar-brand" href="http |
# |        |                   background-color: #005a9c;       |                          <li class="nav-item"><a   |                        flex-wrap: wrap;            |  s://webtestingcourse.dequecloud.com/">Gefälscht   |
# |        |                         color: white;              | class="nav-link active" aria-current="page" href=" |                             }                      |     <span class="fw-normal fs-6 d-block d-sm-      |
# |        |                         border: none;              | https://webtestingcourse.dequecloud.com/index.php" |         nav#main-nav li { border-right: 1px solid  |            inline">CompuTech</span></a>            |
# |        |                      border-radius: 4px;           |                   >Home</a></li>                   |                      #444; }                       |                   <button class="navbar-toggler"   |
# |        |                        cursor: pointer;            |                          <li class="nav-item"><a   |                      nav#main-nav a {              |  type="button" data-bs-toggle="collapse" data-bs-  |
# |        |                             }                      | class="nav-link" href="https://webtestingcourse.de |                        display: block;             |   target="#navbarNav" aria-controls="navbarNav"    |
# |        |                                                    |   quecloud.com/laptopsandnotebooks.php">Laptops    |                      padding: 15px 20px;           |      aria-expanded="false" aria-label="Toggle      |
# |        |         .search-form input[type="submit"]:hover {  |              &amp; Notebooks</a></li>              |                          color: #fff;              |                    navigation">                    |
# |        |                   background-color: #004477;       |                          <li class="nav-item"><a   |                     text-decoration: none;         |                      <span class="navbar-toggler-  |
# |        |                             }                      | class="nav-link" href="https://webtestingcourse.de |                       font-weight: bold;           |                   icon"></span>                    |
# |        |                                                    |    quecloud.com/desktops.php">Desktops</a></li>    |                             }                      |                             </button>              |
# |        |                      /* Navigation */              |                          <li class="nav-item"><a   |         nav#main-nav a:hover, nav#main-nav a:focus |                    <div class="collapse navbar-    |
# |        |                          nav ul {                  | class="nav-link" href="https://webtestingcourse.de |                         {                          |             collapse" id="navbarNav">              |
# |        |                       list-style: none;            |        quecloud.com/cart.php">Cart</a></li>        |                       background: #555;            |                       <ul class="navbar-nav ms-    |
# |        |                          padding: 0;               |                          <li class="nav-item"><a   |                  text-decoration: underline;       |                       auto">                       |
# |        |                         display: flex;             | class="nav-link" href="https://webtestingcourse.de |                             }                      |                          <li class="nav-item"><a   |
# |        |                        flex-wrap: wrap;            |     quecloud.com/support.php">Support</a></li>     |            nav#main-nav .active a { background:    | class="nav-link active" aria-current="page" href=" |
# |        |                       background: #333;            |                          <li class="nav-item"><a   |                     #0056b3; }                     | https://webtestingcourse.dequecloud.com/index.php" |
# |        |                             }                      | class="nav-link" href="https://webtestingcourse.de |                                                    |                   >Home</a></li>                   |
# |        |                                                    |     quecloud.com/contact.php">Contact</a></li>     |                    /* Intro Section */             |                          <li class="nav-item"><a   |
# |        |                        nav ul li {                 |                                 </ul>              |                          #intro {                  | class="nav-link" href="https://webtestingcourse.de |
# |        |                           margin: 0;               |                               </div>               |                         display: flex;             |   quecloud.com/laptopsandnotebooks.php">Laptops    |
# |        |                             }                      |                             </div>                 |                           gap: 20px;               |              &amp; Notebooks</a></li>              |
# |        |                                                    |                           </nav>                   |                        padding: 30px 0;            |                          <li class="nav-item"><a   |
# |        |                       nav ul li a {                |                                                    |                    align-items: flex-start;        | class="nav-link" href="https://webtestingcourse.de |
# |        |                        display: block;             |         <div class="bg-light py-2 border-bottom">  |                             }                      |    quecloud.com/desktops.php">Desktops</a></li>    |
# |        |                      padding: 15px 20px;           |             <div class="container d-flex flex-wrap |                        #intro img {                |                          <li class="nav-item"><a   |
# |        |                         color: white;              |    justify-content-between align-items-center">    |                       max-width: 450px;            | class="nav-link" href="https://webtestingcourse.de |
# |        |                     text-decoration: none;         |                    <p class="mb-0 me-3">Tel: <a    |                         height: auto;              |        quecloud.com/cart.php">Cart</a></li>        |
# |        |                       font-weight: bold;           | href="tel:7035551212">703-555-1212</a> | Mail: <a  |                    border: 1px solid #ccc;         |                          <li class="nav-item"><a   |
# |        |                             }                      | href="mailto:info@deque.com">info@deque.com</a></p |                             }                      | class="nav-link" href="https://webtestingcourse.de |
# |        |                                                    |                         >                          |                  .intro-text { flex: 1; }          |     quecloud.com/support.php">Support</a></li>     |
# |        |           nav ul li a:hover, nav ul li a:focus {   |                 <form action="https://webtestingco |                                                    |                          <li class="nav-item"><a   |
# |        |                    background-color: #555;         |    urse.dequecloud.com/search.php" method="get"    |                  /* Home Content Grid */           | class="nav-link" href="https://webtestingcourse.de |
# |        |                  text-decoration: underline;       |           class="d-flex" role="search">            |                     #homecontent ul {              |     quecloud.com/contact.php">Contact</a></li>     |
# |        |                             }                      |                        <label for="site-search"    |                       list-style: none;            |                                 </ul>              |
# |        |                                                    |  class="visually-hidden">Search the site</label>   |                          padding: 0;               |                               </div>               |
# |        |                    nav ul li.active a {            |                     <input type="search" name="q"  |                         display: grid;             |                             </div>                 |
# |        |                   background-color: #005a9c;       | id="site-search" class="form-control form-control- |              grid-template-columns: repeat(auto-   |                           </nav>                   |
# |        |                             }                      |      sm me-2" placeholder="Search the site…">      |             fit, minmax(300px, 1fr));              |                       </header>                    |
# |        |                                                    |                     <button type="submit" id="go"  |                           gap: 20px;               |                                                    |
# |        |                    /* Intro Section */             |      class="btn btn-sm btn-dark">GO</button>       |                        margin: 40px 0;             |                <main id="main-content">            |
# |        |                          .intro {                  |                              </form>               |                             }                      |                   <!-- Hero Section -->            |
# |        |                         display: flex;             |                             </div>                 |                     #homecontent li {              |            <section class="hero-section" aria-     |
# |        |                           gap: 30px;               |                           </div>                   |                    border: 1px solid #eee;         |           labelledby="welcome-heading">            |
# |        |                      margin-bottom: 40px;          |                       </header>                    |                         padding: 15px;             |                    <div class="container">         |
# |        |                      align-items: center;          |                                                    |                      background: #fafafa;          |                    <div class="row align-items-    |
# |        |                        flex-wrap: wrap;            |                <main id="main-content">            |                             }                      |                      center">                      |
# |        |                             }                      |               <section class="hero-section">       |          #homecontent h2 { margin-top: 0; color:   |                     <div class="col-md-6 mb-4 mb-  |
# |        |                                                    |                    <div class="container">         |                      #333; }                       |                       md-0">                       |
# |        |                        .intro img {                |                    <div class="row align-items-    |                          .imgl {                   |                         <img src="https://webtesti |
# |        |                        max-width: 100%;            |                      center">                      |                          float: left;              | ngcourse.dequecloud.com/images/site/homeLanding.jp |
# |        |                         height: auto;              |                     <div class="col-md-5 mb-4 mb-  |                     margin: 0 15px 10px 0;         |  g" class="img-fluid rounded shadow" alt="Modern   |
# |        |                      border-radius: 8px;           |                 md-0 text-center">                 |                    border: 1px solid #ddd;         |  computer workstation setup with dual monitors">   |
# |        |                             }                      |                         <img src="https://webtesti |                             }                      |                                 </div>             |
# |        |                                                    | ngcourse.dequecloud.com/images/site/homeLanding.jp |                       .readmore a {                |                         <div class="col-md-6">     |
# |        |                       .intro-text {                |    g" alt="A modern workspace with a laptop and    |                       font-weight: bold;           |                              <h1 id="welcome-      |
# |        |                            flex: 1;                |   computer components" class="img-fluid rounded    |                        color: #0056b3;             |    heading">Welcome to Gefälscht CompuTech</h1>    |
# |        |                       min-width: 300px;            |                      shadow">                      |                  text-decoration: underline;       |                                     <p             |
# |        |                             }                      |                                 </div>             |                             }                      |    class="lead"><em>Gefälscht</em> - German for    |
# |        |                                                    |                         <div class="col-md-7">     |                                                    |                    "Fake".</p>                     |
# |        |                  /* Home Content Grid */           |                          <h1 class="display-5 fw-  |                    /* Image Gallery */             |                         <p>This is a demonstration |
# |        |                        .home-grid {                |     bold">Welcome to Gefälscht CompuTech</h1>      |                        #imageline {                | website created by Deque Systems for accessibility |
# |        |                         display: grid;             |                                     <p             |                        padding: 20px 0;            | training. It serves as a controlled environment to |
# |        |              grid-template-columns: repeat(auto-   |   class="lead"><em>Gefälscht</em> is German for    |                  border-top: 1px solid #eee;       |  identify and learn from common web accessibility  |
# |        |             fit, minmax(280px, 1fr));              |                    "Fake".</p>                     |                             }                      |   barriers. While this specific version has been   |
# |        |                           gap: 20px;               |                         <p>This is a demonstration |                      #imageline ul {               |  remediated for compliance, the original content   |
# |        |                       list-style: none;            | website created by Deque Systems for accessibility |                       list-style: none;            | highlights how <strong>not</strong> to design for  |
# |        |                          padding: 0;               | training. It serves as a controlled environment to |                          padding: 0;               |                    the web.</p>                    |
# |        |                      margin-bottom: 40px;          | identify and learn about common web accessibility  |                         display: flex;             |                               <p>If you need       |
# |        |                             }                      |  barriers. Unlike the original version, this page  |                justify-content: space-between;     | professional accessibility testing or consulting,  |
# |        |                                                    | has been corrected to meet WCAG 2.2 standards.</p> |                           gap: 10px;               |       please <a href="http://www.deque.com"        |
# |        |                      .home-grid li {               |                               <p>If you need       |                        flex-wrap: wrap;            |    target="_blank" rel="noopener">contact Deque    |
# |        |                    border: 1px solid #ddd;         |  professional accessibility testing or training,   |                             }                      |                  Systems</a>.</p>                  |
# |        |                         padding: 20px;             |  please visit the <a href="http://www.deque.com"   |                      #imageline img {              |                                 </div>             |
# |        |                      border-radius: 8px;           |   target="_blank" rel="noopener">official Deque    |                    border: 1px solid #ccc;         |                               </div>               |
# |        |                             }                      |              Systems website</a>.</p>              |                        max-width: 100%;            |                             </div>                 |
# |        |                                                    |                                 </div>             |                         height: auto;              |                         </section>                 |
# |        |                      .home-grid img {              |                               </div>               |                        display: block;             |                                                    |
# |        |                          float: left;              |                             </div>                 |                             }                      |                 <!-- Services Section -->          |
# |        |                     margin: 0 15px 10px 0;         |                         </section>                 |                                                    |                <section class="py-5" aria-         |
# |        |                          width: 60px;              |                                                    |                        /* Footer */                |           labelledby="services-heading">           |
# |        |                         height: 60px;              |                   <section class="py-5">           |                          footer {                  |                    <div class="container">         |
# |        |                             }                      |                    <div class="container">         |                       background: #333;            |                     <h2 id="services-heading"      |
# |        |                                                    |                       <div class="row g-4">        |                          color: #eee;              |     class="visually-hidden">Our Services</h2>      |
# |        |                       .readmore a {                |                         <div class="col-md-4">     |                     padding: 40px 0 20px;          |                       <div class="row g-4">        |
# |        |                        color: #005a9c;             |                           <div class="card h-100   |                       margin-top: 40px;            |                         <div class="col-md-4">     |
# |        |                       font-weight: bold;           |                border-0 shadow-sm">                |                             }                      |                         <article class="card h-100 |
# |        |                             }                      |                             <img src="https://webt |                       .footer-grid {               |                border-0 shadow-sm">                |
# |        |                                                    |  estingcourse.dequecloud.com/images/site/small60-  |                         display: grid;             |                             <img src="https://webt |
# |        |                    /* Image Gallery */             | 1.jpg" class="card-img-top" alt="Computer circuit  |              grid-template-columns: repeat(auto-   |  estingcourse.dequecloud.com/images/site/small60-  |
# |        |                       .image-line {                |                   board parts">                    |             fit, minmax(180px, 1fr));              | 1.jpg" class="card-img-top" alt="Assorted computer |
# |        |                         display: flex;             |                               <div class="card-    |                           gap: 20px;               |               hardware components">                |
# |        |                justify-content: space-between;     |                       body">                       |                      margin-bottom: 30px;          |                               <div class="card-    |
# |        |                        flex-wrap: wrap;            |                                   <h2 class="h4    |                             }                      |                       body">                       |
# |        |                           gap: 10px;               |        card-title">Parts and Supplies</h2>         |                       .footbox h2 {                |                                   <h3 class="h5    |
# |        |                      margin-bottom: 40px;          |                                  <p class="card-   |                       font-size: 1.1rem;           |        card-title">Parts and Supplies</h3>         |
# |        |                          padding: 0;               |     text">We sell parts and supplies for every     |                          color: #fff;              |                                  <p class="card-   |
# |        |                       list-style: none;            |  computer we sell and even some that we don't. If  |                 border-bottom: 1px solid #555;     |     text">We sell parts and supplies for every     |
# ...
# |        | stingcourse.dequecloud.com/desktop2.php">Rindviech |                                                    |        shopping cart for current items and         |                                                    |
# |        |                  er 1000</a></li>                  |                                                    |                 checkout.</a></li>                 |                                                    |
# |        |                         <li><a href="https://webte |                                                    |                                 </ul>              |                                                    |
# |        | stingcourse.dequecloud.com/desktop3.php">Verrottet |                                                    |                             </section>             |                                                    |
# |        |                    875</a></li>                    |                                                    |                     <section class="footbox">      |                                                    |
# |        |                                 </ul>              |                                                    |                            <h2>Support</h2>        |                                                    |
# |        |                               </nav>               |                                                    |                                  <ul>              |                                                    |
# |        |                     <nav class="footbox" aria-     |                                                    |                         <li><a href="https://webte |                                                    |
# |        |           labelledby="footer-materials">           |                                                    |    stingcourse.dequecloud.com/support.php">Get     |                                                    |
# |        |                     <h2 id="footer-materials">Test |                                                    | answers to all of your technical support questions |                                                    |
# |        |               Course Materials</h2>                |                                                    |                   here.</a></li>                   |                                                    |
# |        |                                  <ul>              |                                                    |                                 </ul>              |                                                    |
# |        |                         <li><a href="https://webte |                                                    |                             </section>             |                                                    |
# |        | stingcourse.dequecloud.com/dragoncheatsheet.php">D |                                                    |                             </div>                 |                                                    |
# |        |             ragon Cheat Sheet</a></li>             |                                                    |                      <div id="copyright">          |                                                    |
# |        |                         <li><a href="https://webte |                                                    |                   <p>Copyright &copy; 2026 - All   |                                                    |
# |        | stingcourse.dequecloud.com/jawscheatsheet.php">JAW |                                                    | Rights Reserved - <a href="https://webtestingcours |                                                    |
# |        |               S Cheat Sheet</a></li>               |                                                    |        e.dequecloud.com/">Gefälscht</a></p>        |                                                    |
# |        |                         <li><a href="https://webte |                                                    |                     <p>Gefälscht CompuTech</p>     |                                                    |
# |        | stingcourse.dequecloud.com/sampletestcasetemplate. |                                                    |                             </div>                 |                                                    |
# |        |      php">Sample Test Case Template</a></li>       |                                                    |                           </div>                   |                                                    |
# |        |                         <li><a href="https://webte |                                                    |                       </footer>                    |                                                    |
# |        | stingcourse.dequecloud.com/sampleissuetemplate.php |                                                    |                      </body>                       |                                                    |
# |        |          ">Sample Issue Template</a></li>          |                                                    |                      </html>                       |                                                    |
# |        |                                <li><button         |                                                    |                                                    |                                                    |
# |        | class="pseudolink" onclick="window.location.href=' |                                                    |                                                    |                                                    |
# |        | https://webtestingcourse.dequecloud.com/photocredi |                                                    |                                                    |                                                    |
# |        |        ts.php'">Photo Credits</button></li>        |                                                    |                                                    |                                                    |
# |        |                                 </ul>              |                                                    |                                                    |                                                    |
# |        |                               </nav>               |                                                    |                                                    |                                                    |
# |        |                       <div class="footbox">        |                                                    |                                                    |                                                    |
# |        |                             <h2>Cart</h2>          |                                                    |                                                    |                                                    |
# |        |                                  <ul>              |                                                    |                                                    |                                                    |
# |        |                         <li><a href="https://webte |                                                    |                                                    |                                                    |
# |        |   stingcourse.dequecloud.com/cart.php">View your   |                                                    |                                                    |                                                    |
# |        |       shopping cart to manage your selected        |                                                    |                                                    |                                                    |
# |        |                  items.</a></li>                   |                                                    |                                                    |                                                    |
# |        |                                 </ul>              |                                                    |                                                    |                                                    |
# |        |                               </div>               |                                                    |                                                    |                                                    |
# |        |                       <div class="footbox">        |                                                    |                                                    |                                                    |
# |        |                            <h2>Support</h2>        |                                                    |                                                    |                                                    |
# |        |                                  <ul>              |                                                    |                                                    |                                                    |
# |        |                         <li><a href="https://webte |                                                    |                                                    |                                                    |
# |        |    stingcourse.dequecloud.com/support.php">Get     |                                                    |                                                    |                                                    |
# |        |    answers to technical questions and hardware     |                                                    |                                                    |                                                    |
# |        |                 support.</a></li>                  |                                                    |                                                    |                                                    |
# |        |                                 </ul>              |                                                    |                                                    |                                                    |
# |        |                               </div>               |                                                    |                                                    |                                                    |
# |        |                             </div>                 |                                                    |                                                    |                                                    |
# |        |                    <div class="copyright">         |                                                    |                                                    |                                                    |
# |        |                   <p>Copyright &copy; 2026 - All   |                                                    |                                                    |                                                    |
# |        | Rights Reserved - <a href="https://webtestingcours |                                                    |                                                    |                                                    |
# |        |        e.dequecloud.com/">Gefälscht</a></p>        |                                                    |                                                    |                                                    |
# |        |                     <p>Gefälscht CompuTech</p>     |                                                    |                                                    |                                                    |
# |        |                             </div>                 |                                                    |                                                    |                                                    |
# |        |                         </footer>                  |                                                    |                                                    |                                                    |
# |        |                         </div>                     |                                                    |                                                    |                                                    |
# |        |                                                    |                                                    |                                                    |                                                    |
# |        |                        <script>                    |                                                    |                                                    |                                                    |
# |        |               $(document).ready(function() {       |                                                    |                                                    |                                                    |
# |        |              // Apply zebra striping to any data   |                                                    |                                                    |                                                    |
# |        |                    tables found                    |                                                    |                                                    |                                                    |
# |        |                   $('table.data_table tbody        |                                                    |                                                    |                                                    |
# |        |           tr:odd').addClass('odd_row');            |                                                    |                                                    |                                                    |
# |        |                   $('table.data_table tbody        |                                                    |                                                    |                                                    |
# |        |          tr:even').addClass('even_row');           |                                                    |                                                    |                                                    |
# |        |                            });                     |                                                    |                                                    |                                                    |
# |        |                       </script>                    |                                                    |                                                    |                                                    |
# |        |                      </body>                       |                                                    |                                                    |                                                    |
# |        |                      </html>                       |                                                    |                                                    |                                                    |
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+

# %%
generate_output_files("gemini-site1", extracted_html, extracted_html_template, extracted_md, extracted_md_template)

# %% [markdown]
# ---
# ## Evaluation of the Results
#
# The generated outputs are located in the `output` folder. We now need to use the WAVE and Lighthouse tools to evaluate accessibility, following the WCAG-EM methodology. The results from these evaluations should be recorded accordingly.

# %% [markdown]
# ### Paso 1: DataFrame construction

# %%
# Paso 1: Estructura de costos con claves únicas
costs = {
    "GPT_Site1_html": {"ptokens": 2664, "ctokens": 4832, "cost": 0.013118 , "time": 46.17},
    "GPT_Site1_html_template": {"ptokens": 4771, "ctokens": 4322, "cost": 0.015913 , "time": 49.45},
    "GPT_Site1_md": {"ptokens": 2612, "ctokens": 4987, "cost": 0.013298, "time": 59.12},
    "GPT_Site1_md_template": {"ptokens": 4719, "ctokens": 4147, "cost": 0.021456, "time": 46.68},

    "Gem_Site1_html": {"ptokens": 2800, "ctokens": 4352, "cost": 0.016430, "time": 43.01},
    "Gem_Site1_html_template": {"ptokens": 4875, "ctokens": 3955, "cost": 0.026490, "time": 26.92},
    "Gem_Site1_md": {"ptokens": 2725, "ctokens": 4359, "cost": 0.021252, "time": 26.84},
    "Gem_Site1_md_template": {"ptokens": 4800, "ctokens": 3882, "cost": 0.026046, "time": 21.29},
}

# Paso 2: Calcular y agregar TotalTokens
for entry in costs.values():
    entry["totaltokens"] = entry["ptokens"] + entry["ctokens"]

# %%
# !pip install pandas --quiet

# %% [markdown]
# ### Accessibility Evaluation with tools
#
# #### Original Site
#
# <center><img src="images/original-eval.jpg" style="margin:auto; width:40%"/></center>

# %%
# Puntos base de referencia (originales sin remediar)
original_lighthouse_scores = {
    'Site 1': 50
}

original_axe_issues = {
    'Site 1': 50
}

original_wave_metrics = {
    'Site 1': {'WAVEAim': 4.7, 'WAVEErrors': 9, 'WAVEContrastErrors': 13, 'WAVEAlerts': 8, 'WAVEFeatures': 3}
}

# %% [markdown]
# #### Site after model application

# %% [markdown]
# #### GPT-4o with Lighthouse
#
# <center><img src="images/gpt-lh-eval.jpg" style="margin:auto; width:60%"/></center>

# %% [markdown]
# #### GPT-4o with Axe
#
# <center><img src="images/gpt-axe-eval.jpg" style="margin:auto; width:60%"/></center>

# %% [markdown]
# #### GPT-4o with WAVE
#
# <center><img src="images/gpt-wave-eval.jpg" style="margin:auto; width:60%"/></center>

# %% [markdown]
# #### Gemini with LightHouse
#
# <center><img src="images/gem-lh-eval.jpg" style="margin:auto; width:60%"/></center>

# %% [markdown]
# #### Gemini with Axe
#
# <center><img src="images/gem-axe-eval.jpg" style="margin:auto; width:60%"/></center>

# %% [markdown]
# #### Gemini with WAVE
#
# <center><img src="images/gem-wave-eval.jpg" style="margin:auto; width:60%"/></center>

# %%
import pandas as pd

# Lista de combinaciones que vamos a mapear a mano (modelo, sitio, entrada, template, otras métricas)
combinations = [
    # Model, Site, InputType, TemplateUsed, AccessibilityScore, Axe Issues, WAVE Aim, WAVE Errors, Contrast, Alerts, Features, cost_key
    ['GPT-4o', 'Site 1', 'HTML', 'No', 100, 0, 9.9, 0, 0, 5, 14, 'GPT_Site1_html'],
    ['GPT-4o', 'Site 1', 'HTML', 'Yes', 96, 1, 9.6, 0, 1, 5, 13, 'GPT_Site1_html_template'],
    ['GPT-4o', 'Site 1', 'Markdown', 'No', 100, 0, 9.9, 0, 0, 5, 14, 'GPT_Site1_md'],
    ['GPT-4o', 'Site 1', 'Markdown', 'Yes', 96, 3, 8.3, 0, 3, 8, 14, 'GPT_Site1_md_template'],

    ['Gemini', 'Site 1', 'HTML', 'No', 96, 11, 6.0, 0, 11, 3, 14, 'Gem_Site1_html'],
    ['Gemini', 'Site 1', 'HTML', 'Yes', 96, 3, 8.4, 0, 3, 3, 13, 'Gem_Site1_html_template'],
    ['Gemini', 'Site 1', 'Markdown', 'No', 98, 1, 9.9, 0, 0, 4, 14, 'Gem_Site1_md'],
    ['Gemini', 'Site 1', 'Markdown', 'Yes', 100, 0, 9.9, 0, 0, 3, 13, 'Gem_Site1_md_template']
]

# Construir data list a partir de combinaciones y costos
data = []
for row in combinations:
    model, site, input_type, template, score, issues, aim, err, contrast, alerts, features, key = row
    tokens = costs[key]
    data.append([
        model, site, input_type, template,
        score, 
        issues, # Axe issues
        err + contrast + alerts, # Wave issues
        aim, err, contrast, alerts, features,
        tokens['ptokens'], tokens['ctokens'], tokens['totaltokens'], tokens['cost'], tokens['time']
    ])

columns = [
    'Model', 'Site', 'InputType', 'TemplateUsed',
    'AccessibilityScore',
    'AxeIssues',
    'WAVEIssues',
    'WAVEAim', 'WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures',
    'PromptTokens', 'CompletionTokens', 'TotalTokens', 'TotalCost', 'TotalTime' 
]

# Crear el DataFrame
df = pd.DataFrame(data, columns=columns)

# Mostrar el DataFrame completo
pd.set_option('display.width', 800)
print(df)

# Opcional: guardar el CSV
# df.to_csv('results_summary_fullwave.csv', index=False)
# Out:
#     Model    Site InputType TemplateUsed  AccessibilityScore  AxeIssues  WAVEIssues  WAVEAim  WAVEErrors  WAVEContrastErrors  WAVEAlerts  WAVEFeatures  PromptTokens  CompletionTokens  TotalTokens  TotalCost  TotalTime
# 0  GPT-4o  Site 1      HTML           No                 100          0           5      9.9           0                   0           5            14          2664              4832         7496   0.013118      46.17
# 1  GPT-4o  Site 1      HTML          Yes                  96          1           6      9.6           0                   1           5            13          4771              4322         9093   0.015913      49.45
# 2  GPT-4o  Site 1  Markdown           No                 100          0           5      9.9           0                   0           5            14          2612              4987         7599   0.013298      59.12
# 3  GPT-4o  Site 1  Markdown          Yes                  96          3          11      8.3           0                   3           8            14          4719              4147         8866   0.021456      46.68
# 4  Gemini  Site 1      HTML           No                  96         11          14      6.0           0                  11           3            14          2800              4352         7152   0.016430      43.01
# 5  Gemini  Site 1      HTML          Yes                  96          3           6      8.4           0                   3           3            13          4875              3955         8830   0.026490      26.92
# 6  Gemini  Site 1  Markdown           No                  98          1           4      9.9           0                   0           4            14          2725              4359         7084   0.021252      26.84
# 7  Gemini  Site 1  Markdown          Yes                 100          0           3      9.9           0                   0           3            13          4800              3882         8682   0.026046      21.29

# %%
# !pip install scipy --quiet

# %%
import numpy as np
import pandas as pd
from scipy import stats

# Este es con los datos del sitio original

# ---- 1) Construir la(s) fila(s) "Original" y anexarlas al df ----
rows = []
for site, score in original_lighthouse_scores.items():
    wm = original_wave_metrics.get(site, {})
    row = {
        'Model': 'Original',
        'Site': site,
        'InputType': 'Original',
        'TemplateUsed': None,

        # Asumimos que AccessibilityScore = Lighthouse (ajústalo si tu métrica es otra)
        'AccessibilityScore': score,

        'AxeIssues': original_axe_issues.get(site, np.nan),

        # Definimos WAVEIssues como la suma de errores + contrast + alerts (ajústalo si usas otra convención)
        'WAVEIssues': sum(wm.get(k, 0) for k in ['WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts']),
        'WAVEAim': wm.get('WAVEAim', np.nan),
        'WAVEErrors': wm.get('WAVEErrors', np.nan),
        'WAVEContrastErrors': wm.get('WAVEContrastErrors', np.nan),
        'WAVEAlerts': wm.get('WAVEAlerts', np.nan),
        'WAVEFeatures': wm.get('WAVEFeatures', np.nan),

        # La página original no usa LLM: ponemos NaN para no sesgar correlaciones
        'PromptTokens': np.nan,
        'CompletionTokens': np.nan,
        'TotalTokens': np.nan,
        'TotalCost': np.nan,
        'TotalTime': np.nan,
    }
    rows.append(row)

orig_df = pd.DataFrame(rows, columns=columns)
df_with_orig = pd.concat([orig_df, df], ignore_index=True)

# Mostrar el DataFrame completo
pd.set_option('display.width', 800)
print(df_with_orig)
# Out:
#       Model    Site InputType TemplateUsed  AccessibilityScore  AxeIssues  WAVEIssues  WAVEAim  WAVEErrors  WAVEContrastErrors  WAVEAlerts  WAVEFeatures  PromptTokens  CompletionTokens  TotalTokens  TotalCost  TotalTime
# 0  Original  Site 1  Original         None                  50         50          30      4.7           9                  13           8             3           NaN               NaN          NaN        NaN        NaN
# 1    GPT-4o  Site 1      HTML           No                 100          0           5      9.9           0                   0           5            14        2664.0            4832.0       7496.0   0.013118      46.17
# 2    GPT-4o  Site 1      HTML          Yes                  96          1           6      9.6           0                   1           5            13        4771.0            4322.0       9093.0   0.015913      49.45
# 3    GPT-4o  Site 1  Markdown           No                 100          0           5      9.9           0                   0           5            14        2612.0            4987.0       7599.0   0.013298      59.12
# 4    GPT-4o  Site 1  Markdown          Yes                  96          3          11      8.3           0                   3           8            14        4719.0            4147.0       8866.0   0.021456      46.68
# 5    Gemini  Site 1      HTML           No                  96         11          14      6.0           0                  11           3            14        2800.0            4352.0       7152.0   0.016430      43.01
# 6    Gemini  Site 1      HTML          Yes                  96          3           6      8.4           0                   3           3            13        4875.0            3955.0       8830.0   0.026490      26.92
# 7    Gemini  Site 1  Markdown           No                  98          1           4      9.9           0                   0           4            14        2725.0            4359.0       7084.0   0.021252      26.84
# 8    Gemini  Site 1  Markdown          Yes                 100          0           3      9.9           0                   0           3            13        4800.0            3882.0       8682.0   0.026046      21.29

# %% [markdown]
# ### Step 2: Apply Statistical Analysis
#
# Once the final `df` is ready, you can perform the full statistical analysis:
#
#  - Descriptive statistics
#  - Shapiro-Wilk normality tests
#  - T-tests / Wilcoxon comparisons
#  - Spearman correlations
#  - Boxplots and scatterplots (accessibility, tokens, etc.)
#
# ---
#
# **In simple terms:**
#
# | Method               | What does it tell us?                     | How do we use it?                          |
# |:---------------------|:------------------------------------------|:-------------------------------------------|
# | **p-value**          | Whether a result is real or by chance     | Comes from all statistical tests           |
# | **Mann-Whitney U**   | Compares two groups                       | e.g., Are GPT-4o and Gemini significantly different? |
# | **Spearman correlation** | Measures relationship between variables | e.g., Do more tokens mean better scores?   |
# | **Descriptive statistics** | Summarizes data behavior             | e.g., How high or variable are the scores? |

# %% [markdown]
# **What is a p-value?**
#
# - The **p-value** helps us decide **whether a difference or relationship is real or just happened by chance**.
# - **In simple terms**: The p-value tells you **how likely** it is to observe those results **if there were actually no difference**.
#
# **How do we interpret it?**
# - If the **p-value is small** (typically **less than 0.05**), it suggests that the **difference or relationship is likely real**.
# - If the **p-value is large** (greater than or equal to 0.05), the result **might have happened by chance**, and **we cannot conclude that the difference is real**.
#
# | p-value | What does it mean? |
# |:--------|:-------------------|
# | < 0.05  | The difference or relationship **is statistically significant** (unlikely to be due to chance). |
# | ≥ 0.05  | **Not enough evidence** to claim the difference or relationship is real. |
#
# **Simple example**:
# You flip a coin 100 times. If it lands on heads 95 times, the p-value would be very low → something unusual is happening. It's unlikely to be random, so it's considered significant.

# %% [markdown]
# ### 1. Descriptive Analysis
#
# First, we get basic statistics.
#
# - It's just a summary of **how big or small** the values of a variable are.
# - It includes:
#   - **Mean**: the average value.
#   - **Standard Deviation (std)**: how much the data varies (are values close together or widely spread?).
#   - **Min**: the smallest value.
#   - **Max**: the largest value.
#   - **Percentiles (25%, 50%, 75%)**: to see where most of the values are concentrated.
#
# **Put simply**:
# > These are **quick summaries** of the data: "Are the values high or low? Are they all similar, or very different?"

# %%
# !pip install seaborn --quiet

# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# Asegúrate de tener cargado tu DataFrame df
# con las columnas nuevas actualizadas

# 1. Descriptive statistics
print("Descriptive Statistics:\n")
print(df[['AccessibilityScore', 'AxeIssues', 'WAVEIssues', 'WAVEAim', 'WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures',
          'PromptTokens', 'CompletionTokens', 'TotalTokens', 'TotalCost', 'TotalTime']].describe())
# Out:
# Descriptive Statistics:
#
#        AccessibilityScore  AxeIssues  WAVEIssues   WAVEAim  WAVEErrors  WAVEContrastErrors  WAVEAlerts  WAVEFeatures  PromptTokens  CompletionTokens  TotalTokens  TotalCost  TotalTime
# count            8.000000   8.000000    8.000000  8.000000         8.0            8.000000    8.000000      8.000000      8.000000           8.00000     8.000000   8.000000   8.000000
# mean            97.750000   2.375000    6.750000  8.987500         0.0            2.250000    4.500000     13.625000   3745.750000        4354.50000  8100.250000   0.019250  39.935000
# std              1.982062   3.700869    3.770184  1.386092         0.0            3.770184    1.690309      0.517549   1119.754278         388.23005   844.410657   0.005340  13.314496
# min             96.000000   0.000000    3.000000  6.000000         0.0            0.000000    3.000000     13.000000   2612.000000        3882.00000  7084.000000   0.013118  21.290000
# 25%             96.000000   0.000000    4.750000  8.375000         0.0            0.000000    3.000000     13.000000   2709.750000        4099.00000  7410.000000   0.015259  26.900000
# 50%             97.000000   1.000000    5.500000  9.750000         0.0            0.500000    4.500000     14.000000   3759.500000        4337.00000  8140.500000   0.018841  44.590000
# 75%            100.000000   3.000000    7.250000  9.900000         0.0            3.000000    5.000000     14.000000   4778.250000        4477.25000  8839.000000   0.022603  47.372500
# max            100.000000  11.000000   14.000000  9.900000         0.0           11.000000    8.000000     14.000000   4875.000000        4987.00000  9093.000000   0.026490  59.120000

# %% [markdown]
# ### 2. Normality Tests (Shapiro-Wilk)
#
# Before choosing a statistical test, you should always ask:
#
# **Do my data follow a normal distribution (a bell-shaped curve, like the Gaussian curve)?**
#
# - If the data **is normally distributed**, you can use **parametric tests** like the t-test.
# - If the data **is not normal**, you should use **non-parametric tests**, like the Mann-Whitney U test.
#
# To decide between t-test and Mann-Whitney:
#
# - If **p < 0.05** → the data is **not normal** → use **Mann-Whitney U-test**.
# - If **p ≥ 0.05** → the data **is normal** → use **t-test**.

# %%
print("\nShapiro-Wilk Normality Tests:")
for column in ['AccessibilityScore', 'AxeIssues', 'WAVEIssues', 'WAVEAim', 'WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures',
               'PromptTokens', 'CompletionTokens', 'TotalTokens', 'TotalCost', 'TotalTime']:
    stat, p = stats.shapiro(df[column])
    print(f'{column}: W={stat:.4f}, p-value={p:.4f}')

print("\nShapiro-Wilk Normality Tests (With Originals):")
for column in ['AccessibilityScore', 'AxeIssues', 'WAVEIssues', 'WAVEAim', 'WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures']:
    stat, p = stats.shapiro(df_with_orig[column])
    print(f'{column}: W={stat:.4f}, p-value={p:.4f}')
# Out:
# Shapiro-Wilk Normality Tests:
# AccessibilityScore: W=0.7360, p-value=0.0057
# AxeIssues: W=0.6894, p-value=0.0017
# WAVEIssues: W=0.8325, p-value=0.0630
# WAVEAim: W=0.7357, p-value=0.0057
# WAVEErrors: W=1.0000, p-value=1.0000
# WAVEContrastErrors: W=0.6735, p-value=0.0011
# WAVEAlerts: W=0.8261, p-value=0.0540
# WAVEFeatures: W=0.6412, p-value=0.0005
# PromptTokens: W=0.7187, p-value=0.0037
# CompletionTokens: W=0.9192, p-value=0.4237
# TotalTokens: W=0.8440, p-value=0.0828
# TotalCost: W=0.8951, p-value=0.2607
# TotalTime: W=0.9141, p-value=0.3838
#
# Shapiro-Wilk Normality Tests (With Originals):
# AccessibilityScore: W=0.4896, p-value=0.0000
# AxeIssues: W=0.5405, p-value=0.0000
# WAVEIssues: W=0.7190, p-value=0.0024
# WAVEAim: W=0.7688, p-value=0.0089
# WAVEErrors: W=0.3898, p-value=0.0000
# WAVEContrastErrors: W=0.7240, p-value=0.0027
# WAVEAlerts: W=0.8276, p-value=0.0420
# WAVEFeatures: W=0.4922, p-value=0.0000
# /Users/gvera/codigo/doctorado/04.model-springer/.venv/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:592: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# ### Interpretation of Normality Results
#
# The key variables have **p-values < 0.05**, which indicates they **do not follow a normal distribution**.
#
# **Reflection**
#
# Since several of the analyzed variables are **not normally distributed**, using the **Mann–Whitney U test** is more appropriate than the t-test because:
#
# - It **does not assume normality**.
# - It is **robust to skewed distributions and outliers**.
# - It is **suitable for small samples**, as in this case (**n = 16**).
#
# **Conclusion:**
# - The **t-test is not suitable** in this context.
# - The use of the **Mann–Whitney U test in this study is statistically justified**.

# %% [markdown]
# ### 3. Condition Comparisons (Mann–Whitney U Test)
#
# **What is the Mann–Whitney U test?**
#
# - It’s a statistical test to compare **two independent groups** and determine if one tends to have **higher values** than the other.
# - It **does not assume normal distribution** of data, which makes it suitable for real-world scenarios.
# - It is the **non-parametric equivalent** of the t-test.
#
# **How does it work?**
#
# - All values from both groups are **ranked from lowest to highest**.
# - It checks whether one group **consistently ranks higher** than the other.
# - A **p-value** is computed to assess if the observed difference is statistically significant.
#
# **Why do we use it in this study?**
#
# - To compare groups like:
#   - **GPT-4o vs. Gemini** (e.g., who achieves better accessibility scores?)
#   - **HTML vs. Markdown** inputs
#   - **Template vs. No Template** prompts
#
# **In short:**
# Mann–Whitney helps determine if there's a **real difference between two groups**, even with small or non-normal samples.

# %%
comparisons = [
    ('Model', 'GPT-4o', 'Gemini'),
    ('InputType', 'HTML', 'Markdown'),
    ('TemplateUsed', 'Yes', 'No')
]

metrics = ['AccessibilityScore', 'AxeIssues', 'WAVEIssues', 'WAVEAim', 'WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures',
           'PromptTokens', 'CompletionTokens', 'TotalTokens', 'TotalCost', 'TotalTime']

for compare_by, val1, val2 in comparisons:
    print(f"\nComparisons by {compare_by}: {val1} vs {val2}")
    group1 = df[df[compare_by] == val1]
    group2 = df[df[compare_by] == val2]
    for metric in metrics:
        stat, p = stats.mannwhitneyu(group1[metric], group2[metric])
        print(f'{metric}: U={stat:.4f}, p-value={p:.4f}')
# Out:
# Comparisons by Model: GPT-4o vs Gemini
# AccessibilityScore: U=9.0000, p-value=0.8744
# AxeIssues: U=5.0000, p-value=0.4539
# WAVEIssues: U=9.5000, p-value=0.7702
# WAVEAim: U=9.0000, p-value=0.8778
# WAVEErrors: U=8.0000, p-value=1.0000
# WAVEContrastErrors: U=6.5000, p-value=0.7568
# WAVEAlerts: U=16.0000, p-value=0.0228
# WAVEFeatures: U=10.0000, p-value=0.6084
# PromptTokens: U=4.0000, p-value=0.3429
# CompletionTokens: U=12.0000, p-value=0.3429
# TotalTokens: U=12.0000, p-value=0.3429
# TotalCost: U=2.0000, p-value=0.1143
# TotalTime: U=16.0000, p-value=0.0286
#
# Comparisons by InputType: HTML vs Markdown
# AccessibilityScore: U=4.5000, p-value=0.3428
# AxeIssues: U=11.0000, p-value=0.4539
# WAVEIssues: U=12.5000, p-value=0.2425
# WAVEAim: U=4.5000, p-value=0.3562
# WAVEErrors: U=8.0000, p-value=1.0000
# WAVEContrastErrors: U=12.0000, p-value=0.2784
# WAVEAlerts: U=6.0000, p-value=0.6489
# WAVEFeatures: U=6.0000, p-value=0.6084
# PromptTokens: U=10.0000, p-value=0.6857
# CompletionTokens: U=8.0000, p-value=1.0000
# TotalTokens: U=9.0000, p-value=0.8857
# TotalCost: U=6.0000, p-value=0.6857
# TotalTime: U=9.0000, p-value=0.8857
#
# Comparisons by TemplateUsed: Yes vs No
# AccessibilityScore: U=4.5000, p-value=0.3428
# AxeIssues: U=9.5000, p-value=0.7645
# WAVEIssues: U=9.0000, p-value=0.8839
# WAVEAim: U=5.5000, p-value=0.5385
# WAVEErrors: U=8.0000, p-value=1.0000
# WAVEContrastErrors: U=10.5000, p-value=0.5357
# WAVEAlerts: U=8.0000, p-value=1.0000
# WAVEFeatures: U=2.0000, p-value=0.0603
# PromptTokens: U=16.0000, p-value=0.0286
# CompletionTokens: U=0.0000, p-value=0.0286
# TotalTokens: U=16.0000, p-value=0.0286
# TotalCost: U=14.0000, p-value=0.1143
# TotalTime: U=7.0000, p-value=0.8857

# %% [markdown]
# ### 4. Correlation Analysis (Spearman)
#
# Used tokens vs. accessibility quality.
#
# - Spearman correlation is used to measure **whether two variables tend to increase or decrease together**.
# - It’s ideal when data is **not normally distributed** or the relationship is **not linear**.
# - Unlike comparison tests, it tells us **how strongly two variables are related**.
#
# **How does it work?**
# - It ranks the values of each variable.
# - It compares the rankings to assess **how similar their trends are**.
# - The result is a coefficient called **rho (ρ)**:
#
# | ρ (rho) Value | Interpretation |
# |:-------------:|:-------------------------------|
# | +1.0          | Perfect positive correlation: as one increases, the other also increases. |
# | -1.0          | Perfect negative correlation: as one increases, the other decreases. |
# |  0.0          | No correlation at all. |
#
# **Rangos de interpretación comunes (Cohen, 1988; Mukaka, 2012):**
#
# * **0.00–0.19** → very weak
# * **0.20–0.39** → weak
# * **0.40–0.59** → moderate
# * **0.60–0.79** → strong
# * **0.80–1.00** → very strong
#
# *(Lo mismo aplica en signo negativo, solo que la relación es inversa).*
#
# **When do we use it in this study?**
# - To examine relationships like:
#   - Do **more tokens** result in **higher accessibility**?
#   - Do **more Axe or WAVE errors** mean **lower accessibility**?
#
# **In short:**
# > Spearman tells us **how well two variables move together**, regardless of shape or distribution.

# %%
# ---- Cálculo de Spearman con valores ORIGINALES ----
print("\nSpearman Correlation Analysis (WITH ORIGINALS):")
correlation_pairs = [
    ('TotalTokens', 'AccessibilityScore'),
    ('AxeIssues', 'AccessibilityScore'),
    ('WAVEIssues', 'AccessibilityScore'),
    ('AxeIssues', 'WAVEIssues'),
    ('AxeIssues', 'WAVEAim'),
    ('WAVEAim', 'AccessibilityScore'),
    # ('WAVEErrors', 'AccessibilityScore'), # si WAVE errors = 0, se mantiene comentado
    ('WAVEContrastErrors', 'AccessibilityScore'),
    ('WAVEAlerts', 'AccessibilityScore'),
    ('WAVEFeatures', 'AccessibilityScore')
]

for x, y in correlation_pairs:
    pair = df_with_orig[[x, y]].dropna()
    if len(pair) < 2:
        print(f'{x} vs {y}: not enough data after dropna()')
        continue
    rho, p = stats.spearmanr(pair[x], pair[y])
    print(f'{x} vs {y}: rho={rho:.4f}, p-value={p:.4f}')
# Out:
# Spearman Correlation Analysis (WITH ORIGINALS):
# TotalTokens vs AccessibilityScore: rho=-0.4043, p-value=0.3205
# AxeIssues vs AccessibilityScore: rho=-0.9415, p-value=0.0002
# WAVEIssues vs AccessibilityScore: rho=-0.8763, p-value=0.0019
# AxeIssues vs WAVEIssues: rho=0.8794, p-value=0.0018
# AxeIssues vs WAVEAim: rho=-0.9510, p-value=0.0001
# WAVEAim vs AccessibilityScore: rho=0.9261, p-value=0.0003
# WAVEContrastErrors vs AccessibilityScore: rho=-0.9303, p-value=0.0003
# WAVEAlerts vs AccessibilityScore: rho=-0.2904, p-value=0.4484
# WAVEFeatures vs AccessibilityScore: rho=0.4758, p-value=0.1954

# %%
# Este es SIN los datos del sitio original

correlation_pairs = [
    ('TotalTokens', 'AccessibilityScore'),
    ('AxeIssues', 'AccessibilityScore'),
    ('WAVEIssues', 'AccessibilityScore'),
    ('AxeIssues', 'WAVEIssues'),
    ('AxeIssues', 'WAVEAim'),
    ('WAVEAim', 'AccessibilityScore'),
    # ('WAVEErrors', 'AccessibilityScore'), # Commented because WAVE errors=0
    ('WAVEContrastErrors', 'AccessibilityScore'),
    ('WAVEAlerts', 'AccessibilityScore'),
    ('WAVEFeatures', 'AccessibilityScore'),
    ('PromptTokens', 'AccessibilityScore'),
    ('CompletionTokens', 'AccessibilityScore'),
    ('PromptTokens', 'WAVEAim'),
    ('CompletionTokens', 'WAVEAim'),
    ('TotalCost', 'AccessibilityScore'),
    ('TotalTime', 'AccessibilityScore'),
    ('TotalCost', 'WAVEAim'),
    ('TotalTime', 'WAVEAim')
]

print("\nSpearman Correlation Analysis:")
for x, y in correlation_pairs:
    rho, p = stats.spearmanr(df[x], df[y])
    print(f'{x} vs {y}: rho={rho:.4f}, p-value={p:.4f}')

# Pearson Correlation Analysis
print("\nPearson Correlation Analysis (when normal distribution):")
for x, y in correlation_pairs:
    pearson_corr, p = stats.pearsonr(df[x], df[y])
    print(f'{x} vs {y}: r={pearson_corr:.4f}, p-value={p:.4f}')
# Out:
# Spearman Correlation Analysis:
# TotalTokens vs AccessibilityScore: rho=-0.4043, p-value=0.3205
# AxeIssues vs AccessibilityScore: rho=-0.9135, p-value=0.0015
# WAVEIssues vs AccessibilityScore: rho=-0.8183, p-value=0.0130
# AxeIssues vs WAVEIssues: rho=0.8253, p-value=0.0117
# AxeIssues vs WAVEAim: rho=-0.9280, p-value=0.0009
# WAVEAim vs AccessibilityScore: rho=0.8892, p-value=0.0031
# WAVEContrastErrors vs AccessibilityScore: rho=-0.8953, p-value=0.0026
# WAVEAlerts vs AccessibilityScore: rho=0.0274, p-value=0.9486
# WAVEFeatures vs AccessibilityScore: rho=0.1852, p-value=0.6607
# PromptTokens vs AccessibilityScore: rho=-0.5086, p-value=0.1981
# CompletionTokens vs AccessibilityScore: rho=0.3912, p-value=0.3379
# PromptTokens vs WAVEAim: rho=-0.3932, p-value=0.3352
# CompletionTokens vs WAVEAim: rho=0.3551, p-value=0.3880
# TotalCost vs AccessibilityScore: rho=-0.3782, p-value=0.3556
# TotalTime vs AccessibilityScore: rho=-0.1043, p-value=0.8058
# TotalCost vs WAVEAim: rho=-0.3171, p-value=0.4441
# TotalTime vs WAVEAim: rho=-0.1268, p-value=0.7647
#
# Pearson Correlation Analysis (when normal distribution):
# TotalTokens vs AccessibilityScore: r=-0.3523, p-value=0.3921
# AxeIssues vs AccessibilityScore: r=-0.6086, p-value=0.1093
# WAVEIssues vs AccessibilityScore: r=-0.6595, p-value=0.0752
# AxeIssues vs WAVEIssues: r=0.8882, p-value=0.0032
# AxeIssues vs WAVEAim: r=-0.9792, p-value=0.0000
# WAVEAim vs AccessibilityScore: r=0.6643, p-value=0.0724
# WAVEContrastErrors vs AccessibilityScore: r=-0.6022, p-value=0.1142
# WAVEAlerts vs AccessibilityScore: r=-0.1279, p-value=0.7628
# WAVEFeatures vs AccessibilityScore: r=0.1741, p-value=0.6801
# PromptTokens vs AccessibilityScore: r=-0.4304, p-value=0.2871
# CompletionTokens vs AccessibilityScore: r=0.4751, p-value=0.2342
# PromptTokens vs WAVEAim: r=0.0119, p-value=0.9776
# CompletionTokens vs WAVEAim: r=0.2524, p-value=0.5465
# TotalCost vs AccessibilityScore: r=-0.2315, p-value=0.5811
# TotalTime vs AccessibilityScore: r=0.0049, p-value=0.9908
# TotalCost vs WAVEAim: r=-0.0461, p-value=0.9137
# TotalTime vs WAVEAim: r=-0.0473, p-value=0.9114

# %% [markdown]
# ### 5. Visualizations
# ### 5.1 Boxplots — Group Comparisons
#
# Boxplots are a great way to visually compare how different groups behave.
#
# - They show the **distribution** of a variable within each group.
# - You can quickly spot **differences in medians**, **variability**, and **potential outliers**.
#
# **What do they display?**
# - **Box**: shows the middle 50% of the data (interquartile range).
# - **Line inside the box**: the median value.
# - **Whiskers**: extend to the minimum and maximum values (excluding outliers).
# - **Dots**: possible outliers.
#
# **How we use them in this study:**
# - Compare **accessibility scores** between models (e.g., GPT-4o vs. Gemini).
# - Compare **token usage** by input format (HTML vs. Markdown).
# - Compare **WAVE errors** between pages with and without templates.
#
# > Boxplots help visualize **how spread out and different** the data is across conditions.

# %% [markdown]
# #### Color palette

# %%
# Configurar colores
color_claro = "#F8D9BC"
color_medio = "#F8E7D6"
color_fuerte = "#F8BC85"
color_borde = "#FE7B00"

color_negro = "#000000"  # negro
color_rojo = "#FF0000"  # rojo

# %% [markdown]
# #### WAVE AIM Scores by Model

# %%
# Estilo visual
sns.reset_defaults()

plt.figure(figsize=(7,4))
sns.boxplot(x='Model', y='WAVEAim', data=df, width=0.4,
    boxprops=dict(edgecolor=color_borde, facecolor=color_claro),
    medianprops=dict(color=color_negro),
    whiskerprops=dict(color=color_borde),
    capprops=dict(color=color_borde),
    flierprops=dict(markerfacecolor=color_claro, markeredgecolor=color_borde)
)
plt.title('WAVE AIM by Model', fontsize=15)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.ylabel('WAVE AIM Score')
plt.xlabel('Model')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/Fig10a.png', dpi=600)
plt.show()

# %% [markdown]
# #### WAVE AIM by Input Type (HTML vs Markdown)

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='InputType', y='WAVEAim', data=df, width=0.4,
    boxprops=dict(edgecolor=color_borde, facecolor=color_claro),
    medianprops=dict(color=color_negro),
    whiskerprops=dict(color=color_borde),
    capprops=dict(color=color_borde),
    flierprops=dict(markerfacecolor=color_claro, markeredgecolor=color_borde)
)
plt.title('WAVE AIM by Input Type', fontsize=15)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.ylabel('WAVE AIM Score')
plt.xlabel('Input Type')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_wave_aim_inputtype.jpg', dpi=600)
plt.show()

# %% [markdown]
# #### WAVE AIM Scores by Template Usage

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='TemplateUsed', y='WAVEAim', data=df, width=0.4,
    boxprops=dict(edgecolor=color_borde, facecolor=color_claro),
    medianprops=dict(color=color_negro),
    whiskerprops=dict(color=color_borde),
    capprops=dict(color=color_borde),
    flierprops=dict(markerfacecolor=color_claro, markeredgecolor=color_borde)
)
plt.title('WAVE AIM by Template Usage', fontsize=15)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.ylabel('WAVE AIM Score')
plt.xlabel('Template Used')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_wave_aim_template.jpg', dpi=600)
plt.show()

# %% [markdown]
# #### Accessibility Scores by Model

# %%
# Estilo visual
sns.reset_defaults()

plt.figure(figsize=(7,4))
sns.boxplot(x='Model', y='AccessibilityScore', data=df, width=0.4,
    boxprops=dict(edgecolor=color_borde, facecolor=color_claro),
    medianprops=dict(color=color_negro),
    whiskerprops=dict(color=color_borde),
    capprops=dict(color=color_borde),
    flierprops=dict(markerfacecolor=color_claro, markeredgecolor=color_borde)
)
plt.title('Accessibility Score by Model', fontsize=15)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.ylabel('Accessibility Score (Lighthouse)')
plt.xlabel('Model')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_accessibility_model.jpg', dpi=300)
plt.show()

# %% [markdown]
# #### Accessibility Score by Input Type (HTML vs Markdown)

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='InputType', y='AccessibilityScore', data=df, width=0.4,
    boxprops=dict(edgecolor=color_borde, facecolor=color_claro),
    medianprops=dict(color=color_negro),
    whiskerprops=dict(color=color_borde),
    capprops=dict(color=color_borde),
    flierprops=dict(markerfacecolor=color_claro, markeredgecolor=color_borde)
)
plt.title('Accessibility Score by Input Type', fontsize=15)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.ylabel('Accessibility Score (Lighthouse)')
plt.xlabel('Input Type')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_accessibility_inputtype.jpg', dpi=300)
plt.show()

# %% [markdown]
# #### Accessibility Score by Template Usage

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='TemplateUsed', y='AccessibilityScore', data=df, width=0.4,
    boxprops=dict(edgecolor=color_borde, facecolor=color_claro),
    medianprops=dict(color=color_negro),
    whiskerprops=dict(color=color_borde),
    capprops=dict(color=color_borde),
    flierprops=dict(markerfacecolor=color_claro, markeredgecolor=color_borde)
)
plt.title('Accessibility Score by Template Usage', fontsize=15)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.ylabel('Accessibility Score (Lighthouse)')
plt.xlabel('Template Used')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_accessibility_template.jpg', dpi=300)
plt.show()

# %% [markdown]
# #### Axe Issues by Model

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Model', y='AxeIssues', data=df, width=0.4,
    boxprops=dict(edgecolor=color_borde, facecolor=color_claro),
    medianprops=dict(color=color_negro),
    whiskerprops=dict(color=color_borde),
    capprops=dict(color=color_borde),
    flierprops=dict(markerfacecolor=color_claro, markeredgecolor=color_borde)
)
plt.title('Axe Issues by Model', fontsize=15)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_axeissues_model.jpg', dpi=400)
plt.show()

# %% [markdown]
# #### Axe issues by Input Type (HTML vs Markdown)

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='InputType', y='AxeIssues', data=df, width=0.4,
    boxprops=dict(edgecolor=color_borde, facecolor=color_claro),
    medianprops=dict(color=color_negro),
    whiskerprops=dict(color=color_borde),
    capprops=dict(color=color_borde),
    flierprops=dict(markerfacecolor=color_claro, markeredgecolor=color_borde)
)
plt.title('Axe Issues by Input Type', fontsize=15)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.ylabel('Axe Issues')
plt.xlabel('Input Type')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_axeissues_inputtype.jpg', dpi=300)
plt.show()

# %% [markdown]
# #### Axe Issues by Template Usage

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='TemplateUsed', y='AxeIssues', data=df, width=0.4,
    boxprops=dict(edgecolor=color_borde, facecolor=color_claro),
    medianprops=dict(color=color_negro),
    whiskerprops=dict(color=color_borde),
    capprops=dict(color=color_borde),
    flierprops=dict(markerfacecolor=color_claro, markeredgecolor=color_borde)
)
plt.title('Axe Issues by Template Usage', fontsize=15)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.ylabel('AxeIssues')
plt.xlabel('Template Used')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_axeissues_template.jpg', dpi=300)
plt.show()

# %% [markdown]
# #### WAVE Issues by Model

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Model', y='WAVEIssues', data=df, width=0.4,
    boxprops=dict(edgecolor=color_borde, facecolor=color_claro),
    medianprops=dict(color=color_negro),
    whiskerprops=dict(color=color_borde),
    capprops=dict(color=color_borde),
    flierprops=dict(markerfacecolor=color_claro, markeredgecolor=color_borde)
)
plt.title('WAVE Issues by Model', fontsize=15)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_waveissues_model.jpg', dpi=400)
plt.show()

# %% [markdown]
# #### WAVE issues by Input Type (HTML vs Markdown)

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='InputType', y='WAVEIssues', data=df, width=0.4,
    boxprops=dict(edgecolor=color_borde, facecolor=color_claro),
    medianprops=dict(color=color_negro),
    whiskerprops=dict(color=color_borde),
    capprops=dict(color=color_borde),
    flierprops=dict(markerfacecolor=color_claro, markeredgecolor=color_borde)
)
plt.title('WAVE Issues by Input Type', fontsize=15)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.ylabel('WAVE Issues')
plt.xlabel('Input Type')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_waveissues_inputtype.jpg', dpi=300)
plt.show()

# %% [markdown]
# #### WAVE Issues by Template Usage

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='TemplateUsed', y='WAVEIssues', data=df, width=0.4,
    boxprops=dict(edgecolor=color_borde, facecolor=color_claro),
    medianprops=dict(color=color_negro),
    whiskerprops=dict(color=color_borde),
    capprops=dict(color=color_borde),
    flierprops=dict(markerfacecolor=color_claro, markeredgecolor=color_borde)
)
plt.title('WAVE Issues by Template Usage', fontsize=15)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.ylabel('WAVE Issues')
plt.xlabel('Template Used')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_waveissues_template.jpg', dpi=300)
plt.show()

# %% [markdown]
# ### 1.2 Total tokens by model

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='Model', y='TotalTokens', data=df, width=0.4,
    boxprops=dict(edgecolor=color_borde, facecolor=color_claro),
    medianprops=dict(color=color_negro),
    whiskerprops=dict(color=color_borde),
    capprops=dict(color=color_borde),
    flierprops=dict(markerfacecolor=color_claro, markeredgecolor=color_borde)
)
plt.title('Total tokens by Model', fontsize=15)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_tokens_model.png', dpi=600)
plt.show()

# %% [markdown]
# ### 1.3 Total time by model

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='Model', y='TotalTime', data=df, width=0.4,
    boxprops=dict(edgecolor=color_borde, facecolor=color_claro),
    medianprops=dict(color=color_negro),
    whiskerprops=dict(color=color_borde),
    capprops=dict(color=color_borde),
    flierprops=dict(markerfacecolor=color_claro, markeredgecolor=color_borde)
)
plt.title('Total time by Model', fontsize=15)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/Fig10b.png', dpi=600)
plt.show()

# %% [markdown]
# ### 2. Scatterplots — Correlations

# %% [markdown]
# #### 2.1 Prompt tokens vs Accessibility Score

# %%
# Crear scatterplot
plt.figure(figsize=(8,6))
sns.scatterplot(
    x='PromptTokens', 
    y='AccessibilityScore', 
    hue='Model', 
    style='TemplateUsed', 
    data=df,
    s=100,
    edgecolor='black',
)

# Añadir línea de tendencia (regresión lineal)
sns.regplot(
    x='PromptTokens', 
    y='AccessibilityScore', 
    data=df, 
    scatter=False, 
    color=color_borde,  # Color personalizado
    ci=None
)

plt.title('Prompt Tokens vs Accessibility Score', fontsize=15)
plt.xlabel('Prompt Tokens', fontsize=14)
plt.ylabel('Accessibility Score (Lighthouse)', fontsize=14)
plt.grid(linestyle='--', linewidth=0.7)
plt.tight_layout()

# Guardar imagen
plt.savefig('figures/scatter_completiontokens_vs_accessibility.png', dpi=500)
plt.show()

# %% [markdown]
# #### 2.2 Total Tokens vs Accessibility Score

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='TotalTokens', y='AccessibilityScore', hue=df['Model'], style=df['TemplateUsed'], data=df, s=100, edgecolor='black')
sns.regplot(x='TotalTokens', y='AccessibilityScore', data=df, scatter=False, color=color_borde, ci=None)

plt.title('Total Tokens vs Accessibility Score', fontsize=15)
plt.xlabel('Total Tokens (Prompt + Completion)', fontsize=14)
plt.ylabel('Accessibility Score (Lighthouse)', fontsize=14)
plt.grid(linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/scatter_tokens_vs_accessibility.png', dpi=500)
plt.show()

# %% [markdown]
# #### 2.3 Axe Issues vs Accessibility Score

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='AxeIssues', y='AccessibilityScore', hue=df['Model'], style=df['InputType'], data=df, s=100, edgecolor='black')
sns.regplot(x='AxeIssues', y='AccessibilityScore', data=df, scatter=False, color=color_borde, ci=None)
plt.title('Axe Issues vs Accessibility Score')
plt.xlabel('Number of Axe Issues')
plt.ylabel('Accessibility Score (Lighthouse)')
plt.grid(linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/scatter_axeissues_vs_accessibility.jpg', dpi=300)
plt.show()

# %% [markdown]
# #### 2.4 Axe Issues vs Accessibility Score (WITH ORIGINAL)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='AxeIssues', y='AccessibilityScore', data=df_with_orig, s=100, edgecolor='black')
sns.regplot(x='AxeIssues', y='AccessibilityScore', data=df_with_orig, scatter=False, color=color_borde, ci=None)

plt.title('Axe Issues vs Accessibility Score', fontsize=15)
plt.xlabel('Number of Axe Issues', fontsize=14)
plt.ylabel('Accessibility Score (Lighthouse)', fontsize=14)
plt.grid(linestyle='--', linewidth=0.7)
# plt.tight_layout()
plt.savefig('figures/scatter_axeissues_vs_accessibility_original.png', dpi=500)
plt.show()

# %% [markdown]
# #### 2.5 WAVEIssues vs Accessibility Score (WITH ORIGINAL)

# %%
# Función para clasificar la fuerza de la correlación
def classify_corr(r):
    r_abs = abs(r)
    if r_abs < 0.2:
        return "Very Weak"
    elif r_abs < 0.4:
        return "Weak"
    elif r_abs < 0.6:
        return "Moderate"
    elif r_abs < 0.8:
        return "Strong"
    else:
        return "Very Strong"

# %%
from scipy.stats import pearsonr, spearmanr

plt.figure(figsize=(6,4))
sns.scatterplot(x='WAVEIssues', y='AccessibilityScore', data=df_with_orig, s=100, edgecolor='black')
sns.regplot(x='WAVEIssues', y='AccessibilityScore', data=df_with_orig, scatter=False, color=color_borde, ci=None)

# plt.title('WAVE Issues vs Accessibility Score', fontsize=15)
plt.xlabel('WAVE Issues', fontsize=15)
plt.ylabel('Accessibility Score', fontsize=15, labelpad=-6)

# Ocultar números de ejes 
plt.gca().set_xticklabels([]) 
plt.gca().set_yticklabels([])
plt.gca().xaxis.set_label_position('top')

# Calcular correlaciones
r, p_r = pearsonr(df_with_orig['WAVEIssues'], df_with_orig['AccessibilityScore'])
rho, p_rho = spearmanr(df_with_orig['WAVEIssues'], df_with_orig['AccessibilityScore'])

# Clasificación de Spearman
strength = classify_corr(rho)

# Anotar cuadro con Pearson y Spearman
pos_x=0.03
pos_y=0.29
# plt.text(pos_x, pos_y,
#             f"Pearson r = {r:.2f}, p = {p_r:.3f}\nSpearman ρ = {rho:.2f}, p = {p_rho:.3f}", 
#             transform=plt.gca().transAxes, fontsize=14,
#             verticalalignment='top', bbox=dict(boxstyle="square,pad=0.3", 
#             facecolor="white", edgecolor="#BBB", alpha=0.8))
plt.text(pos_x, pos_y,
            f"Spearman ρ = {rho:.2f}, p = {p_rho:.3f}", 
            transform=plt.gca().transAxes, fontsize=14,
            verticalalignment='top', bbox=dict(boxstyle="square,pad=0.3", 
            facecolor="white", edgecolor="#BBB", alpha=0.8))

# Añadir leyenda debajo con la interpretación de la fuerza
pos_y=0.128
plt.text(pos_x, pos_y, f"{strength}", 
            transform=plt.gca().transAxes, fontsize=14, fontweight='bold', bbox=dict(boxstyle="square,pad=0.3", 
            facecolor="white", edgecolor="#BBB", alpha=0.8))

plt.grid(linestyle='--', linewidth=0.7)
# plt.tight_layout()
plt.savefig('figures/scatter_waveissues_vs_accessibility_original.png', dpi=500)
plt.show()

# %% [markdown]
# #### 2.6 AxeIssues vs WAVEIssues Score (WITH ORIGINAL)

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='AxeIssues', y='WAVEIssues', data=df_with_orig, s=100, edgecolor='black')
sns.regplot(x='AxeIssues', y='WAVEIssues', data=df_with_orig, scatter=False, color=color_borde, ci=None)

# plt.title('Axe Issues vs WAVE Issues', fontsize=15)
plt.xlabel('Axe Issues', fontsize=15)
plt.ylabel('WAVE Issues', fontsize=15, labelpad=-6)

# Ocultar números de ejes 
plt.gca().set_xticklabels([]) 
plt.gca().set_yticklabels([])
plt.gca().xaxis.set_label_position('top')

# Calcular correlaciones
r, p_r = pearsonr(df_with_orig['AxeIssues'], df_with_orig['WAVEIssues'])
rho, p_rho = spearmanr(df_with_orig['AxeIssues'], df_with_orig['WAVEIssues'])

# Clasificación de Spearman
strength = classify_corr(rho)

# Anotar cuadro con Pearson y Spearman
pos_x=0.32
pos_y=0.28
# plt.text(pos_x, pos_y,
#             f"Pearson r = {r:.2f}, p = {p_r:.3f}\nSpearman ρ = {rho:.2f}, p = {p_rho:.3f}", 
#             transform=plt.gca().transAxes, fontsize=14,
#             verticalalignment='top', bbox=dict(boxstyle="square,pad=0.3", 
#             facecolor="white", edgecolor="#BBB", alpha=0.8))

plt.text(pos_x, pos_y,
            f"Spearman ρ = {rho:.2f}, p = {p_rho:.3f}", 
            transform=plt.gca().transAxes, fontsize=14,
            verticalalignment='top', bbox=dict(boxstyle="square,pad=0.3", 
            facecolor="white", edgecolor="#BBB", alpha=0.8))

# Añadir leyenda debajo con la interpretación de la fuerza
pos_y=0.128
plt.text(pos_x, pos_y, f"{strength}", 
            transform=plt.gca().transAxes, fontsize=14, fontweight='bold', bbox=dict(boxstyle="square,pad=0.3", 
            facecolor="white", edgecolor="#BBB", alpha=0.8))

plt.grid(linestyle='--', linewidth=0.7)
# plt.tight_layout()
plt.savefig('figures/scatter_axeissues_vs_waveissues_original.png', dpi=500)
plt.show()

# %% [markdown]
# ### 3. Bar Charts — Before and After Comparisons

# %% [markdown]
# #### 3.1 Errores WAVE Original vs Mejorados (per site)

# %%
import pandas as pd

# Provided dataframe `df` assumed to be already loaded with all metrics
# Compute the generated means grouped by site
generated_metrics = df.groupby('Site')[['WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures']].mean()

# Build summary table
rows = []
for site in ['Site 1']:
    for metric in ['WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures']:
        original = original_wave_metrics[site][metric]
        generated = generated_metrics.loc[site, metric]
        if metric == 'WAVEFeatures':
            improvement = ((generated - original) / original) * 100
        else:
            improvement = ((original - generated) / original) * 100
        rows.append({
            'Site': site,
            'Metric': metric.replace('WAVE', ''),
            'Original': original,
            'Generated Mean': round(generated, 2),
            'Improvement (%)': round(improvement, 1)
        })

# Convert to DataFrame
improvement_df = pd.DataFrame(rows)

# Show the result
print(improvement_df)
# Out:
#      Site          Metric  Original  Generated Mean  Improvement (%)
# 0  Site 1          Errors         9            0.00            100.0
# 1  Site 1  ContrastErrors        13            2.25             82.7
# 2  Site 1          Alerts         8            4.50             43.8
# 3  Site 1        Features         3           13.62            354.2

# %% [markdown]
# #### 3.2 WAVE Errors: Original vs Improved (per site)
#
# This bar chart compares the average number of WAVE errors before and after remediation for each site. The results show a significant reduction in detected errors, demonstrating the effectiveness of the LLM-based remediation process.

# %%
# Promedios de las métricas generadas
generated_metrics = df.groupby('Site')[['WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures']].mean()

# Estructurar los datos para graficar
data = []
sites = ['Site 1']
metrics = ['WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures']

for site in sites:
    for metric in metrics:
        data.append({
            'Site': site,
            'Metric': metric,
            'Type': 'Original',
            'Value': original_wave_metrics[site][metric]
        })
        data.append({
            'Site': site,
            'Metric': metric,
            'Type': 'Generated',
            'Value': generated_metrics.loc[site, metric]
        })

compare_df = pd.DataFrame(data)
print(compare_df)

# Remover prefijo 'WAVE' de las etiquetas
compare_df['Metric'] = compare_df['Metric'].str.replace('WAVE', '')

# Gráfica
plt.figure(figsize=(12,6))

# Dibujar las barras manualmente por tipo
palette = {'Original': color_medio, 'Generated': color_claro}
edgecolor = color_borde

sns.barplot(x='Metric', y='Value', hue='Type', data=compare_df, errorbar=None, palette=palette, edgecolor=edgecolor)
plt.title('Comparison of WAVE metrics: Original vs Generated pages', fontsize=15)
plt.ylabel('Average number of issues')
plt.xlabel('Accessibility Metric')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.legend(title='Page Type')
plt.tight_layout()
plt.savefig('figures/bar_wave_metrics_comparison.png', dpi=500)
plt.show()
# Out:
#      Site              Metric       Type   Value
# 0  Site 1          WAVEErrors   Original   9.000
# 1  Site 1          WAVEErrors  Generated   0.000
# 2  Site 1  WAVEContrastErrors   Original  13.000
# 3  Site 1  WAVEContrastErrors  Generated   2.250
# 4  Site 1          WAVEAlerts   Original   8.000
# 5  Site 1          WAVEAlerts  Generated   4.500
# 6  Site 1        WAVEFeatures   Original   3.000
# 7  Site 1        WAVEFeatures  Generated  13.625

# %% [markdown]
# #### 3.3 Axe and WAVE Issues: Original vs Improved (per site)
#
# This bar chart compares the average number of Axe and WAVE issues before and after remediation for each site. The results show a significant reduction in detected errors, demonstrating the effectiveness of the LLM-based remediation process.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

site = "Site 1"

# --- Tomar valores originales (de la primera fila 'Original') ---
orig_wave_issues = float(df_with_orig.iloc[0]['WAVEIssues'])
orig_axe_issues  = float(df_with_orig.iloc[0]['AxeIssues'])

# --- Promedios de las variantes generadas ---
gen_wave_issues = float(df['WAVEIssues'].mean())
gen_axe_issues  = float(df['AxeIssues'].mean())

# --- DataFrame de comparación ---
compare_df = pd.DataFrame([
    {'Metric': 'WAVE Issues', 'Type': 'Original',  'Value': orig_wave_issues},
    {'Metric': 'WAVE Issues', 'Type': 'Generated', 'Value': gen_wave_issues},
    {'Metric': 'Axe Issues',  'Type': 'Original',  'Value': orig_axe_issues},
    {'Metric': 'Axe Issues',  'Type': 'Generated', 'Value': gen_axe_issues},
])

# --- Plot ---
palette   = {'Original': color_medio, 'Generated': color_claro}
edgecolor = color_borde

plt.figure(figsize=(9, 5))
ax = sns.barplot(
    data=compare_df, x='Metric', y='Value', hue='Type',
    order=['WAVE Issues', 'Axe Issues'],
    palette=palette, edgecolor=edgecolor, errorbar=None
)

plt.title('Axe & WAVE issues: Original vs Generated', fontsize=15)
plt.ylabel('Number of issues')
plt.xlabel('Metric')
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.6)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.legend(title='Page Type')
plt.tight_layout()
plt.savefig('figures/bar_axe_wave_metrics_comparison.png', dpi=500)
plt.show()

# %% [markdown]
# #### 3.4 Lighhouse Score: Accessibility Score By Input Type And Model
#
# This bar chart compares the Accessibility Score by input type and model after remediation.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Preparar columna para eje X
df['Input+Template'] = df['InputType'] + df['TemplateUsed'].map({'Yes': '+T', 'No': ''})

# Crear diccionario de colores por modelo
palette = {'GPT-4o': color_fuerte, 'Gemini': color_claro}
edgecolor = color_borde  # Color del borde de las barras

plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='Input+Template', y='AccessibilityScore', hue='Model', palette=palette, edgecolor=edgecolor)

# Agregar línea del score original
plt.axhline(y=54, color=color_rojo, linestyle='--', linewidth=1.5, label='Original Score (54)')
plt.text(-0.38, 55, 'Original (54)', color=color_rojo, fontsize=9, va='bottom')


# Personalización del gráfico
plt.title("Accessibility Score by Input Type and Model", fontsize=15)
plt.ylabel("Accessibility Score")
plt.xlabel("Input configuration")
plt.ylim(50, 114)
plt.xticks(rotation=0, ha='center', fontsize=15)
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.legend(title='Model', loc='upper right', fontsize=11, title_fontsize=11)
plt.tight_layout()

# Guardar imagen
plt.savefig("figures/bar_accessibility_comparison_compact.png", dpi=500)
plt.show()

# %% [markdown]
# ### Additional: Distribution of Studies After QA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Simulamos una lista de puntajes QA sin normalizar
qa_scores = [
    0.95, 0.88, 0.80, 0.80, 0.98, 0.80, 0.80, 0.90, 0.80, 0.80,
    1.00, 0.80, 0.90, 0.98, 1.00, 0.95, 0.80, 0.95, 0.80, 0.95,
    0.80, 0.83, 0.80, 0.80, 0.98, 0.80, 1.00, 0.98, 0.98, 0.80,
    0.80, 0.80, 0.80, 0.80, 0.98, 0.80, 0.80, 0.80, 0.80, 0.80,
    0.80, 0.95, 1.00, 0.80, 0.80, 0.80, 0.80, 0.88, 0.88, 0.80,
    1.00, 1.00, 0.80, 0.80, 0.80, 0.88, 0.80, 0.80, 0.93, 0.98,
    0.80, 1.00, 0.80, 1.00, 0.95, 1.00, 0.80, 0.80, 0.80, 0.98,
    0.90, 0.80, 0.98, 1.00, 0.90, 0.80, 1.00, 0.98, 1.00, 0.98,
    0.80, 0.85, 1.00
]

# Convertimos a DataFrame
qa_df = pd.DataFrame({'NormalizedScore': qa_scores})

# Graficamos la distribución
plt.figure(figsize=(8, 4))
bars = sns.histplot(qa_df['NormalizedScore'], bins=10, kde=True, edgecolor=color_borde, color=color_claro)

# Personalización del gráfico
# plt.title('Distribution of normalized QA scores')
plt.xlabel('Normalized score', fontsize=15)
plt.ylabel('Number of studies', fontsize=15)
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()

# Guardar y mostrar
plt.savefig("figures/qa-distribution.png", dpi=500)
plt.show()
